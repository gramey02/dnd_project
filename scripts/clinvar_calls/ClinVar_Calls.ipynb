# %% [markdown]
# # Script to query ClinVar's API so we can tell how many missense mutations a gene may contain.

# %%
# load libraries
import json
from math import isnan
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle
import requests
import time
import urllib.request
from urllib.error import HTTPError
import time
from collections import defaultdict
from ast import literal_eval

# %%
data=pd.read_excel('/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/master_dataframe/dnd_593_2025_12_23.xlsx')
data.columns
# Out:
# Index(['hgnc_symbol', 'GENE ID (HGNC)', 'Approved name', 'DISEASE LABEL',
#        'DISEASE ID (MONDO)', 'MOI', 'CLASSIFICATION', 'HI Score', '%HI', 'pLI',
#        'LOEUF', 'total_plp', 'missense_plp', 'nonsense_plp', 'ensg', 'chrom',
#        's_het', 's_het_lower_CI', 's_het_upper_CI',
#        'indel_targetable_pre_NMD_assessment',
#        'num_indel_vars_pre_NMD_assessment',
#        'num_indel_amenable_vars_inducing_NMD',
#        'num_indel_amenable_vars_escaping_NMD',
#        'indel_targetable_post_NMD_assessment', 'crisproff_targetable',
#        'num_crisproff_vars', 'base_editable', 'num_base_editable_vars',
#        'excision_targetable', 'num_excision_vars', 'num_excision_pairs',
#        'HPO_term_list', 'indel_pam_targetable', 'crisproff_pam_targetable',
#        'base_edit_pam_targetable', 'excision_pam_targetable',
#        'hets_across_strats', 'prop_hets_across_strats', 'num_indel_hets',
#        'indel_hets_prop', 'num_crisproff_hets', 'crisproff_hets_prop',
#        'num_base_edit_hets', 'base_edit_hets_prop', 'num_excision_hets',
#        'excision_hets_prop', 'num_hets_targeted_four_guides_indels',
#        'num_hets_targeted_four_guides_crisproff',
#        'num_hets_targeted_four_guides_base_edits',
#        'num_hets_targeted_four_guides_excision',
#        'prop_hets_targeted_four_guides_indels',
#        'prop_hets_targeted_four_guides_crisproff',
#        'prop_hets_targeted_four_guides_base_edits',
#        'prop_hets_targeted_four_guides_excision', 'Gene Group'],
#       dtype='object')

# %%
gene_df=data[['hgnc_symbol']].drop_duplicates()

# %%
gene_df.sort_values(by='hgnc_symbol', inplace=True, ignore_index=True)
gene_df
# Out:
#     hgnc_symbol
# 0         AARS1
# 1         ABCB6
# 2         ABCC6
# 3         ABCC8
# 4         ABCC9
# ..          ...
# 588        ZIC1
# 589       ZMIZ1
# 590      ZMYND8
# 591      ZNF292
# 592      ZSWIM6
#
# [593 rows x 1 columns]

# %%
# =========================
# SETUP QUERY LINKS
# =========================
base_esearch = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
base_epost  = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/epost.fcgi"
base_esummary = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi"

record_list = []
mutation_nums = []
mis_mutation_nums = []
ns_mutation_nums = []
counter_list = []

session = requests.Session()  # reuse connections

# =========================
# CHECKPOINT CONFIG
# =========================
CHECKPOINT_DIR = "/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

CHECKPOINT_EVERY_N_GENES = 10  # hard checkpoint interval

PER_GENE_CSV = os.path.join(CHECKPOINT_DIR, "per_gene_checkpoint.csv")
ROLLING_CSV  = os.path.join(CHECKPOINT_DIR, "rolling_checkpoint.csv")

# =========================
# ClinVar JSON max
# =========================
ESUMMARY_PAGE_SIZE = 500

ALLOWED_GERMLINE = {
    "Pathogenic",
    "Likely pathogenic",
    "Pathogenic/Likely pathogenic",
}

# =========================
# HELPERS
# =========================
def batched(iterable, n):
    for i in range(0, len(iterable), n):
        yield iterable[i:i + n]


def request_with_429_retry(
    method,
    url,
    *,
    params=None,
    data=None,
    timeout=60,
    sleep_on_429=1.0,
    max_tries=10,
):
    for _attempt in range(max_tries):
        r = session.request(method, url, params=params, data=data, timeout=timeout)
        if r.status_code != 429:
            r.raise_for_status()
            return r
        print(f"429 from {url.split('/')[-1]} ; sleeping {sleep_on_429}s and retrying…")
        time.sleep(sleep_on_429)
    raise RuntimeError(f"Too many 429s from {url} after {max_tries} tries")


def epost_ids(db, ids):
    r = request_with_429_retry(
        "POST",
        base_epost,
        data={"db": db, "id": ",".join(ids)},
        timeout=60,
    )
    txt = r.text
    webenv = txt.split("<WebEnv>")[1].split("</WebEnv>")[0]
    query_key = txt.split("<QueryKey>")[1].split("</QueryKey>")[0]
    return webenv, query_key


def esummary_from_history(db, webenv, query_key, retstart, retmax):
    params = {
        "db": db,
        "query_key": query_key,
        "WebEnv": webenv,
        "retmode": "json",
        "retstart": retstart,
        "retmax": retmax,
    }
    r = request_with_429_retry("GET", base_esummary, params=params, timeout=60)
    data = r.json()
    if "error" in data:
        raise RuntimeError(f"ClinVar esummary error: {data['error']}")
    return data


def save_checkpoint(counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums):
    df = pd.DataFrame({
        "counter": counter_list,
        "gene": gene_list,
        "total_plp": mutation_nums,
        "missense_plp": mis_mutation_nums,
        "nonsense_plp": ns_mutation_nums,
    })
    df.to_csv(ROLLING_CSV, index=False)


def append_per_gene_row(counter, gene, total_plp, mis_plp, ns_plp):
    row = pd.DataFrame([{
        "counter": counter,
        "gene": gene,
        "total_plp": total_plp,
        "missense_plp": mis_plp,
        "nonsense_plp": ns_plp,
    }])
    header = not os.path.exists(PER_GENE_CSV)
    row.to_csv(PER_GENE_CSV, mode="a", header=header, index=False)


def load_checkpoint():
    """
    Returns:
      done_counters: set[int]
      counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums: lists
    """
    if not os.path.exists(PER_GENE_CSV):
        return set(), [], [], [], [], []

    df = pd.read_csv(PER_GENE_CSV)

    # Normalize / guard
    if df.empty:
        return set(), [], [], [], [], []

    # If you re-ran and appended duplicates, keep the last occurrence per counter.
    df = df.sort_values("counter").drop_duplicates(subset=["counter"], keep="last")

    done_counters = set(df["counter"].astype(int).tolist())

    counter_list = df["counter"].astype(int).tolist()
    gene_list = df["gene"].astype(str).tolist()
    mutation_nums = df["total_plp"].astype(int).tolist()
    mis_mutation_nums = df["missense_plp"].astype(int).tolist()
    ns_mutation_nums = df["nonsense_plp"].astype(int).tolist()

    return done_counters, counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums


# =========================
# RESUME STATE
# =========================
done_counters, counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums = load_checkpoint()

if done_counters:
    print(f"Resuming from checkpoint: {len(done_counters)} genes already completed.")
    print(f"Last completed counter: {max(done_counters)}")
else:
    print("No checkpoint found. Starting fresh.")

# This list is only used for debugging / optional record keeping
record_list = []  # NOTE: not checkpointed (can be huge); remove if you don't need it.

# =========================
# MAIN LOOP (RESUMABLE)
# =========================
for counter, gene in enumerate(gene_df["hgnc_symbol"]):
    if counter in done_counters:
        continue

    print(f"{counter}  {gene}")

    term = (
        f'{gene}[gene] AND single_gene[prop] AND "moi autosomal dominant"[prop] AND '
        '(pathogenic[clinsig] OR "likely pathogenic"[clinsig] OR "pathogenic/likely pathogenic"[clinsig])'
    )

    esearch_params = {"db": "clinvar", "term": term, "retmode": "json", "retmax": 100000}
    r = request_with_429_retry("GET", base_esearch, params=esearch_params, timeout=30)
    esearch_data = r.json()

    cur_ids = esearch_data["esearchresult"]["idlist"]
    record_list.append(cur_ids)

    # STRICT aggregate germline P/LP-only counts
    p_lp_mutation_counter = 0
    mis_plp_mutation_counter = 0
    ns_plp_mutation_counter = 0

    if cur_ids:
        for post_batch in batched(cur_ids, 5000):
            webenv, query_key = epost_ids("clinvar", post_batch)

            retstart = 0
            while retstart < len(post_batch):
                esum_data = esummary_from_history(
                    "clinvar",
                    webenv,
                    query_key,
                    retstart=retstart,
                    retmax=ESUMMARY_PAGE_SIZE,
                )
                #print(len(esum_data.get("result", {}).get("uids", [])))
                for uid in esum_data.get("result", {}).get("uids", []):
                    cur_uid_result = esum_data["result"].get(uid, {})

                    germ_desc = (
                        cur_uid_result
                        .get("germline_classification", {})
                        .get("description", "")
                        .strip()
                    )
                    if germ_desc not in ALLOWED_GERMLINE:
                        continue

                    p_lp_mutation_counter += 1

                    mcons = cur_uid_result.get("molecular_consequence_list", [])
                    mcons_text = " ".join(
                        (mc.get("type", "") if isinstance(mc, dict) else str(mc))
                        for mc in mcons
                    ).lower()

                    if "missense" in mcons_text:
                        mis_plp_mutation_counter += 1
                    if ("nonsense" in mcons_text) or ("stop_gained" in mcons_text):
                        ns_plp_mutation_counter += 1

                retstart += ESUMMARY_PAGE_SIZE
                time.sleep(0.35)

    # Store in-memory
    counter_list.append(counter)
    gene_list.append(gene)
    mutation_nums.append(p_lp_mutation_counter)
    mis_mutation_nums.append(mis_plp_mutation_counter)
    ns_mutation_nums.append(ns_plp_mutation_counter)

    # Append-only per-gene checkpoint
    append_per_gene_row(counter, gene, p_lp_mutation_counter, mis_plp_mutation_counter, ns_plp_mutation_counter)

    # Update done set
    done_counters.add(counter)

    # Periodic rolling checkpoint
    if counter % CHECKPOINT_EVERY_N_GENES == 0 and counter > 0:
        save_checkpoint(counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums)

    time.sleep(0.35)

# Final rolling checkpoint
save_checkpoint(counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums)

print("Done. Final checkpoints written:")
print(f"  Per-gene:  {PER_GENE_CSV}")
print(f"  Rolling:   {ROLLING_CSV}")
# Out:
# Resuming from checkpoint: 593 genes already completed.
# Last completed counter: 592
# Done. Final checkpoints written:
#   Per-gene:  /Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/per_gene_checkpoint.csv
#   Rolling:   /Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/rolling_checkpoint.csv

# %%
# merge with existing data
mutation_df = pd.DataFrame({
    'hgnc_symbol':gene_list,
    'dominant_plp_mutations':mutation_nums,
    'dominant_mis_plp_mutations':mis_mutation_nums,
    'dominant_ns_plp_mutations':ns_mutation_nums
})
mutation_df
# Out:
#     hgnc_symbol  dominant_plp_mutations  dominant_mis_plp_mutations  \
# 0         AARS1                       4                           2
# 1         ABCB6                       2                           1
# 2         ABCC6                       1                           0
# 3         ABCC8                      10                           7
# 4         ABCC9                       6                           6
# ..          ...                     ...                         ...
# 588        ZIC1                       0                           0
# 589       ZMIZ1                       4                           1
# 590      ZMYND8                       1                           0
# 591      ZNF292                      23                           1
# 592      ZSWIM6                       2                           0
#
#      dominant_ns_plp_mutations
# 0                            0
# 1                            0
# 2                            1
# 3                            0
# 4                            0
# ..                         ...
# 588                          0
# 589                          2
# 590                          0
# 591                          9
# 592                          1
#
# [593 rows x 4 columns]

# %%
merged_df = data.merge(mutation_df,on='hgnc_symbol',how='left')
merged_df
# Out:
#     hgnc_symbol GENE ID (HGNC)  \
# 0         AARS1        HGNC:20
# 1         AARS1        HGNC:20
# 2         ABCB6        HGNC:47
# 3         ABCB6        HGNC:47
# 4         ABCC6        HGNC:57
# ..          ...            ...
# 850        ZIC1     HGNC:12872
# 851       ZMIZ1     HGNC:16493
# 852      ZMYND8      HGNC:9397
# 853      ZNF292     HGNC:18410
# 854      ZSWIM6     HGNC:29316
#
#                                          Approved name  \
# 0                             alanyl-tRNA synthetase 1
# 1                             alanyl-tRNA synthetase 1
# 2    ATP binding cassette subfamily B member 6 (LAN...
# 3    ATP binding cassette subfamily B member 6 (LAN...
# 4            ATP binding cassette subfamily C member 6
# ..                                                 ...
# 850                           Zic family zinc finger 1
# 851                  zinc finger MIZ-type containing 1
# 852                 zinc finger MYND-type containing 8
# 853                            zinc finger protein 292
# 854                 zinc finger SWIM-type containing 6
#
#                                      DISEASE LABEL DISEASE ID (MONDO) MOI  \
# 0       Charcot-Marie-Tooth disease axonal type 2N      MONDO:0013212  AD
# 1                AARS1-related leukoencephalopathy      MONDO:1010132  AD
# 2        microphthalmia, isolated, with coloboma 7      MONDO:0013783  AD
# 3         dyschromatosis universalis hereditaria 3      MONDO:0014169  AD
# 4               inherited pseudoxanthoma elasticum      MONDO:0100091  SD
# ..                                             ...                ...  ..
# 850                             craniosynostosis 6      MONDO:0014705  AD
# 851            complex neurodevelopmental disorder      MONDO:0100038  AD
# 852  syndromic complex neurodevelopmental disorder      MONDO:0800439  AD
# 853            complex neurodevelopmental disorder      MONDO:0100038  AD
# 854               acromelic frontonasal dysostosis      MONDO:0011359  AD
#
#     CLASSIFICATION        HI Score           %HI  pLI  ...  \
# 0       Definitive      NoEvidence         24.74    0  ...
# 1          Limited      NoEvidence         24.74    0  ...
# 2          Limited    NoneReported  NoneReported  0.0  ...
# 3         Moderate    NoneReported  NoneReported  0.0  ...
# 4       Definitive    NoneReported  NoneReported  0.0  ...
# ..             ...             ...           ...  ...  ...
# 850     Definitive      NoEvidence          7.94    1  ...
# 851     Definitive    NoneReported  NoneReported    1  ...
# 852         Strong    NoneReported  NoneReported    1  ...
# 853     Definitive  LittleEvidence         26.56    1  ...
# 854     Definitive    NoneReported  NoneReported    1  ...
#
#     num_hets_targeted_four_guides_base_edits  \
# 0                                      497.0
# 1                                      497.0
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 850                                      NaN
# 851                                   1168.0
# 852                                      NaN
# 853                                      NaN
# 854                                      NaN
#
#      num_hets_targeted_four_guides_excision  \
# 0                                    1076.0
# 1                                    1076.0
# 2                                       NaN
# 3                                       NaN
# 4                                     552.0
# ..                                      ...
# 850                                     NaN
# 851                                  1206.0
# 852                                   329.0
# 853                                  1200.0
# 854                                  1134.0
#
#      prop_hets_targeted_four_guides_indels  \
# 0                                 0.483124
# 1                                 0.483124
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 850                                    NaN
# 851                               0.459184
# 852                                    NaN
# 853                                    NaN
# 854                                    NaN
#
#      prop_hets_targeted_four_guides_crisproff  \
# 0                                    0.466248
# 1                                    0.466248
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 850                                       NaN
# 851                                  0.503140
# 852                                       NaN
# 853                                       NaN
# 854                                  0.180534
#
#     prop_hets_targeted_four_guides_base_edits  \
# 0                                    0.195055
# 1                                    0.195055
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 850                                       NaN
# 851                                  0.458399
# 852                                       NaN
# 853                                       NaN
# 854                                       NaN
#
#     prop_hets_targeted_four_guides_excision  Gene Group  \
# 0                                  0.422292         NaN
# 1                                  0.422292         NaN
# 2                                       NaN         NaN
# 3                                       NaN         NaN
# 4                                  0.216641         NaN
# ..                                      ...         ...
# 850                                     NaN         NaN
# 851                                0.473312         NaN
# 852                                0.129121         NaN
# 853                                0.470958         NaN
# 854                                0.445055         NaN
#
#      dominant_plp_mutations  dominant_mis_plp_mutations  \
# 0                         4                           2
# 1                         4                           2
# 2                         2                           1
# 3                         2                           1
# 4                         1                           0
# ..                      ...                         ...
# 850                       0                           0
# 851                       4                           1
# 852                       1                           0
# 853                      23                           1
# 854                       2                           0
#
#      dominant_ns_plp_mutations
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            1
# ..                         ...
# 850                          0
# 851                          2
# 852                          0
# 853                          9
# 854                          1
#
# [855 rows x 58 columns]

# %%
merged_df.to_csv('/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/master_dataframe/dnd_593_2025_12_23_w_dplp_muts.csv')

# %% [markdown]
# ## let's plot the information for the new dominant-only variants versus for the non-specific pathogenic/likely pathogenic variants

# %%
merged_df.columns
# Out:
# Index(['hgnc_symbol', 'GENE ID (HGNC)', 'Approved name', 'DISEASE LABEL',
#        'DISEASE ID (MONDO)', 'MOI', 'CLASSIFICATION', 'HI Score', '%HI', 'pLI',
#        'LOEUF', 'total_plp', 'missense_plp', 'nonsense_plp', 'ensg', 'chrom',
#        's_het', 's_het_lower_CI', 's_het_upper_CI',
#        'indel_targetable_pre_NMD_assessment',
#        'num_indel_vars_pre_NMD_assessment',
#        'num_indel_amenable_vars_inducing_NMD',
#        'num_indel_amenable_vars_escaping_NMD',
#        'indel_targetable_post_NMD_assessment', 'crisproff_targetable',
#        'num_crisproff_vars', 'base_editable', 'num_base_editable_vars',
#        'excision_targetable', 'num_excision_vars', 'num_excision_pairs',
#        'HPO_term_list', 'indel_pam_targetable', 'crisproff_pam_targetable',
#        'base_edit_pam_targetable', 'excision_pam_targetable',
#        'hets_across_strats', 'prop_hets_across_strats', 'num_indel_hets',
#        'indel_hets_prop', 'num_crisproff_hets', 'crisproff_hets_prop',
#        'num_base_edit_hets', 'base_edit_hets_prop', 'num_excision_hets',
#        'excision_hets_prop', 'num_hets_targeted_four_guides_indels',
#        'num_hets_targeted_four_guides_crisproff',
#        'num_hets_targeted_four_guides_base_edits',
#        'num_hets_targeted_four_guides_excision',
#        'prop_hets_targeted_four_guides_indels',
#        'prop_hets_targeted_four_guides_crisproff',
#        'prop_hets_targeted_four_guides_base_edits',
#        'prop_hets_targeted_four_guides_excision', 'Gene Group',
#        'dominant_plp_mutations', 'dominant_mis_plp_mutations',
#        'dominant_ns_plp_mutations'],
#       dtype='object')

# %%
df = merged_df[['hgnc_symbol','s_het','total_plp','missense_plp','nonsense_plp',
                'dominant_plp_mutations','dominant_mis_plp_mutations','dominant_ns_plp_mutations']].drop_duplicates()
df
# Out:
#     hgnc_symbol     s_het  total_plp  missense_plp  nonsense_plp  \
# 0         AARS1  0.022459         87            16            25
# 2         ABCB6  0.000834          9             7             0
# 4         ABCC6  0.000681        317            96            62
# 5         ABCC8  0.008893        439           135            96
# 7         ABCC9  0.020637         76            25            13
# ..          ...       ...        ...           ...           ...
# 850        ZIC1  0.205882         13             5             6
# 851       ZMIZ1  0.209067         53             8             9
# 852      ZMYND8  0.254357          4             1             1
# 853      ZNF292  0.217299         95             3            34
# 854      ZSWIM6  0.260329          4             2             1
#
#      dominant_plp_mutations  dominant_mis_plp_mutations  \
# 0                         4                           2
# 2                         2                           1
# 4                         1                           0
# 5                        10                           7
# 7                         6                           6
# ..                      ...                         ...
# 850                       0                           0
# 851                       4                           1
# 852                       1                           0
# 853                      23                           1
# 854                       2                           0
#
#      dominant_ns_plp_mutations
# 0                            0
# 2                            0
# 4                            1
# 5                            0
# 7                            0
# ..                         ...
# 850                          0
# 851                          2
# 852                          0
# 853                          9
# 854                          1
#
# [593 rows x 8 columns]

# %%
# increase dpi of fig
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
# plot each category of all mutations vs dominant mutations
cols = [
    "total_plp",
    "dominant_plp_mutations",
    "missense_plp",
    "dominant_mis_plp_mutations",
    "nonsense_plp",
    "dominant_ns_plp_mutations"
]

plot_data = [df[col].values for col in cols]
fig, ax = plt.subplots(figsize=(10, 5))

vp = ax.violinplot(
    plot_data,
    showmeans=False,
    showmedians=True,
    showextrema=True
)

# bp = ax.boxplot(
#     plot_data
#     # showmeans=False,
#     # showmedians=True,
#     # showextrema=True
# )

ax.set_xticks(np.arange(1, len(cols) + 1))
ax.set_xticklabels(cols, rotation=30, ha="right")

for i, col in enumerate(cols, start=1):
    y = df[col].values
    x = np.random.normal(i, 0.04, size=len(y))  # jitter
    ax.scatter(x, y, s=10, alpha=0.6, color="black")
#ax.set_yscale("log")
ax.set_ylabel("Pathogenic variant count per gene")

# for body in vp["bodies"]:
#     body.set_alpha(0.7)

plt.tight_layout()
plt.show()

# %%
# try grouping the violins
groups = {
    "Overall Pathogenic Mutations": ["total_plp", "dominant_plp_mutations"],
    "Missense Pathogenic Mutations": ["missense_plp", "dominant_mis_plp_mutations"],
    "Nonsense Pathogenic Mutations": ["nonsense_plp", "dominant_ns_plp_mutations"],
}

group_spacing = 1.8   # distance between groups
within_spacing = 0.4 # distance within group

plot_data = []
positions = []
labels = []

pos = 1
for group_name, cols in groups.items():
    for i, col in enumerate(cols):
        plot_data.append(df[col].values)
        positions.append(pos + i * within_spacing)
        labels.append(col)
    pos += group_spacing

fig, ax = plt.subplots(figsize=(10, 5))

jitter_width = 0.05  # controls horizontal spread

for x0, y in zip(positions, plot_data):
    x = np.random.normal(loc=x0, scale=jitter_width, size=len(y))
    ax.scatter(
        x,
        y,
        s=12,
        alpha=0.2,
        color="grey",
        zorder=3
    )

vp = ax.violinplot(
    plot_data,
    positions=positions,
    widths=0.35,
    showmedians=True,
)


group_centers = []
pos = 1
for _ in groups:
    group_centers.append(pos + within_spacing / 2)
    pos += group_spacing

ax.set_xticks(group_centers)
ax.set_xticklabels(groups.keys())

for x, label in zip(positions, labels):
    ax.text(x, ax.get_ylim()[0], label.replace("_", "\n"),
            ha="center", va="top", fontsize=8, rotation=0)

ax.set_xticks(group_centers)
ax.set_xticklabels([])  # remove default labels

for x, group in zip(group_centers, groups.keys()):
    ax.text(
        x,
        -0.12,
        group,
        ha="center",
        va="top",
        transform=ax.get_xaxis_transform(),
        fontsize=10
    )


plt.tight_layout()
plt.show()

# %%
# -----------------------------
# Define grouped violins
# -----------------------------
groups = {
    "Overall Pathogenic\nMutations": ["total_plp", "dominant_plp_mutations"],
    "Missense Pathogenic\nMutations": ["missense_plp", "dominant_mis_plp_mutations"],
    "Nonsense Pathogenic\nMutations": ["nonsense_plp", "dominant_ns_plp_mutations"],
}

group_spacing = 1.8
within_spacing = 0.4
violin_width = 0.35
jitter_width = violin_width / 4

plot_data = []
positions = []

pos = 1
for cols in groups.values():
    for i, col in enumerate(cols):
        y = df[col].values
        y = y[y > 0]          # remove zeros for log scale
        plot_data.append(y)
        positions.append(pos + i * within_spacing)
    pos += group_spacing

# -----------------------------
# Create figure
# -----------------------------
fig, ax = plt.subplots(figsize=(10, 5))

# -----------------------------
# JITTERS (draw FIRST, behind)
# -----------------------------
for x0, y in zip(positions, plot_data):
    x = np.random.normal(loc=x0, scale=jitter_width, size=len(y))
    ax.scatter(
        x,
        y,
        s=10,
        alpha=0.2,
        color="grey",
        zorder=1
    )

# -----------------------------
# VIOLINS (draw after jitters)
# -----------------------------
vp = ax.violinplot(
    plot_data,
    positions=positions,
    widths=violin_width,
    showmedians=True,
)

# Make violin outlines black
for body in vp["bodies"]:
    body.set_edgecolor("black")
    body.set_linewidth(1.2)
    body.set_alpha(0.6)

# Make median and bar lines black
if "cmedians" in vp:
    vp["cmedians"].set_color("black")
    vp["cmedians"].set_linewidth(1.5)

for key in ("cbars", "cmins", "cmaxes"):
    if key in vp:
        vp[key].set_color("black")
        vp[key].set_linewidth(1.2)

# for body in vp["bodies"]:
#     body.set_alpha(0.9)
#     body.set_zorder(2)

# vp["cmedians"].set_zorder(3)

# -----------------------------
# Group labels
# -----------------------------
group_centers = []
pos = 1
for _ in groups:
    group_centers.append(pos + within_spacing / 2)
    pos += group_spacing

ax.set_xticks(group_centers)
ax.set_xticklabels([])

for x, label in zip(group_centers, groups.keys()):
    ax.text(
        x,
        -0.07,
        label,
        ha="center",
        va="top",
        transform=ax.get_xaxis_transform(),
        fontsize=11
    )

# -----------------------------
# Small x axis violin labels
# -----------------------------
new_labels=['All','Dominant','All','Dominant','All','Dominant']
for x, label in zip(positions, new_labels):
    ax.text(
        x,
        -100, #ax.get_ylim()[0],   # start at bottom of y-axis
        label.replace("_", "\n"),
        ha="center",
        va="top",
        fontsize=8,
        rotation=0
    )

# -----------------------------
# Extra text formatting
# -----------------------------
ax.text(
    0.98, 0.98,
    "N = 593 D&D \nGroup 1 Genes",
    transform=ax.transAxes,
    ha="right",
    va="top",
    fontsize=10
)

# -----------------------------
# Axis formatting
# -----------------------------
#ax.set_yscale("log")
ax.set_ylabel("Pathogenic mutation count per gene")
ax.tick_params(axis="x", length=0)

#ax.tick_params(axis="x", length=0)
#ax.spines["bottom"].set_visible(False)

# ---------------------------
# Final showing and saving
# ---------------------------
savedir="/Users/graceramey/Library/CloudStorage/Box-Box/capra_lab/projects/dominant_negative_disease_editing/figures/jupyter_notebook_savefigs"
plt.savefig(savedir + "/PLP_all_and_dominant.svg", format='svg', bbox_inches='tight',transparent=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Hmmm, the dominant numbers get quite small here.
# That's not because they are, it's just the dominant annotations are lacking in ClinVar, so the real number is probably somewhere between the 'All' and 'Dominant' groups.
# ### Since later on in the paper we focus on 4 gRNAs as a reasonably feasible therapeutic goal, let's look at the percentage of genes that have more than 4 dominant mutations

# %%
df[df['dominant_plp_mutations']>4]
# Out:
#     hgnc_symbol     s_het  total_plp  missense_plp  nonsense_plp  \
# 5         ABCC8  0.008893        439           135            96
# 7         ABCC9  0.020637         76            25            13
# 10         ACAN  0.104639        195            13            65
# 17        ACTA1  0.008776        225           185            12
# 19        ACTA2  0.131379         29            25             0
# ..          ...       ...        ...           ...           ...
# 839        WFS1  0.001000        227            82            60
# 842      WNT10A  0.001348        113            28            32
# 847         YY1  0.523540         44            27             3
# 848      ZBTB20  0.138367         85            58             6
# 853      ZNF292  0.217299         95             3            34
#
#      dominant_plp_mutations  dominant_mis_plp_mutations  \
# 5                        10                           7
# 7                         6                           6
# 10                       10                           0
# 17                       32                          31
# 19                        9                           8
# ..                      ...                         ...
# 839                      11                           9
# 842                       5                           3
# 847                      14                           8
# 848                      10                           5
# 853                      23                           1
#
#      dominant_ns_plp_mutations
# 5                            0
# 7                            0
# 10                           2
# 17                           0
# 19                           0
# ..                         ...
# 839                          1
# 842                          2
# 847                          1
# 848                          1
# 853                          9
#
# [208 rows x 8 columns]

# %%
## Okay, looks like ~200 genes have more than 4 dominant mutations in them
208/593
# Out:
# 0.35075885328836426

# %% [markdown]
# ## Hmmm, I need to think about this a bit more, and what's the best way to show this

# %%
# let's plot just the dominant data
cols = [
    "dominant_plp_mutations",
    "dominant_mis_plp_mutations",
    "dominant_ns_plp_mutations"
]

plot_data = [df[col].values for col in cols]
fig, ax = plt.subplots(figsize=(7, 7))

vp = ax.violinplot(
    plot_data,
    showmeans=False,
    showmedians=True,
    showextrema=True
)

# bp = ax.boxplot(
#     plot_data
#     # showmeans=False,
#     # showmedians=True,
#     # showextrema=True
# )

ax.set_xticks(np.arange(1, len(cols) + 1))
ax.set_xticklabels(['All Dominant\nPathogenic Mutations','Dominant Missense\nPathogenic Mutations','Dominant Nonsense\nPathogenic Mutations'], 
                   rotation=0)

for i, col in enumerate(cols, start=1):
    y = df[col].values
    x = np.random.normal(i, 0.04, size=len(y))  # jitter
    ax.scatter(x, y, s=10, alpha=0.6, color="black")
#ax.set_yscale("log")
ax.set_ylabel("Pathogenic mutation count per gene", fontsize=12)

ax.text(
    0.98, 0.98,
    "N = 593 D&D \nGroup 1 Genes",
    transform=ax.transAxes,
    ha="right",
    va="top",
    fontsize=10
)

# for body in vp["bodies"]:
#     body.set_alpha(0.7)

plt.tight_layout()
plt.show()

# %%
labels
# Out:
# ['total_plp',
#  'dominant_plp_mutations',
#  'missense_plp',
#  'dominant_mis_plp_mutations',
#  'nonsense_plp',
#  'dominant_ns_plp_mutations']

# %%
# let's plot just the dominant data
cols = [
    "dominant_plp_mutations",
    "dominant_mis_plp_mutations",
    "dominant_ns_plp_mutations"
]

plot_data = [df[col].values for col in cols]
fig, ax = plt.subplots(figsize=(7, 7))

vp = ax.violinplot(
    plot_data,
    showmeans=False,
    showmedians=True,
    showextrema=True
)

# bp = ax.boxplot(
#     plot_data
#     # showmeans=False,
#     # showmedians=True,
#     # showextrema=True
# )

ax.set_xticks(np.arange(1, len(cols) + 1))
ax.set_xticklabels(['All Dominant\nPathogenic Mutations','Dominant Missense\nPathogenic Mutations','Dominant Nonsense\nPathogenic Mutations'], 
                   rotation=0)

for i, col in enumerate(cols, start=1):
    y = df[col].values
    x = np.random.normal(i, 0.04, size=len(y))  # jitter
    ax.scatter(x, y, s=10, alpha=0.6, color="black")
#ax.set_yscale("log")
ax.set_ylabel("Pathogenic mutation count per gene", fontsize=12)

ax.text(
    0.98, 0.98,
    "N = 593 D&D \nGroup 1 Genes",
    transform=ax.transAxes,
    ha="right",
    va="top",
    fontsize=10
)

# for body in vp["bodies"]:
#     body.set_alpha(0.7)

plt.tight_layout()
plt.show()

# %%
# get the median of each of the dominant mutation categories
df[['dominant_plp_mutations','dominant_mis_plp_mutations','dominant_ns_plp_mutations']].median(axis=0)
# Out:
# dominant_plp_mutations        2.0
# dominant_mis_plp_mutations    1.0
# dominant_ns_plp_mutations     0.0
# dtype: float64

# %%
# get the median of each of the dominant mutation categories
df[['dominant_plp_mutations','dominant_mis_plp_mutations','dominant_ns_plp_mutations']].mean(axis=0)
# Out:
# dominant_plp_mutations        5.890388
# dominant_mis_plp_mutations    3.775717
# dominant_ns_plp_mutations     0.647555
# dtype: float64

# %% [markdown]
# # Let's also take a look at gene length versus the number of mutations

# %%
# load file that contains gene length information
exon_df = pd.read_csv('/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/RUN_12_19_2025/filtered_exon_info.csv',
                      dtype={'chromosome_name':'str'},index_col=0)
exon_df
# Out:
#         ensembl_gene_id ensembl_transcript_id hgnc_symbol chromosome_name  \
# 1       ENSG00000000971       ENST00000359637         CFH               1
# 2       ENSG00000000971       ENST00000359637         CFH               1
# 3       ENSG00000000971       ENST00000359637         CFH               1
# 4       ENSG00000000971       ENST00000359637         CFH               1
# 5       ENSG00000000971       ENST00000359637         CFH               1
# ...                 ...                   ...         ...             ...
# 188861  ENSG00000277258       ENST00000620225       PCGF2              17
# 189017  ENSG00000277586       ENST00000610854        NEFL               8
# 189018  ENSG00000277586       ENST00000610854        NEFL               8
# 189019  ENSG00000277586       ENST00000610854        NEFL               8
# 189020  ENSG00000277586       ENST00000610854        NEFL               8
#
#         start_position  end_position  strand  transcript_start  \
# 1            196651754     196752476       1         196651754
# 2            196651754     196752476       1         196651754
# 3            196651754     196752476       1         196651754
# 4            196651754     196752476       1         196651754
# 5            196651754     196752476       1         196651754
# ...                ...           ...     ...               ...
# 188861        38733894      38752555      -1          38733898
# 189017        24950955      24956721      -1          24950955
# 189018        24950955      24956721      -1          24950955
# 189019        24950955      24956721      -1          24950955
# 189020        24950955      24956721      -1          24950955
#
#         transcript_end  transcription_start_site  ...  ensembl_peptide_id  \
# 1            196701565                 196651754  ...     ENSP00000352658
# 2            196701565                 196651754  ...     ENSP00000352658
# 3            196701565                 196651754  ...     ENSP00000352658
# 4            196701565                 196651754  ...     ENSP00000352658
# 5            196701565                 196651754  ...     ENSP00000352658
# ...                ...                       ...  ...                 ...
# 188861        38748336                  38748336  ...     ENSP00000482815
# 189017        24956612                  24956612  ...     ENSP00000482169
# 189018        24956612                  24956612  ...     ENSP00000482169
# 189019        24956612                  24956612  ...     ENSP00000482169
# 189020        24956612                  24956612  ...     ENSP00000482169
#
#         exon_chrom_start exon_chrom_end  ensembl_exon_id is_constitutive rank  \
# 1              196679623      196679793  ENSE00000791016               0    5
# 2              196675989      196676065  ENSE00003965712               0    4
# 3              196651754      196652175  ENSE00003965676               0    1
# 4              196672978      196673163  ENSE00001134426               0    2
# 5              196690063      196690239  ENSE00003623048               0    8
# ...                  ...            ...              ...             ...  ...
# 188861          38736090       38736170  ENSE00003895038               0   10
# 189017          24954181       24954305  ENSE00003713115               0    2
# 189018          24955472       24956612  ENSE00003746083               0    1
# 189019          24953476       24953795  ENSE00003730059               0    3
# 189020          24950955       24952952  ENSE00003731174               0    4
#
#         genomic_coding_start  genomic_coding_end cds_start  cds_end
# 1                196679623.0         196679793.0     428.0    598.0
# 2                196675989.0         196676065.0     351.0    427.0
# 3                196652118.0         196652175.0       1.0     58.0
# 4                196672978.0         196673163.0      59.0    244.0
# 5                196690063.0         196690239.0     968.0   1144.0
# ...                      ...                 ...       ...      ...
# 188861            38736090.0          38736170.0     577.0    657.0
# 189017            24954181.0          24954305.0    1045.0   1169.0
# 189018            24955472.0          24956515.0       1.0   1044.0
# 189019            24953476.0          24953795.0    1170.0   1489.0
# 189020            24952810.0          24952952.0    1490.0   1632.0
#
# [34897 rows x 25 columns]

# %%
gl = df.merge(exon_df[['hgnc_symbol','start_position','end_position']].drop_duplicates(), on='hgnc_symbol',how='left')
gl['gene_length']=gl['end_position']-gl['start_position']
gl
# Out:
#     hgnc_symbol     s_het  total_plp  missense_plp  nonsense_plp  \
# 0         AARS1  0.022459         87            16            25
# 1         ABCB6  0.000834          9             7             0
# 2         ABCC6  0.000681        317            96            62
# 3         ABCC8  0.008893        439           135            96
# 4         ABCC9  0.020637         76            25            13
# ..          ...       ...        ...           ...           ...
# 588        ZIC1  0.205882         13             5             6
# 589       ZMIZ1  0.209067         53             8             9
# 590      ZMYND8  0.254357          4             1             1
# 591      ZNF292  0.217299         95             3            34
# 592      ZSWIM6  0.260329          4             2             1
#
#      dominant_plp_mutations  dominant_mis_plp_mutations  \
# 0                         4                           2
# 1                         2                           1
# 2                         1                           0
# 3                        10                           7
# 4                         6                           6
# ..                      ...                         ...
# 588                       0                           0
# 589                       4                           1
# 590                       1                           0
# 591                      23                           1
# 592                       2                           0
#
#      dominant_ns_plp_mutations  start_position  end_position  gene_length
# 0                            0        70251983      70289707        37724
# 1                            0       219209766     219219012         9246
# 2                            1        16149565      16223637        74072
# 3                            0        17392498      17476894        84396
# 4                            0        21797389      21942543       145154
# ..                         ...             ...           ...          ...
# 588                          0       147393422     147510293       116871
# 589                          2        79068929      79316550       247621
# 590                          0        47209214      47357804       148590
# 591                          9        87151803      87265943       114140
# 592                          1        61332258      61546172       213914
#
# [593 rows x 11 columns]

# %%
# plot the relationship between gene length and number of pathogenic mutations
plt.scatter(gl['gene_length'],gl['total_plp'], color='black', alpha=0.5,label='N = 593 D&D Group 1 Genes')
plt.legend()
plt.xlabel('Gene Length (bp)')
plt.ylabel('Total pathogenic mutations')
plt.show()

# %%
# now plot versus just the dominant mutations
plt.scatter(gl['gene_length'],gl['dominant_plp_mutations'], color='black', alpha=0.5)
plt.xlabel('Gene Length (bp)')
plt.ylabel('Total dominant pathogenic mutations')
plt.show()

# %%
# is the relationhsip more clear for s_het genes?
df_filt = df[df['s_het']<0.1]
gl = df_filt.merge(exon_df[['hgnc_symbol','start_position','end_position']].drop_duplicates(), on='hgnc_symbol',how='left')
gl['gene_length']=gl['end_position']-gl['start_position']

# %%
# plot the relationship between gene length and number of pathogenic mutations
plt.scatter(gl['gene_length'],gl['total_plp'], color='black', alpha=0.5)
plt.xlabel('Gene Length (bp)')
plt.ylabel('Total pathogenic mutations')
plt.show()

# %%
# now plot versus just the dominant mutations
plt.scatter(gl['gene_length'],gl['dominant_plp_mutations'], color='black', alpha=0.5)
plt.xlabel('Gene Length (bp)')
plt.ylabel('Total dominant pathogenic mutations')
plt.show()

# %% [markdown]
# # Now let's see if we can get more accurate dominant pathogenic mutation prevalence by overlapping the names of the linked dominant diseases in ClinGen with the names in ClinVar

# %%
## install fuzzywuzzy and python-Levenshtein packages for string matching
#!pip install fuzzywuzzy python-Levenshtein
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting python-Levenshtein
#   Downloading python_levenshtein-0.27.3-py3-none-any.whl (9.5 kB)
# Collecting Levenshtein==0.27.3 (from python-Levenshtein)
#   Downloading levenshtein-0.27.3-cp311-cp311-macosx_11_0_arm64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.6/158.6 kB 3.2 MB/s eta 0:00:004.3 MB/s eta 0:00:01
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.3->python-Levenshtein)
#   Downloading rapidfuzz-3.14.3-cp311-cp311-macosx_11_0_arm64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.5 MB/s eta 0:00:000m eta 0:00:010:01
# Installing collected packages: fuzzywuzzy, rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.27.3 fuzzywuzzy-0.18.0 python-Levenshtein-0.27.3 rapidfuzz-3.14.3

# %%
# load some packages that will help with fuzzy string matching
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
# load disease names from original file
data_ad = data[data['MOI'].isin(['AD','SD'])]
dis = data_ad[['hgnc_symbol','DISEASE LABEL','DISEASE ID (MONDO)']]
dis
# Out:
#     hgnc_symbol                                  DISEASE LABEL  \
# 0         AARS1     Charcot-Marie-Tooth disease axonal type 2N
# 1         AARS1              AARS1-related leukoencephalopathy
# 2         ABCB6      microphthalmia, isolated, with coloboma 7
# 3         ABCB6       dyschromatosis universalis hereditaria 3
# 4         ABCC6             inherited pseudoxanthoma elasticum
# ..          ...                                            ...
# 850        ZIC1                             craniosynostosis 6
# 851       ZMIZ1            complex neurodevelopmental disorder
# 852      ZMYND8  syndromic complex neurodevelopmental disorder
# 853      ZNF292            complex neurodevelopmental disorder
# 854      ZSWIM6               acromelic frontonasal dysostosis
#
#     DISEASE ID (MONDO)
# 0        MONDO:0013212
# 1        MONDO:1010132
# 2        MONDO:0013783
# 3        MONDO:0014169
# 4        MONDO:0100091
# ..                 ...
# 850      MONDO:0014705
# 851      MONDO:0100038
# 852      MONDO:0800439
# 853      MONDO:0100038
# 854      MONDO:0011359
#
# [737 rows x 3 columns]

# %% [markdown]
# # Currently working on this setup

# %%
# set up the ClinVar query below, including string matching

# =========================
# SETUP QUERY LINKS
# =========================
base_esearch = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
base_epost  = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/epost.fcgi"
base_esummary = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi"

record_list = []
mutation_nums = []
mis_mutation_nums = []
ns_mutation_nums = []
counter_list = []
dom_ids_list=[]

session = requests.Session()  # reuse connections

# =========================
# CHECKPOINT CONFIG
# =========================
CHECKPOINT_DIR = "/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints"
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

CHECKPOINT_EVERY_N_GENES = 10  # hard checkpoint interval

PER_GENE_CSV = os.path.join(CHECKPOINT_DIR, "per_gene_checkpoint_dis_matching.csv")
ROLLING_CSV  = os.path.join(CHECKPOINT_DIR, "rolling_checkpoint_dis_matching.csv")

# =========================
# ClinVar JSON max
# =========================
ESUMMARY_PAGE_SIZE = 500

ALLOWED_GERMLINE = {
    "Pathogenic",
    "Likely pathogenic",
    "Pathogenic/Likely pathogenic",
}

# =========================
# HELPERS
# =========================
def batched(iterable, n):
    for i in range(0, len(iterable), n):
        yield iterable[i:i + n]


def request_with_429_retry(
    method,
    url,
    *,
    params=None,
    data=None,
    timeout=60,
    sleep_on_429=1.0,
    max_tries=10,
):
    for _attempt in range(max_tries):
        r = session.request(method, url, params=params, data=data, timeout=timeout)
        if r.status_code != 429:
            r.raise_for_status()
            return r
        print(f"429 from {url.split('/')[-1]} ; sleeping {sleep_on_429}s and retrying…")
        time.sleep(sleep_on_429)
    raise RuntimeError(f"Too many 429s from {url} after {max_tries} tries")


def epost_ids(db, ids):
    r = request_with_429_retry(
        "POST",
        base_epost,
        data={"db": db, "id": ",".join(ids)},
        timeout=60,
    )
    txt = r.text
    webenv = txt.split("<WebEnv>")[1].split("</WebEnv>")[0]
    query_key = txt.split("<QueryKey>")[1].split("</QueryKey>")[0]
    return webenv, query_key


def esummary_from_history(db, webenv, query_key, retstart, retmax):
    params = {
        "db": db,
        "query_key": query_key,
        "WebEnv": webenv,
        "retmode": "json",
        "retstart": retstart,
        "retmax": retmax,
    }
    r = request_with_429_retry("GET", base_esummary, params=params, timeout=60)
    data = r.json()
    if "error" in data:
        raise RuntimeError(f"ClinVar esummary error: {data['error']}")
    return data


def save_checkpoint(counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums, dom_ids_list):
    df = pd.DataFrame({
        "counter": counter_list,
        "gene": gene_list,
        "total_plp": mutation_nums,
        "missense_plp": mis_mutation_nums,
        "nonsense_plp": ns_mutation_nums,
        "dom_ids_list": dom_ids_list
    })
    df.to_csv(ROLLING_CSV, index=False)


def append_per_gene_row(counter, gene, total_plp, mis_plp, ns_plp, dom_ids_list):
    row = pd.DataFrame([{
        "counter": counter,
        "gene": gene,
        "total_plp": total_plp,
        "missense_plp": mis_plp,
        "nonsense_plp": ns_plp,
        "dom_ids_list": dom_ids_list
    }])
    header = not os.path.exists(PER_GENE_CSV)
    row.to_csv(PER_GENE_CSV, mode="a", header=header, index=False)


def load_checkpoint():
    """
    Returns:
      done_counters: set[int]
      counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums, dom_ids_list: lists
    """
    if not os.path.exists(PER_GENE_CSV):
        return set(), [], [], [], [], [], []

    df = pd.read_csv(PER_GENE_CSV)

    # Normalize / guard
    if df.empty:
        return set(), [], [], [], [], [], []

    # If you re-ran and appended duplicates, keep the last occurrence per counter.
    df = df.sort_values("counter").drop_duplicates(subset=["counter"], keep="last")

    done_counters = set(df["counter"].astype(int).tolist())

    counter_list = df["counter"].astype(int).tolist()
    gene_list = df["gene"].astype(str).tolist()
    mutation_nums = df["total_plp"].astype(int).tolist()
    mis_mutation_nums = df["missense_plp"].astype(int).tolist()
    ns_mutation_nums = df["nonsense_plp"].astype(int).tolist()
    dom_ids_list=[literal_eval(x) for x in df["dom_ids_list"]]

    return done_counters, counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums, dom_ids_list


# =========================
# RESUME STATE
# =========================
done_counters, counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums, dom_ids_list = load_checkpoint()

if done_counters:
    print(f"Resuming from checkpoint: {len(done_counters)} genes already completed.")
    print(f"Last completed counter: {max(done_counters)}")
else:
    print("No checkpoint found. Starting fresh.")

# =========================
# MAIN LOOP (RESUMABLE)
# =========================
for counter, gene in enumerate(gene_df["hgnc_symbol"]):
    if counter in done_counters:
        continue

    print(f"{counter}  {gene}")

    # autosomal dominant-annotated entries (note that many annotations are missing, which we'll deal with below
    term = (
        f'{gene}[gene] AND single_gene[prop] AND "moi autosomal dominant"[prop] AND '
        '(pathogenic[clinsig] OR "likely pathogenic"[clinsig] OR "pathogenic/likely pathogenic"[clinsig])'
    )
    
    esearch_params = {"db": "clinvar", "term": term, "retmode": "json", "retmax": 100000}
    r = request_with_429_retry("GET", base_esearch, params=esearch_params, timeout=30)
    esearch_data = r.json()
    
    cur_ids = esearch_data["esearchresult"]["idlist"]
    
    # STRICT aggregate germline P/LP-only counts
    p_lp_mutation_counter = 0
    mis_plp_mutation_counter = 0
    ns_plp_mutation_counter = 0
    dom_ids=[]
    
    if cur_ids:
        for post_batch in batched(cur_ids, 5000):
            webenv, query_key = epost_ids("clinvar", post_batch)
    
            retstart = 0
            while retstart < len(post_batch):
                esum_data = esummary_from_history(
                    "clinvar",
                    webenv,
                    query_key,
                    retstart=retstart,
                    retmax=ESUMMARY_PAGE_SIZE,
                )
                #print(len(esum_data.get("result", {}).get("uids", [])))
                for uid in esum_data.get("result", {}).get("uids", []):
                    dom_ids.append(uid)
                    cur_uid_result = esum_data["result"].get(uid, {})
    
                    germ_desc = (
                        cur_uid_result
                        .get("germline_classification", {})
                        .get("description", "")
                        .strip()
                    )
                    if germ_desc not in ALLOWED_GERMLINE:
                        continue
    
                    p_lp_mutation_counter += 1
    
                    mcons = cur_uid_result.get("molecular_consequence_list", [])
                    mcons_text = " ".join(
                        (mc.get("type", "") if isinstance(mc, dict) else str(mc))
                        for mc in mcons
                    ).lower()
    
                    if "missense" in mcons_text:
                        mis_plp_mutation_counter += 1
                    if ("nonsense" in mcons_text) or ("stop_gained" in mcons_text):
                        ns_plp_mutation_counter += 1
    
                retstart += ESUMMARY_PAGE_SIZE
                time.sleep(0.35)
    
    # Store in-memory
    counter_list.append(counter)
    gene_list.append(gene)
    mutation_nums.append(p_lp_mutation_counter)
    mis_mutation_nums.append(mis_plp_mutation_counter)
    ns_mutation_nums.append(ns_plp_mutation_counter)
    dom_ids_list.append(dom_ids)

    # Append-only per-gene checkpoint
    append_per_gene_row(counter, gene, p_lp_mutation_counter, mis_plp_mutation_counter, ns_plp_mutation_counter, dom_ids_list)

    # Update done set
    done_counters.add(counter)

    # Periodic rolling checkpoint
    if counter % CHECKPOINT_EVERY_N_GENES == 0 and counter > 0:
        save_checkpoint(counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums, dom_ids_list)

    time.sleep(0.35)

# Final rolling checkpoint
save_checkpoint(counter_list, gene_list, mutation_nums, mis_mutation_nums, ns_mutation_nums, dom_ids_list)

print("Done. Final checkpoints written:")
print(f"  Per-gene:  {PER_GENE_CSV}")
print(f"  Rolling:   {ROLLING_CSV}")
# Out:
# Resuming from checkpoint: 10 genes already completed.
# Last completed counter: 9
# 10  ACTA2
# 11  ACTB
# 12  ACTC1
# 13  ACTG1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 14  ACTL6A
# 15  ACTN1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 16  ACTN2
# 17  ACVR1
# 18  ADAR
# 19  ADCY5
# 20  AFG3L2
# 21  AGO2
# 22  AICDA
# 23  AKT3
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 24  ALB
# 25  ALDH18A1
# 26  ALG5
# 27  ALG8
# 28  ALG9
# 29  ALK
# 30  ALPK3
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 31  ALPL
# 32  ANK1
# 33  ANKRD26
# 34  ANO5
# 35  ANXA11
# 36  AP1G1
# 37  AP2M1
# 38  APP
# 39  ARF1
# 40  ARHGAP29
# 41  ASXL2
# 42  ATL1
# 43  ATL3
# 44  ATP11A
# 45  ATP13A3
# 46  ATP1A1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 47  ATP1A2
# 48  ATP1A3
# 49  ATP2B2
# 50  ATXN2
# 51  BACH2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 52  BCL11B
# 53  BEST1
# 54  BICRA
# 55  BRAF
# 56  BRD4
# 57  BRSK2
# 58  BSCL2
# 59  C19orf12
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 60  C1QTNF5
# 61  C3
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 62  C9orf72
# 63  CACNA1C
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 64  CACNA1D
# 65  CACNA1E
# 66  CACNA1S
# 67  CALM1
# 68  CALM2
# 69  CALM3
# 70  CAMK2A
# 71  CAPN3
# 72  CAPN5
# 73  CARD11
# 74  CASQ2
# 75  CASR
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 76  CAV1
# 77  CAV3
# 78  CBL
# 79  CCM2
# 80  CCND2
# 81  CD164
# 82  CD2AP
# 83  CD46
# 84  CDC42
# 85  CDH11
# 86  CDK4
# 87  CEACAM16
# 88  CEBPA
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 89  CEL
# 90  CEP85L
# 91  CFB
# 92  CFH
# 93  CFI
# 94  CHAMP1
# 95  CHCHD10
# 96  CHD3
# 97  CHD4
# 98  CHMP2B
# 99  CHN1
# 100  CHRNA4
# 101  CHRNB1
# 102  CHRNB2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 103  CITED2
# 104  CLCN6
# 105  CLCN7
# 106  CNNM2
# 107  CNOT3
# 108  COCH
# 109  COL10A1
# 110  COL11A1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 111  COL11A2
# 112  COL1A2
# 113  COL4A3
# 114  COL4A4
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 115  COL5A2
# 116  COL6A1
# 117  COL6A2
# 118  COL6A3
# 119  COMP
# 120  CPOX
# 121  CRX
# 122  CSDE1
# 123  CSNK2A1
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 124  CSNK2B
# 125  CSRP3
# 126  CTLA4
# 127  CTNND1
# 128  CTR9
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 129  CUX2
# 130  CXCR4
# 131  CYFIP2
# 132  DCC
# 133  DCTN1
# 134  DDR2
# 135  DES
# 136  DHX30
# 137  DIAPH1
# 138  DNAJB11
# 139  DNAJB6
# 140  DNAJC5
# 141  DNM1
# 142  DNM1L
# 143  DNM2
# 144  DPF2
# 145  DSC2
# 146  DSPP
# 147  EED
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 148  EEF1A2
# 149  EFEMP1
# 150  EGFR
# 151  EGR2
# 152  EIF2S3
# 153  ELANE
# 154  ELOVL4
# 155  ELP4
# 156  EMC1
# 157  EPCAM
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 158  EPHB4
# 159  ETS1
# 160  EZH2
# 161  F11
# 162  F12
# 163  F2
# 164  F5
# 165  FAM111B
# 166  FAR1
# 167  FBLN5
# 168  FBXO38
# 169  FGA
# 170  FGB
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 171  FGF12
# 172  FGF8
# 173  FGF9
# 174  FGFR2
# 175  FGFR3
# 176  FGG
# 177  FHOD3
# 178  FLI1
# 179  FLT4
# 180  FN1
# 181  FOXA2
# 182  FOXE3
# 183  FOXJ1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 184  FOXN1
# 185  FTH1
# 186  FUS
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 187  FXYD2
# 188  GABBR2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 189  GABRA1
# 190  GABRB2
# 191  GABRB3
# 192  GABRD
# 193  GABRG2
# 194  GANAB
# 195  GARS1
# 196  GBA1
# 197  GDAP1
# 198  GDF2
# 199  GFAP
# 200  GFI1B
# 201  GGCX
# 202  GJB3
# 203  GJB6
# 204  GLUD1
# 205  GLUL
# 206  GMNN
# 207  GNAI1
# 208  GNAO1
# 209  GNAT1
# 210  GNB1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 211  GNB4
# 212  GP1BA
# 213  GREM1
# 214  GRHL2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 215  GRIA1
# 216  GRIA2
# 217  GRIA4
# 218  GRIN1
# 219  GRIN2D
# 220  GRN
# 221  GSDME
# 222  GUCA1A
# 223  GUCY2D
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 224  H1-4
# 225  H3-3A
# 226  H4C5
# 227  HAND1
# 228  HAND2
# 229  HBA1
# 230  HBB
# 231  HCN1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 232  HCN4
# 233  HECW2
# 234  HEPACAM
# 235  HMGA2
# 236  HNRNPA2B1
# 237  HNRNPD
# 238  HNRNPDL
# 239  HNRNPH1
# 240  HNRNPR
# 241  HOMER2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 242  HRAS
# 243  HRG
# 244  HSPB1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 245  HSPB8
# 246  HTT
# 247  IDH2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 248  IFIH1
# 249  IFT140
# 250  IGF2
# 251  IKBKB
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 252  IKZF2
# 253  IKZF3
# 254  IMPDH1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 255  IMPG1
# 256  INF2
# 257  INS
# 258  IRF2BPL
# 259  IRF4
# 260  ISL1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 261  ITGA2B
# 262  ITGB3
# 263  ITPR1
# 264  JAK1
# 265  JPH2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 266  KBTBD13
# 267  KCNA1
# 268  KCNA2
# 269  KCNB1
# 270  KCNC1
# 271  KCNC2
# 272  KCNC3
# 273  KCNH1
# 274  KCNH5
# 275  KCNJ11
# 276  KCNJ2
# 277  KCNJ5
# 278  KCNK3
# 279  KCNK4
# 280  KCNMA1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 281  KCNQ3
# 282  KCNQ4
# 283  KCNT1
# 284  KDF1
# 285  KDM3B
# 286  KDM4B
# 287  KDR
# 288  KIDINS220
# 289  KIF1A
# 290  KIF21A
# 291  KIF5A
# 292  KLF13
# 293  KLHL20
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 294  KRAS
# 295  LITAF
# 296  LMX1A
# 297  LOX
# 298  LRP12
# 299  LRRK2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 300  LRSAM1
# 301  LZTR1
# 302  MAB21L2
# 303  MACF1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 304  MAGEL2
# 305  MAP1B
# 306  MAP2K1
# 307  MAP2K2
# 308  MAPK8IP3
# 309  MATR3
# 310  MDM4
# 311  MECOM
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 312  MED12L
# 313  MED13
# 314  MEFV
# 315  MESP1
# 316  MET
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 317  MFAP5
# 318  MFN2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 319  MIR96
# 320  MORC2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 321  MPL
# 322  MPZ
# 323  MRAS
# 324  MSX2
# 325  MTAP
# 326  MTOR
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 327  MUC1
# 328  MYH10
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 329  MYH11
# 330  MYH14
# 331  MYH2
# 332  MYH6
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 333  MYH7
# 334  MYH9
# 335  MYL2
# 336  MYL3
# 337  MYLK
# 338  MYLK3
# 339  MYO6
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 340  MYO7A
# 341  MYOC
# 342  NACC1
# 343  NAF1
# 344  NARS1
# 345  NEB
# 346  NEDD4L
# 347  NEFH
# 348  NEFL
# 349  NEK1
# 350  NEK8
# 351  NEXN
# 352  NFKB1
# 353  NFKB2
# 354  NFKBIA
# 355  NKX2-1
# 356  NOD2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 357  NOTCH2
# 358  NOVA2
# 359  NPRL2
# 360  NR2F2
# 361  NRAS
# 362  NRL
# 363  OPA1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 364  OPA3
# 365  OPTN
# 366  ORAI1
# 367  OSBPL2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 368  P2RX2
# 369  P2RY12
# 370  PACS1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 371  PACS2
# 372  PARN
# 373  PCGF2
# 374  PCSK9
# 375  PDGFRA
# 376  PDX1
# 377  PFN1
# 378  PIEZO1
# 379  PIK3CA
# 380  PIK3CD
# 381  PIK3R1
# 382  PIK3R2
# 383  PLAU
# 384  PLCB4
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 385  PLIN1
# 386  PLN
# 387  PMP2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 388  POFUT1
# 389  POLD1
# 390  POLE
# 391  POLR1B
# 392  POLR3B
# 393  POU3F3
# 394  PPARG
# 395  PPM1D
# 396  PPOX
# 397  PPP1CB
# 398  PPP1R12A
# 399  PPP2CA
# 400  PPP2R1A
# 401  PPP2R5D
# 402  PRDM16
# 403  PRKAG2
# 404  PRKG1
# 405  PROC
# 406  PROK2
# 407  PROKR2
# 408  PROM1
# 409  PROS1
# 410  PRPF3
# 411  PRPF31
# 412  PRPF4
# 413  PRPF8
# 414  PRPH2
# 415  PRSS1
# 416  PSMD12
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 417  RAB7A
# 418  RAC1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 419  RAC2
# 420  RAF1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 421  RALA
# 422  RANBP2
# 423  RARB
# 424  RBFOX2
# 425  RBM20
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 426  RDH12
# 427  RELA
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 428  REN
# 429  RERE
# 430  RFX3
# 431  RFX6
# 432  RFX7
# 433  RHBDF2
# 429 from epost.fcgi ; sleeping 1.0s and retrying…
# 434  RHO
# 429 from epost.fcgi ; sleeping 1.0s and retrying…
# 435  RHOBTB2
# 436  RIT1
# 437  RNF43
# 438  RP1
# 439  RPE65
# 440  RPL5
# 441  RPS10
# 442  RRAS2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 443  RYR1
# 444  RYR2
# 445  SAMD9
# 446  SAMD9L
# 447  SATB1
# 448  SCAF4
# 449  SCN11A
# 450  SCN1B
# 451  SCN3A
# 452  SCN8A
# 453  SCNN1G
# 454  SDHA
# 455  SEC61A1
# 456  SEC63
# 457  SEMA6B
# 458  SEPTIN9
# 459  SERPINC1
# 460  SERPIND1
# 461  SERPING1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 462  SERPINI1
# 463  SETX
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 464  SFTPA1
# 465  SFTPA2
# 466  SFTPC
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 467  SHANK1
# 468  SHOC2
# 469  SIX1
# 470  SKI
# 471  SLC17A8
# 472  SLC1A2
# 473  SLC1A3
# 474  SLC30A2
# 475  SLC4A3
# 476  SLC52A1
# 477  SLC5A7
# 478  SLFN14
# 479  SMAD2
# 480  SMAD6
# 481  SMAD9
# 482  SMARCA2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 483  SMARCA5
# 484  SMARCC1
# 485  SMARCC2
# 486  SMC3
# 487  SMCHD1
# 488  SMO
# 489  SNAP25
# 490  SNCA
# 491  SNRNP200
# 492  SOCS1
# 493  SOD1
# 494  SOS1
# 495  SOS2
# 496  SOX17
# 497  SOX6
# 498  SPEN
# 499  SPI1
# 500  SPTBN1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 501  SPTBN2
# 502  SPTLC2
# 503  SQSTM1
# 504  SRC
# 505  SRCAP
# 506  SSBP1
# 507  STAT1
# 508  STAT3
# 509  STAT6
# 510  STIM1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 511  STT3A
# 512  STX1B
# 513  SUFU
# 514  SYT2
# 515  TANC2
# 516  TARDBP
# 517  TBK1
# 518  TBXA2R
# 519  TCF3
# 520  TCF7L2
# 521  TECTA
# 522  TEK
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 523  TERC
# 524  TERT
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 525  TET2
# 526  TET3
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 527  TGFB2
# 528  TGFBR2
# 529  THBD
# 530  THPO
# 531  TIMP3
# 532  TINF2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 533  TLK2
# 534  TMC1
# 535  TMEM43
# 536  TNFRSF1A
# 537  TNNC1
# 538  TNNI3
# 539  TNNI3K
# 540  TNNT2
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 541  TNPO3
# 542  TOP2B
# 543  TOPORS
# 544  TP63
# 545  TPM1
# 546  TPM2
# 547  TPM3
# 548  TPM4
# 549  TRAF3
# 550  TRAF7
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 551  TRIM8
# 552  TRPM3
# 553  TRPM7
# 554  TRPV4
# 555  TRRAP
# 556  TSPAN12
# 557  TTR
# 558  TUBA1A
# 559  TUBA4A
# 560  TUBB1
# 561  TUBB2A
# 562  TUBB2B
# 563  TUBB3
# 564  TUBB4A
# 565  TUBB4B
# 566  TUBG1
# 567  UBA2
# 568  UBTF
# 569  UCHL1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 570  UMOD
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 571  UNC93B1
# 572  VAPB
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 573  VCAN
# 574  VCL
# 575  VCP
# 576  VPS35
# 577  VWF
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 578  WASHC5
# 579  WDR37
# 580  WFS1
# 581  WNT10A
# 582  WNT5A
# 583  WRAP53
# 584  YARS1
# 429 from esummary.fcgi ; sleeping 1.0s and retrying…
# 585  YY1
# 586  ZBTB20
# 587  ZCCHC8
# 588  ZIC1
# 589  ZMIZ1
# 590  ZMYND8
# 591  ZNF292
# 592  ZSWIM6
# Done. Final checkpoints written:
#   Per-gene:  /Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/per_gene_checkpoint_dis_matching.csv
#   Rolling:   /Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/rolling_checkpoint_dis_matching.csv

# %%
# load the resulting data frame
df_fp="/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/per_gene_checkpoint_dis_matching.csv"
dom_annot = pd.read_csv(df_fp,index_col=0)

# %%
dom_annot
# Out:
#            gene  total_plp  missense_plp  nonsense_plp  \
# counter
# 0         AARS1          4             2             0
# 1         ABCB6          2             1             0
# 2         ABCC6          1             0             1
# 3         ABCC8         10             7             0
# 4         ABCC9          6             6             0
# ...         ...        ...           ...           ...
# 588        ZIC1          0             0             0
# 589       ZMIZ1          4             1             2
# 590      ZMYND8          1             0             0
# 591      ZNF292         23             1             9
# 592      ZSWIM6          2             0             1
#
#                                               dom_ids_list
# counter
# 0        [['2584743', '2504064', '1299470', '955835', '...
# 1        [['2584743', '2504064', '1299470', '955835', '...
# 2        [['2584743', '2504064', '1299470', '955835', '...
# 3        [['2584743', '2504064', '1299470', '955835', '...
# 4        [['2584743', '2504064', '1299470', '955835', '...
# ...                                                    ...
# 588      [[['2584743', '2504064', '1299470', '955835', ...
# 589      [[['2584743', '2504064', '1299470', '955835', ...
# 590      [[['2584743', '2504064', '1299470', '955835', ...
# 591      [[['2584743', '2504064', '1299470', '955835', ...
# 592      [[['2584743', '2504064', '1299470', '955835', ...
#
# [593 rows x 5 columns]

# %% [markdown]
# # Get the omim queries ready below

# %% [markdown]
# ### Gets a list of the omim ids per mutation per gene (excluding mutations that are already annotated as dominant)

# %%
# set up mondo->omim mapping
def mondo_xrefs(mondo_id): # prefixes=("OMIM", "Orpha")):
    term = mondo.get(mondo_id)
    xrefs=set()
    if term is None:
        return set()
    else:
        for x in term.xrefs:
            xrefs.add(getattr(x, 'id'))
    return xrefs

# second query for disease matching dominance
# here we'll do a broader search and some fancy filtering for dominant using ontology mapping
PICKLE_PATH = (
    "/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/gene2_plp_uids_with_mis_ns.pkl"
)
MIS_NS_PATH = (
    "/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/mis_ns_dict.pkl"
)

# Load existing checkpoint if present
if os.path.exists(PICKLE_PATH):
    with open(PICKLE_PATH, "rb") as fp:
        gene2_plp_uid = pickle.load(fp)
    print(f"Loaded checkpoint with {len(gene2_plp_uid)} genes")
else:
    gene2_plp_uid = {}
    print("No checkpoint found — starting fresh")
if os.path.exists(MIS_NS_PATH):
    with open(MIS_NS_PATH, "rb") as fp:
        mis_ns_dict = pickle.load(fp)
    print(f"Loaded checkpoint with {len(mis_ns_dict)} genes")
else:
    mis_ns_dict = {}
    print("No checkpoint found — starting fresh")


for counter, gene in enumerate(gene_df["hgnc_symbol"]):
    if gene in gene2_plp_uid:
        continue  # already processed

    print(f"{counter}  {gene}")
    var2_omim_ids = {}
    mis_ns_dict_cur_gene={}
    
    
    term = (
            f'{gene}[gene] AND single_gene[prop] AND "moi autosomal dominant"[prop] AND '
            '(pathogenic[clinsig] OR "likely pathogenic"[clinsig] OR "pathogenic/likely pathogenic"[clinsig])'
        )
        
    esearch_params = {"db": "clinvar", "term": term, "retmode": "json", "retmax": 100000}
    r = request_with_429_retry("GET", base_esearch, params=esearch_params, timeout=30)
    esearch_data = r.json()
    
    dom_annot_ids = esearch_data["esearchresult"]["idlist"]
    
    
    term2 = (
        f'{gene}[gene] AND single_gene[prop] AND '
        '(pathogenic[clinsig] OR "likely pathogenic"[clinsig] OR "pathogenic/likely pathogenic"[clinsig])'
    )
    esearch_params = {"db": "clinvar", "term": term2, "retmode": "json", "retmax": 100000}
    r = request_with_429_retry("GET", base_esearch, params=esearch_params, timeout=30)
    esearch_data = r.json()
    cur_ids2 = esearch_data["esearchresult"]["idlist"]
    
    if cur_ids2:
        for post_batch in batched(cur_ids2, 5000):
            webenv, query_key = epost_ids("clinvar", post_batch)
    
            retstart = 0
            while retstart < len(post_batch):
                esum_data = esummary_from_history(
                    "clinvar",
                    webenv,
                    query_key,
                    retstart=retstart,
                    retmax=ESUMMARY_PAGE_SIZE,
                )
                # check if the uid has already been analyzed
                for uid in esum_data.get("result", {}).get("uids", []):
                    if uid not in dom_annot_ids:
                        cur_uid_result = esum_data["result"].get(uid, {})
    
                        germ_desc = (
                            cur_uid_result
                            .get("germline_classification", {})
                            .get("description", "")
                            .strip()
                        )
                        if germ_desc not in ALLOWED_GERMLINE:
                            continue
                            

                        # store whether the mutation is missense or nonsense
                        mcons = cur_uid_result.get("molecular_consequence_list", [])
                        mcons_text = " ".join(
                            (mc.get("type", "") if isinstance(mc, dict) else str(mc))
                            for mc in mcons
                        ).lower()
        
                        if "missense" in mcons_text:
                            mis_ns_dict_cur_gene[uid] = 'missense'
                        if ("nonsense" in mcons_text) or ("stop_gained" in mcons_text):
                            mis_ns_dict_cur_gene[uid]='nonsense'
                        else:
                            mis_ns_dict_cur_gene[uid]=None
                        

                            
                        # get trait information for the current variant
                        trait_set = (cur_uid_result
                                    .get("germline_classification", {})
                                    .get("trait_set", []))
                        source_to_ids = defaultdict(list)
                        
                        # of the multiple trait entries, store ontology sources with their ids that we'll use for lookup
                        for entry in trait_set:
                            for xref in entry.get("trait_xrefs", []):
                                source_to_ids[xref["db_source"]].append(xref["db_id"])
                        source_to_ids = dict(source_to_ids)
    
                        # if OMIM ids are available, look those up using OMIM API
                        # otherwise, map MONDO id to OMIM
                        # notice how we're being very relaxed in stringency here-->
                        # if any one of these disease terms is associated with dominance, we'll consider the mutation dominant
                        source_keys = list(source_to_ids.keys())
                        omim_query_ids=[]
                        if 'OMIMPS' in source_keys:
                            omim_query_ids = omim_query_ids + source_to_ids['OMIMPS']
                        elif ('OMIM' in source_keys):
                            omim_query_ids = omim_query_ids + source_to_ids['OMIM']
                        elif ('MONDO' in source_keys):
                            # map to OMIM first
                            for mondo_id in source_to_ids['MONDO']:
                                cur_xrefs = mondo_xrefs(mondo_id)
                                # isolate any 'OMIM' containing elements from cur_xrefs
                                if any('OMIM' in element for element in cur_xrefs):
                                    omim_query_ids = omim_query_ids + [
                                            x.split(":")[1] for x in cur_xrefs
                                            if x.startswith(("OMIM", "OMIMPS"))]
                        # if variant is plp but we don't know if dominant, add omim ids for later lookup
                        if len(omim_query_ids)==0:
                            var2_omim_ids[uid] = None
                        else:
                            var2_omim_ids[uid] = omim_query_ids
    
                retstart += ESUMMARY_PAGE_SIZE
                time.sleep(0.35)
        gene2_plp_uid[gene] = var2_omim_ids
        mis_ns_dict[gene]=mis_ns_dict_cur_gene
        with open("/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/gene2_plp_uids.pkl", 'wb') as fp:
            pickle.dump(gene2_plp_uid,fp)
# Out:
# Loaded checkpoint with 570 genes
# No checkpoint found — starting fresh
# 12  ACTC1
# 60  C1QTNF5
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 87  CEACAM16
# 109  COL10A1
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 146  DSPP
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 182  FOXE3
# 187  FXYD2
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 222  GUCA1A
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 228  HAND2
# 239  HNRNPH1
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 242  HRAS
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 250  IGF2
# 279  KCNK4
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 292  KLF13
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 302  MAB21L2
# 325  MTAP
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 369  P2RY12
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 383  PLAU
# 460  SERPIND1
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 521  TECTA
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 531  TIMP3
# 539  TNNI3K
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…
# 568  UBTF
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…

# %% [markdown]
# ### Get a list of all unique OMIM ids so you can do a batch query

# %%
# then, let's make master list of all the unique OMIM ids to look up, so we can query them all at once
unique_omims = set()
for gene,uid2omim_dict in gene2_plp_uid.items():
    for values in uid2omim_dict.values():
        if values is not None:
            unique_omims.update(values)
    
unique_omims = list(unique_omims)

# %%
print(len(unique_omims))
# Out:
# 1198

# %%
unique_omims
# Out:
# ['180100',
#  '618659',
#  '620278',
#  '600513',
#  '615704',
#  '614298',
#  '618314',
#  '109800',
#  '135500',
#  '300148',
#  '220290',
#  '611553',
#  '143100',
#  '201400',
#  '613026',
#  '614390',
#  '609260',
#  '188550',
#  '613796',
#  '614436',
#  '616100',
#  '180105',
#  '619293',
#  '616249',
#  '618416',
#  '613657',
#  '610628',
#  '604004',
#  '619913',
#  '605583',
#  '620725',
#  '600652',
#  '187350',
#  '607791',
#  '614203',
#  '607594',
#  '605714',
#  'PS234200',
#  '615422',
#  '168601',
#  '615214',
#  '609814',
#  '614669',
#  '613319',
#  '621180',
#  '613708',
#  '616154',
#  '618598',
#  '611136',
#  '153670',
#  'PS607594',
#  'PS617468',
#  '610759',
#  '613217',
#  '614296',
#  '112200',
#  '600794',
#  '153870',
#  '605289',
#  '619418',
#  '120970',
#  'PS166200',
#  'PS236600',
#  'PS601462',
#  '607785',
#  '618036',
#  '608895',
#  '619492',
#  '617903',
#  '612095',
#  '612422',
#  '616576',
#  '618587',
#  '613065',
#  '619707',
#  '176200',
#  '620806',
#  '123790',
#  '618906',
#  '620458',
#  '192500',
#  '617439',
#  '181400',
#  '234750',
#  '259420',
#  '204000',
#  '187500',
#  '619810',
#  '615561',
#  '607197',
#  '607677',
#  '616411',
#  '618336',
#  '115200',
#  '156000',
#  '612561',
#  '610455',
#  '618971',
#  '136140',
#  '617393',
#  '621233',
#  '618846',
#  '613780',
#  'PS248200',
#  '616687',
#  '615592',
#  '149000',
#  '620330',
#  'PS310300',
#  '614743',
#  '116860',
#  '165500',
#  '167000',
#  '608340',
#  '621097',
#  '616973',
#  '617757',
#  '618939',
#  'PS604772',
#  '619467',
#  '617904',
#  '618088',
#  '612712',
#  '609153',
#  '615193',
#  '611809',
#  '604233',
#  '606346',
#  '617921',
#  '269880',
#  'PS184255',
#  '620073',
#  '613116',
#  '147950',
#  '619927',
#  '135700',
#  '611875',
#  '153100',
#  '255160',
#  '608224',
#  '256000',
#  '228520',
#  '230900',
#  '187600',
#  '617450',
#  'PS174050',
#  '615506',
#  '184840',
#  '619611',
#  '618541',
#  '143200',
#  '193220',
#  '613980',
#  'PS124900',
#  '615108',
#  '268000',
#  '619851',
#  'PS117000',
#  '158810',
#  '135300',
#  '614514',
#  '615185',
#  '616875',
#  '620192',
#  '140500',
#  '167250',
#  'PS616263',
#  '613990',
#  '102500',
#  '614592',
#  '614255',
#  '605192',
#  '143890',
#  '613435',
#  '617190',
#  '209850',
#  '605253',
#  '618798',
#  '614042',
#  '265500',
#  '619320',
#  '608161',
#  '260370',
#  '182212',
#  '610708',
#  '618872',
#  '607278',
#  '214400',
#  '604498',
#  '619808',
#  '613112',
#  '618780',
#  '180050',
#  '224750',
#  '108800',
#  '109730',
#  '146300',
#  '616362',
#  '613092',
#  '243310',
#  '606835',
#  '616056',
#  '608068',
#  '266600',
#  '615342',
#  '176860',
#  '206700',
#  '613642',
#  'PS300755',
#  '613640',
#  '179300',
#  '619804',
#  '613731',
#  '601098',
#  'PS115430',
#  '168605',
#  '610551',
#  '606703',
#  '615279',
#  '617935',
#  '603596',
#  'PS160565',
#  '608569',
#  '600666',
#  '614569',
#  '123500',
#  '608030',
#  '602089',
#  '612304',
#  '618901',
#  '614039',
#  '619657',
#  '232400',
#  '253600',
#  '618806',
#  '614254',
#  '608033',
#  '155500',
#  '616353',
#  '608104',
#  '601198',
#  '613286',
#  '610246',
#  '616564',
#  'PS218330',
#  'PS602483',
#  '264800',
#  '618149',
#  '135100',
#  '155255',
#  '606705',
#  '310600',
#  '618454',
#  '609192',
#  '617874',
#  '614849',
#  '166710',
#  '121201',
#  '129500',
#  '613310',
#  '607821',
#  '613237',
#  '616172',
#  '601820',
#  '617542',
#  '619720',
#  '607174',
#  '167320',
#  '609924',
#  '164300',
#  '127400',
#  '604356',
#  '155950',
#  '613779',
#  '613224',
#  '108120',
#  '603563',
#  '621266',
#  '254450',
#  '610474',
#  '612591',
#  '617004',
#  '277450',
#  '601472',
#  '182601',
#  '617087',
#  '612069',
#  '163200',
#  '607831',
#  '277480',
#  '613194',
#  '600975',
#  '611880',
#  '174000',
#  'PS193670',
#  '613837',
#  '617506',
#  'PS145980',
#  '617056',
#  '613060',
#  '614782',
#  '618857',
#  '621225',
#  '619651',
#  '619606',
#  '600669',
#  '616029',
#  '611878',
#  '613251',
#  'PS273800',
#  '601414',
#  '617116',
#  '115150',
#  '616214',
#  '609923',
#  '616247',
#  '101400',
#  '129400',
#  '618917',
#  '115430',
#  '614457',
#  '621231',
#  '187900',
#  '114480',
#  '611603',
#  '616346',
#  '612645',
#  '620475',
#  'PS606176',
#  '600110',
#  '104290',
#  '620674',
#  '615386',
#  '618873',
#  '157600',
#  '184095',
#  '184252',
#  '124900',
#  '145980',
#  '232300',
#  '219721',
#  '619090',
#  'PS220210',
#  '617062',
#  '145600',
#  '603671',
#  '620207',
#  '604367',
#  'PS127550',
#  '607832',
#  '618697',
#  '619229',
#  '612336',
#  '160150',
#  'PS104290',
#  'PS121200',
#  '611378',
#  '614389',
#  '158590',
#  '608654',
#  '118200',
#  '619595',
#  '615575',
#  '208920',
#  '214500',
#  '616937',
#  '618555',
#  '257980',
#  '605258',
#  '255600',
#  '619950',
#  '256450',
#  '612918',
#  '259050',
#  '600994',
#  '165800',
#  '619228',
#  '620727',
#  '166210',
#  '604218',
#  '615763',
#  '300216',
#  '617882',
#  '617159',
#  '615412',
#  '600138',
#  '620246',
#  '125853',
#  '252011',
#  'PS192600',
#  '619041',
#  '612158',
#  '607684',
#  '613105',
#  '106100',
#  '613370',
#  '254090',
#  '603776',
#  '600795',
#  'PS607432',
#  '614321',
#  '115000',
#  '618778',
#  '616314',
#  '601412',
#  '613089',
#  '611879',
#  '606762',
#  '619267',
#  'PS108120',
#  'PS609192',
#  '101600',
#  '601705',
#  '180800',
#  '615373',
#  '616040',
#  '609296',
#  '606071',
#  '109650',
#  'PS607086',
#  '612813',
#  '145900',
#  '613172',
#  '234000',
#  '166220',
#  '606070',
#  '612657',
#  '301040',
#  '608203',
#  '177850',
#  'PS163950',
#  '601005',
#  '612132',
#  '607694',
#  '601388',
#  '616366',
#  '605259',
#  '184255',
#  '612783',
#  '612899',
#  '601894',
#  '130060',
#  '615005',
#  '617350',
#  '612526',
#  '601626',
#  '269700',
#  '600965',
#  '613563',
#  '616000',
#  'PS183600',
#  '163800',
#  '616638',
#  '614808',
#  '615139',
#  '614211',
#  '618557',
#  '126700',
#  '605074',
#  'PS204000',
#  '235400',
#  '617337',
#  '620486',
#  '249300',
#  '115195',
#  '614524',
#  '208900',
#  '202700',
#  '615577',
#  '612269',
#  '128235',
#  '135900',
#  '619311',
#  '617113',
#  'PS141200',
#  '158350',
#  '615596',
#  '168550',
#  '605130',
#  '611490',
#  '607678',
#  '607721',
#  '617158',
#  'PS153100',
#  '617820',
#  '220210',
#  '614473',
#  '616737',
#  '154780',
#  '612702',
#  '616330',
#  '603956',
#  '606657',
#  '603511',
#  'PS601495',
#  '105550',
#  '619325',
#  '618918',
#  '617638',
#  '616393',
#  '615916',
#  '620311',
#  '604765',
#  '619351',
#  '615952',
#  '613925',
#  '614706',
#  '618672',
#  '610168',
#  '617561',
#  '609273',
#  'PS614429',
#  '616707',
#  '602433',
#  '168500',
#  '618205',
#  '618655',
#  '612643',
#  '618031',
#  '600882',
#  '204100',
#  '614455',
#  '182000',
#  '620343',
#  '612923',
#  '617435',
#  'PS116200',
#  '615491',
#  'PS108800',
#  'PS160150',
#  '604292',
#  '616632',
#  '611307',
#  '615937',
#  '276900',
#  '620532',
#  'PS105650',
#  '615009',
#  '607485',
#  '141200',
#  '609812',
#  '615524',
#  '120790',
#  '241500',
#  'PS141500',
#  '146000',
#  '620241',
#  '603457',
#  '271665',
#  '178600',
#  '614165',
#  '608627',
#  '615010',
#  '263520',
#  'PS228520',
#  '130000',
#  '615134',
#  '274600',
#  '600131',
#  '614089',
#  '616313',
#  '618061',
#  '614302',
#  '618878',
#  '621096',
#  'PS249210',
#  '615474',
#  '256030',
#  '612961',
#  '616166',
#  '614487',
#  '109820',
#  '610205',
#  'PS161800',
#  '618204',
#  '620365',
#  'PS300049',
#  '103285',
#  'PS167320',
#  '614162',
#  '170390',
#  '617829',
#  '616705',
#  '227400',
#  '268130',
#  '620029',
#  '121300',
#  '619742',
#  '617080',
#  '608758',
#  '608634',
#  '619773',
#  '273800',
#  '617839',
#  '600638',
#  '260350',
#  '616289',
#  '616603',
#  '621078',
#  '607086',
#  '621234',
#  '617053',
#  '617143',
#  '613829',
#  '613014',
#  '611554',
#  '133239',
#  '608358',
#  '620478',
#  '619161',
#  '619661',
#  '618285',
#  '166600',
#  '619475',
#  '619461',
#  '613882',
#  '606721',
#  '603622',
#  '215500',
#  '616913',
#  '166200',
#  '621226',
#  '609579',
#  '182250',
#  '620481',
#  '620265',
#  '173100',
#  '610444',
#  '617235',
#  '133200',
#  '140300',
#  '215150',
#  '202400',
#  '616187',
#  '614433',
#  '618858',
#  '618396',
#  '231005',
#  '613244',
#  '185050',
#  '236750',
#  '117100',
#  '612925',
#  '254500',
#  '618856',
#  '615344',
#  '621390',
#  '601152',
#  '613876',
#  '165300',
#  '616371',
#  'PS276900',
#  '181405',
#  '617443',
#  '615871',
#  '613707',
#  '619542',
#  '608641',
#  '618482',
#  '249100',
#  'PS146200',
#  '617804',
#  '603932',
#  'PS149730',
#  '614486',
#  '614558',
#  '227300',
#  '616452',
#  '132900',
#  '303100',
#  '613118',
#  '619656',
#  '188055',
#  '604919',
#  '180700',
#  '194200',
#  '615883',
#  '615432',
#  '606392',
#  '207410',
#  '617145',
#  '617272',
#  '615710',
#  '101200',
#  'PS173900',
#  '618052',
#  '619959',
#  '616941',
#  '601868',
#  '221900',
#  '601887',
#  '615338',
#  '603387',
#  '615043',
#  '613287',
#  '613834',
#  '229600',
#  '618699',
#  'PS600669',
#  '617268',
#  '618820',
#  '136880',
#  '162100',
#  '612247',
#  '616843',
#  '607736',
#  '604187',
#  '614820',
#  'PS120435',
#  '621371',
#  '194380',
#  '615280',
#  '612416',
#  '227600',
#  '619854',
#  '615083',
#  '617798',
#  '619691',
#  '613123',
#  '619271',
#  '613722',
#  '241510',
#  '614959',
#  '608389',
#  '613659',
#  '619375',
#  '176270',
#  '615377',
#  '610359',
#  '600880',
#  '620728',
#  '612922',
#  '620726',
#  '230800',
#  '621261',
#  '615355',
#  '150400',
#  '608644',
#  '159550',
#  '265400',
#  '600974',
#  '618184',
#  '614896',
#  '614306',
#  '115196',
#  '610031',
#  '613071',
#  '608423',
#  'PS108300',
#  '600059',
#  '618729',
#  '188000',
#  '618095',
#  '613877',
#  '616355',
#  '114500',
#  '187601',
#  'PS603165',
#  'PS123100',
#  '105400',
#  '619188',
#  '621248',
#  '248200',
#  '615473',
#  '608673',
#  '619259',
#  '619120',
#  '618027',
#  '620221',
#  '604400',
#  '601494',
#  '601162',
#  '617108',
#  '605375',
#  '618654',
#  '616340',
#  '601358',
#  '613690',
#  'PS120970',
#  '258660',
#  '240800',
#  '621402',
#  '613674',
#  '609500',
#  '161800',
#  'PS145600',
#  '123150',
#  '606631',
#  '618287',
#  '619736',
#  '618008',
#  '617162',
#  '125852',
#  '211980',
#  '600060',
#  '616586',
#  '106260',
#  '613328',
#  '607641',
#  '266920',
#  '146110',
#  '618986',
#  '610374',
#  '182900',
#  '615552',
#  '616409',
#  '601367',
#  '600195',
#  '615415',
#  '607371',
#  '620607',
#  '263210',
#  '620568',
#  '600416',
#  '618604',
#  '618447',
#  '609755',
#  '193670',
#  '617237',
#  '617090',
#  '619042',
#  '154700',
#  '618050',
#  '132400',
#  '618009',
#  '608361',
#  '606369',
#  '611162',
#  '618782',
#  '105200',
#  '239850',
#  '600274',
#  '616005',
#  '126600',
#  '277590',
#  '177170',
#  '231200',
#  '610476',
#  '619338',
#  '201300',
#  '613794',
#  '131500',
#  '242700',
#  '610015',
#  '617821',
#  '610253',
#  '611938',
#  '618987',
#  '613750',
#  '600101',
#  '610733',
#  '160565',
#  '615938',
#  '241800',
#  '618371',
#  '620880',
#  '612438',
#  '618960',
#  '601777',
#  '600268',
#  '614497',
#  '602501',
#  '618364',
#  '604841',
#  '609446',
#  'PS254770',
#  '612782',
#  '617643',
#  '175510',
#  '619764',
#  '608089',
#  '618876',
#  '614742',
#  'PS132400',
#  '603284',
#  '613426',
#  '273300',
#  '610698',
#  '612838',
#  '264470',
#  '160120',
#  '617493',
#  'PS604498',
#  '261740',
#  '618129',
#  'PS236100',
#  '602849',
#  '606002',
#  '145680',
#  '609135',
#  '168600',
#  '182980',
#  '614381',
#  '186580',
#  '609622',
#  '614331',
#  '612926',
#  '607842',
#  '147791',
#  '104300',
#  '609706',
#  '610842',
#  '267430',
#  '618092',
#  '616208',
#  '613824',
#  'PS305100',
#  '610984',
#  '155310',
#  '613252',
#  '171300',
#  '152700',
#  '213000',
#  '608013',
#  '613873',
#  'PS604169',
#  '618977',
#  'PS268000',
#  '618164',
#  '620669',
#  '609285',
#  '614388',
#  '188050',
#  '616389',
#  '611816',
#  '193400',
#  '239200',
#  'PS265120',
#  '619548',
#  '255320',
#  '619091',
#  '613554',
#  '610582',
#  'PS608354',
#  '618908',
#  '127550',
#  '617516',
#  '616004',
#  '602483',
#  '620903',
#  '615327',
#  'PS609129',
#  '610913',
#  '616439',
#  '603543',
#  '231000',
#  '619437',
#  '618999',
#  '182600',
#  '104200',
#  '614892',
#  '604772',
#  '607734',
#  '114550',
#  '203450',
#  '192600',
#  '618354',
#  '158901',
#  'PS115150',
#  '619312',
#  '609909',
#  'PS301050',
#  '620460',
#  '142680',
#  '601680',
#  '160500',
#  'PS125850',
#  '614559',
#  '616437',
#  '115210',
#  '616579',
#  '169150',
#  'PS158350',
#  '619402',
#  '620483',
#  '252270',
#  'PS130000',
#  '614213',
#  '617105',
#  '604717',
#  '616482',
#  '252100',
#  '608118',
#  '619350',
#  '615048',
#  '613243',
#  '616418',
#  '618859',
#  '244200',
#  '615744',
#  '210000',
#  '608051',
#  '616151',
#  '264350',
#  '614809',
#  '165510',
#  '615026',
#  'PS128200',
#  '616559',
#  '618443',
#  ...]

# %% [markdown]
# ### Helper function to query OMIM in batches

# %%
# construct one large OMIM query
def query_omim(omim_ids, api_key="FM5UzX8IRfa7sC3WasvlXA", batch_size=20, sleep_s=0.3):
    """
    Queries OMIM in batches and returns a combined JSON dict.
    Raises HTTPError if any request fails.
    """
    if not omim_ids:
        return None
    # strip omim ids of any 'PS' prefixes
    cleaned=[
    v[2:] if v.startswith("PS") else v
    for v in omim_ids
    ]

    # query structure
    url = (
        "https://api.omim.org/api/entry?mimNumber=" +
        "%2C".join(map(str, cleaned)) +
        "&include=clinicalSynopsis&include=geneMap&format=json&apiKey=" + api_key
    )

    # response structure that we'll fill upon each batch
    combined_response = {
        "omim": {
            "entryList": []
        }
    }

    for i in range(0, len(cleaned), batch_size):
        batch = cleaned[i:i + batch_size]

        url = (
            "https://api.omim.org/api/entry?mimNumber=" +
            "%2C".join(batch) +
            "&include=clinicalSynopsis&include=geneMap"
            "&format=json&apiKey=" + api_key
        )

        response = requests.get(url, timeout=30)
        response.raise_for_status()

        json_data = response.json()

        entry_list = json_data.get("omim", {}).get("entryList", [])
        combined_response["omim"]["entryList"].extend(entry_list)

        time.sleep(sleep_s)

    return combined_response


# BEFORE RUNNING THIS - Check if query can accomodate 'PS' in the mim id
#json_data = query_omim(unique_omims)

# get inheritance from clinical synopsis
def get_inheritance(clinical_synopsis):
    """
    Returns inheritance string from OMIM clinicalSynopsis,
    handling both new and old OMIM formats.
    """
    if not isinstance(clinical_synopsis, dict):
        return ""
    
    # New format
    inh = clinical_synopsis.get("inheritance")
    if inh:
        return inh
    
    # Old format
    old = clinical_synopsis.get("oldFormat", {})
    if isinstance(old, dict):
        return old.get("Inheritance", "")
    
    return ""

# helper function to parse json data and determine if an OMIM ID is associated with dominance
def parse_json(json_data):
    mim_ids=[]
    dom_mim_list=[]
    for entry_wrapper in json_data.get("omim", {}).get("entryList", []):
        var_assoc_with_dominance=False
        entry = entry_wrapper.get("entry", {})
        mim_number = entry.get("mimNumber")
        #print(mim_number)
        mim_ids.append(mim_number)
        #print('mim_number')

        # get clinical synopsis inheritance
        clinical_synopsis = entry.get("clinicalSynopsis", {})
        inheritance_str = get_inheritance(clinical_synopsis)

        #print(clinicalSynopsis_inheritance)
        pheno_map_inheritance_list=[]
        #print(entry.get("phenotypeMapList", []))
        for list_item in entry.get("phenotypeMapList", []):
            #print(list_item)
            pheno_inheritance=list_item.get("phenotypeMap",{}).get("phenotypeInheritance", "")
            if len(pheno_inheritance)>0:
                pheno_map_inheritance_list.append(pheno_inheritance)
        
        # check if any of the listed phenotypes have autosomal dominant annotations in OMIM
        #print(inheritance_str)
        #print(pheno_map_inheritance_list)
        if ('Autosomal dominant' in inheritance_str) or (any('Autosomal dominant' in str(x) for x in pheno_map_inheritance_list)):
            var_assoc_with_dominance=True
            dom_mim_list.append(var_assoc_with_dominance)
            continue
        else:
            dom_mim_list.append(var_assoc_with_dominance)
    return dict(zip([str(x) for x in mim_ids],dom_mim_list))

# helper function to map back to each variant per gene
def map_uids_to_dominance(gene2_plp_uid,mim_dom_map):
    gene2_plp_uid_dominance={}
    for gene,mut_dict in gene2_plp_uid.items():
        uid2_dominance={}
        for uid, mim_id_list in mut_dict.items():
            uid_dom_value=False
            if mim_id_list is None:
                uid2_dominance[uid]=uid_dom_value
                continue
            for item in mim_id_list:
                # strip of prefix
                if 'PS' in item:
                    item=item.split('PS')[1]
                # get dominance value
                if str(item) in list(mim_dom_map.keys()):
                    uid_dom_value = mim_dom_map[str(item)]
                    # if dominance value is already true, don't need to check other OMIM terms
                    if uid_dom_value==True:
                        uid2_dominance[uid]=uid_dom_value
                        break
                uid2_dominance[uid]=uid_dom_value
        gene2_plp_uid_dominance[gene]=uid2_dominance
    return gene2_plp_uid_dominance

# helper function to total up the resulting dominant variants per gene
def total_plp_vars(gene2_plp_uid_dominance):
    gene_plp_totals={}
    for gene,mut_dict in gene2_plp_uid_dominance.items():
        gene_plp_totals[gene]=sum(mut_dict.values())
    return gene_plp_totals

# %%
# Run the omim query
json_data = query_omim(unique_omims)

# parse the resulting data
mim_dom_map = parse_json(json_data)

# map the uids for the mutations of each gene to whether or not they are dominant
gene2_plp_uid_dominance = map_uids_to_dominance(gene2_plp_uid,mim_dom_map)

# total up all of the dominant vars
gene_plp_totals=total_plp_vars(gene2_plp_uid_dominance)

# %%
for gene,uid_dict in mis_ns_dict.items():
    for uid,mis_ns in uid_dict.items():
        if mis_ns is not None:
            if mis_ns=='missense':
                print(gene, uid)

# %%
# clean up df with dominant annotations
df_fp="/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/per_gene_checkpoint_dis_matching.csv"
dom_annot = pd.read_csv(df_fp,index_col=0)
dom_clean=dom_annot.drop(labels=['dom_ids_list'],axis=1)

# %%
dom_annot
# Out:
#            gene  total_plp  missense_plp  nonsense_plp  \
# counter
# 0         AARS1          4             2             0
# 1         ABCB6          2             1             0
# 2         ABCC6          1             0             1
# 3         ABCC8         10             7             0
# 4         ABCC9          6             6             0
# ...         ...        ...           ...           ...
# 588        ZIC1          0             0             0
# 589       ZMIZ1          4             1             2
# 590      ZMYND8          1             0             0
# 591      ZNF292         23             1             9
# 592      ZSWIM6          2             0             1
#
#                                               dom_ids_list
# counter
# 0        [['2584743', '2504064', '1299470', '955835', '...
# 1        [['2584743', '2504064', '1299470', '955835', '...
# 2        [['2584743', '2504064', '1299470', '955835', '...
# 3        [['2584743', '2504064', '1299470', '955835', '...
# 4        [['2584743', '2504064', '1299470', '955835', '...
# ...                                                    ...
# 588      [[['2584743', '2504064', '1299470', '955835', ...
# 589      [[['2584743', '2504064', '1299470', '955835', ...
# 590      [[['2584743', '2504064', '1299470', '955835', ...
# 591      [[['2584743', '2504064', '1299470', '955835', ...
# 592      [[['2584743', '2504064', '1299470', '955835', ...
#
# [593 rows x 5 columns]

# %%
# add to dom_annot dataframe
dom_clean.rename(columns={'total_plp':'total_dom_annot_plp', 'missense_plp':'total_dom_annot_mis_plp','nonsense_plp':'total_dom_annot_ns_plp'},inplace=True)
all_dom_totals=[]
for idx,row in dom_clean.iterrows():
    if row.gene in list(gene_plp_totals.keys()):
        all_dom_totals.append(row.total_dom_annot_plp + gene_plp_totals[row.gene])
    else:
        all_dom_totals.append(row.total_dom_annot_plp)
dom_clean['total_dom_annot_and_omim_plp']=all_dom_totals
dom_clean['added_mutations']=dom_clean['total_dom_annot_and_omim_plp']-dom_clean['total_dom_annot_plp']
dom_clean
# Out:
#            gene  total_dom_annot_plp  total_dom_annot_mis_plp  \
# counter
# 0         AARS1                    4                        2
# 1         ABCB6                    2                        1
# 2         ABCC6                    1                        0
# 3         ABCC8                   10                        7
# 4         ABCC9                    6                        6
# ...         ...                  ...                      ...
# 588        ZIC1                    0                        0
# 589       ZMIZ1                    4                        1
# 590      ZMYND8                    1                        0
# 591      ZNF292                   23                        1
# 592      ZSWIM6                    2                        0
#
#          total_dom_annot_ns_plp  total_dom_annot_and_omim_plp  added_mutations
# counter
# 0                             0                            10                6
# 1                             0                             8                6
# 2                             1                            74               73
# 3                             0                           272              262
# 4                             0                            63               57
# ...                         ...                           ...              ...
# 588                           0                             5                5
# 589                           2                            25               21
# 590                           0                             1                0
# 591                           9                            47               24
# 592                           1                             3                1
#
# [593 rows x 6 columns]

# %%
# increase dpi of fig
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
# let's plot this now
# let's plot just the dominant data
cols = [
    "total_dom_annot_and_omim_plp"
]

plot_data = [dom_clean[col].values for col in cols]
fig, ax = plt.subplots(figsize=(5, 4))

vp = ax.violinplot(
    plot_data,
    showmeans=False,
    showmedians=True,
    showextrema=True
)

# bp = ax.boxplot(
#     plot_data
#     # showmeans=False,
#     # showmedians=True,
#     # showextrema=True
# )

ax.set_xticks(np.arange(1, len(cols) + 1))
ax.set_xticklabels(['Dominant\nPathogenic Mutations'], 
                   rotation=0)

for i, col in enumerate(cols, start=1):
    y = dom_clean[col].values
    x = np.random.normal(i, 0.04, size=len(y))  # jitter
    ax.scatter(x, y, s=10, alpha=0.6, color="black")
#ax.set_yscale("log")
ax.set_ylabel("Pathogenic mutation count per gene", fontsize=12)

ax.text(
    0.94, 0.9,
    "N = 593 D&D \nGroup 1 Genes",
    transform=ax.transAxes,
    ha="right",
    va="top",
    fontsize=10
)

# for body in vp["bodies"]:
#     body.set_alpha(0.7)

plt.tight_layout()
plt.show()

savedir="/Users/graceramey/Library/CloudStorage/Box-Box/capra_lab/projects/dominant_negative_disease_editing/figures/jupyter_notebook_savefigs"
plt.savefig(savedir + "/ClinVar_OMIM_dom_annots.svg", format='svg', bbox_inches='tight',transparent=True)

# %%
# we should also show Group 1 vs Group 2 genes here
s_het_data = data[['hgnc_symbol', 's_het']]
s_het_data=s_het_data.copy()
s_het_data.rename(columns={'hgnc_symbol':'gene'}, inplace=True)
s_het_data
# Out:
#        gene     s_het
# 0     AARS1  0.022459
# 1     AARS1  0.022459
# 2     ABCB6  0.000834
# 3     ABCB6  0.000834
# 4     ABCC6  0.000681
# ..      ...       ...
# 850    ZIC1  0.205882
# 851   ZMIZ1  0.209067
# 852  ZMYND8  0.254357
# 853  ZNF292  0.217299
# 854  ZSWIM6  0.260329
#
# [855 rows x 2 columns]

# %%
g2_genes = dom_clean.merge(s_het_data, on='gene', how='left')
g2_genes.drop_duplicates(inplace=True)
g2_genes=g2_genes[g2_genes['s_het']<0.1]
g2_genes
# Out:
#        gene  total_dom_annot_plp  total_dom_annot_mis_plp  \
# 0     AARS1                    4                        2
# 2     ABCB6                    2                        1
# 4     ABCC6                    1                        0
# 5     ABCC8                   10                        7
# 7     ABCC9                    6                        6
# ..      ...                  ...                      ...
# 839    WFS1                   11                        9
# 842  WNT10A                    5                        3
# 843   WNT5A                    2                        2
# 844  WRAP53                    0                        0
# 846   YARS1                    2                        2
#
#      total_dom_annot_ns_plp  total_dom_annot_and_omim_plp  added_mutations  \
# 0                         0                            10                6
# 2                         0                             8                6
# 4                         1                            74               73
# 5                         0                           272              262
# 7                         0                            63               57
# ..                      ...                           ...              ...
# 839                       1                            72               61
# 842                       2                            95               90
# 843                       0                             7                5
# 844                       0                             0                0
# 846                       0                             7                5
#
#         s_het
# 0    0.022459
# 2    0.000834
# 4    0.000681
# 5    0.008893
# 7    0.020637
# ..        ...
# 839  0.001000
# 842  0.001348
# 843  0.096404
# 844  0.017655
# 846  0.023600
#
# [363 rows x 7 columns]

# %%
dom_clean = pd.read_csv("/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/ClinVar_Omim_dom_annot.csv")
dom_clean
# Out:
#      counter    gene  total_dom_annot_plp_from_clinvar  \
# 0          0   AARS1                                 4
# 1          1   ABCB6                                 2
# 2          2   ABCC6                                 1
# 3          3   ABCC8                                10
# 4          4   ABCC9                                 6
# ..       ...     ...                               ...
# 588      588    ZIC1                                 0
# 589      589   ZMIZ1                                 4
# 590      590  ZMYND8                                 1
# 591      591  ZNF292                                23
# 592      592  ZSWIM6                                 2
#
#      total_dom_annot_mis_plp_from_clinvar  \
# 0                                       2
# 1                                       1
# 2                                       0
# 3                                       7
# 4                                       6
# ..                                    ...
# 588                                     0
# 589                                     1
# 590                                     0
# 591                                     1
# 592                                     0
#
#      total_dom_annot_ns_plp_from_clinvar  \
# 0                                      0
# 1                                      0
# 2                                      1
# 3                                      0
# 4                                      0
# ..                                   ...
# 588                                    0
# 589                                    2
# 590                                    0
# 591                                    9
# 592                                    1
#
#      total_dom_annot_from_clinvar_and_omim_plp  added_mutations
# 0                                           10                6
# 1                                            8                6
# 2                                           74               73
# 3                                          272              262
# 4                                           63               57
# ..                                         ...              ...
# 588                                          5                5
# 589                                         25               21
# 590                                          1                0
# 591                                         47               24
# 592                                          3                1
#
# [593 rows x 7 columns]

# %%
# increase dpi of fig
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
# let's plot this now
# let's plot just the dominant data
cols = [
    "total_dom_annot_from_clinvar_and_omim_plp"
]

plot_data = [[x if x < 200 else 200 for x in dom_clean["total_dom_annot_from_clinvar_and_omim_plp"].values]]

fig, ax = plt.subplots(figsize=(5, 4.5))

vp = ax.violinplot(
    plot_data,
    showmeans=False,
    showmedians=True,
    showextrema=True
)

color_map=['#9f4a96']
for body, color in zip(vp["bodies"], color_map):
    body.set_facecolor(color)
    body.set_edgecolor("black")
    body.set_alpha(0.3)

# Median
vp["cmedians"].set_color("#757575")
vp["cmedians"].set_linewidth(2)

# Extrema (min/max + connecting bar)
for key in ["cmins", "cmaxes", "cbars"]:
    vp[key].set_color("#757575")
    vp[key].set_linewidth(1.5)

# bp = ax.boxplot(
#     plot_data
#     # showmeans=False,
#     # showmedians=True,
#     # showextrema=True
# )

ax.set_xticks(np.arange(1, len(plot_data) + 1))
ax.set_xticklabels(['D&D Group 1 Genes'], 
                   rotation=0)
color_map2 = ['#9f4a96']
for i, col in enumerate(plot_data, start=1):
    y = plot_data[i-1]
    x = np.random.normal(i, 0.04, size=len(y))  # jitter
    ax.scatter(x, y, s=10, alpha=0.5, color=color_map2[i-1])
#ax.set_yscale("log")
ax.set_ylabel("Pathogenic mutation count per gene", fontsize=12)

# ax.text(
#     0.94, 0.9,
#     "N = 593 D&D \nGroup 1 Genes",
#     transform=ax.transAxes,
#     ha="right",
#     va="top",
#     fontsize=10
# )

# # for body in vp["bodies"]:
# #     body.set_alpha(0.7)

# save
savedir="/Users/graceramey/Library/CloudStorage/Box-Box/capra_lab/projects/dominant_negative_disease_editing/figures/jupyter_notebook_savefigs"
plt.savefig(savedir + "/Pathogenic_Var_nums_tall.svg", format='svg', bbox_inches='tight',transparent=True)


plt.tight_layout()
plt.show()

# %%
dom_clean[dom_clean['gene'].isin(['MFN2', 'MYH7', 'NEFL', 'RHO','ALPL', 'COL4A4', 'VWF', 'PARN', 'STAT'])][['gene','total_dom_annot_from_clinvar_and_omim_plp']]
# Out:
#        gene  total_dom_annot_from_clinvar_and_omim_plp
# 31     ALPL                                        194
# 114  COL4A4                                        339
# 318    MFN2                                         55
# 333    MYH7                                        149
# 348    NEFL                                         44
# 372    PARN                                         70
# 434     RHO                                         86
# 577     VWF                                        159

# %%
data=pd.read_csv('/Users/graceramey/Library/CloudStorage/Box-Box/capra_lab/projects/dominant_negative_disease_editing/results/dnd_593_2026_02_19.csv')
data.rename(columns={'hgnc_symbol':'gene','post_mean':'s_het'},inplace=True)
data.columns
# Out:
# Index(['gene', 'GENE ID (HGNC)', 'DISEASE LABEL', 'DISEASE ID (MONDO)', 'MOI',
#        'CLASSIFICATION', 'HI Score', '%HI', 'pLI', 'LOEUF', 'total_plp',
#        'missense_plp', 'nonsense_plp', 'ensg', 'chrom', 'obs_lof', 'exp_lof',
#        'prior_mean', 's_het', 'post_lower_95', 'post_upper_95',
#        'indel_targetable_pre_NMD_assessment', 'num_indel_vars',
#        'crisproff_targetable', 'num_crisproff_vars', 'base_editable',
#        'num_base_editable_vars', 'excision_targetable', 'num_excision_vars',
#        'num_excision_pairs', 'HPO_term_list', 'Approved name',
#        'indel_pam_targetable', 'crisproff_pam_targetable',
#        'base_edit_pam_targetable', 'excision_pam_targetable',
#        'hets_across_strats', 'prop_hets_across_strats', 'num_indel_hets',
#        'indel_hets_prop', 'num_crisproff_hets', 'crisproff_hets_prop',
#        'num_base_edit_hets', 'base_edit_hets_prop', 'num_excision_hets',
#        'excision_hets_prop', 'hets_across_strats_prePAM',
#        'prop_hets_across_strats_prePAM', 'num_indel_hets_prePAM',
#        'indel_hets_prop_prePAM', 'num_crisproff_hets_prePAM',
#        'crisproff_hets_prop_prePAM', 'num_base_edit_hets_prePAM',
#        'base_edit_hets_prop_prePAM', 'num_excision_hets_prePAM',
#        'excision_hets_prop_prePAM', 'num_hets_targeted_four_guides_indels',
#        'indel_targetable_post_NMD_assessment', 'num_vars_inducing_NMD',
#        'indels_num_haps_four_guides_alg2', 'indels_num_hets_four_guides_alg2',
#        'indels_num_haps_all_guides_alg2', 'indels_num_hets_all_guides_alg2',
#        'indels_max_guides', 'CRISPRoff_num_haps_four_guides_alg2',
#        'CRISPRoff_num_hets_four_guides_alg2',
#        'CRISPRoff_num_haps_all_guides_alg2',
#        'CRISPRoff_num_hets_all_guides_alg2', 'CRISPRoff_max_guides',
#        'excision_num_haps_four_guides_alg2',
#        'excision_num_hets_four_guides_alg2',
#        'excision_num_haps_all_guides_alg2',
#        'excision_num_hets_all_guides_alg2', 'excision_max_guides',
#        'combined_base_edit_num_haps_four_guides_alg2',
#        'combined_base_edit_num_hets_four_guides_alg2',
#        'combined_base_edit_num_haps_all_guides_alg2',
#        'combined_base_edit_num_hets_all_guides_alg2',
#        'combined_base_edit_max_guides'],
#       dtype='object')

# %%
merged = dom_clean.merge(data[['gene','s_het']], on='gene',how='left')
merged.drop_duplicates(inplace=True)
merged
# Out:
#      counter    gene  total_dom_annot_plp_from_clinvar  \
# 0          0   AARS1                                 4
# 2          1   ABCB6                                 2
# 4          2   ABCC6                                 1
# 5          3   ABCC8                                10
# 7          4   ABCC9                                 6
# ..       ...     ...                               ...
# 732      588    ZIC1                                 0
# 733      589   ZMIZ1                                 4
# 734      590  ZMYND8                                 1
# 735      591  ZNF292                                23
# 736      592  ZSWIM6                                 2
#
#      total_dom_annot_mis_plp_from_clinvar  \
# 0                                       2
# 2                                       1
# 4                                       0
# 5                                       7
# 7                                       6
# ..                                    ...
# 732                                     0
# 733                                     1
# 734                                     0
# 735                                     1
# 736                                     0
#
#      total_dom_annot_ns_plp_from_clinvar  \
# 0                                      0
# 2                                      0
# 4                                      1
# 5                                      0
# 7                                      0
# ..                                   ...
# 732                                    0
# 733                                    2
# 734                                    0
# 735                                    9
# 736                                    1
#
#      total_dom_annot_from_clinvar_and_omim_plp  added_mutations     s_het
# 0                                           10                6  0.022459
# 2                                            8                6  0.000834
# 4                                           74               73  0.000681
# 5                                          272              262  0.008893
# 7                                           63               57  0.020637
# ..                                         ...              ...       ...
# 732                                          5                5  0.205882
# 733                                         25               21  0.209067
# 734                                          1                0  0.254357
# 735                                         47               24  0.217299
# 736                                          3                1  0.260329
#
# [593 rows x 8 columns]

# %%
merged[merged['s_het']<0.1]
# Out:
#      counter    gene  total_dom_annot_plp_from_clinvar  \
# 0          0   AARS1                                 4
# 2          1   ABCB6                                 2
# 4          2   ABCC6                                 1
# 5          3   ABCC8                                10
# 7          4   ABCC9                                 6
# ..       ...     ...                               ...
# 723      580    WFS1                                11
# 725      581  WNT10A                                 5
# 726      582   WNT5A                                 2
# 727      583  WRAP53                                 0
# 728      584   YARS1                                 2
#
#      total_dom_annot_mis_plp_from_clinvar  \
# 0                                       2
# 2                                       1
# 4                                       0
# 5                                       7
# 7                                       6
# ..                                    ...
# 723                                     9
# 725                                     3
# 726                                     2
# 727                                     0
# 728                                     2
#
#      total_dom_annot_ns_plp_from_clinvar  \
# 0                                      0
# 2                                      0
# 4                                      1
# 5                                      0
# 7                                      0
# ..                                   ...
# 723                                    1
# 725                                    2
# 726                                    0
# 727                                    0
# 728                                    0
#
#      total_dom_annot_from_clinvar_and_omim_plp  added_mutations     s_het
# 0                                           10                6  0.022459
# 2                                            8                6  0.000834
# 4                                           74               73  0.000681
# 5                                          272              262  0.008893
# 7                                           63               57  0.020637
# ..                                         ...              ...       ...
# 723                                         72               61  0.001000
# 725                                         95               90  0.001348
# 726                                          7                5  0.096404
# 727                                          0                0  0.017655
# 728                                          7                5  0.023600
#
# [363 rows x 8 columns]

# %%
# also generate for group 2 genes
# let's plot this now
# let's plot just the dominant data

# cols = [
#     "total_dom_annot_from_clinvar_and_omim_plp"
# ]

plot_data = [[x if x < 200 else 200 for x in dom_clean["total_dom_annot_from_clinvar_and_omim_plp"].values],
            [x if x<200 else 200 for x in (merged[merged['s_het']<0.1])['total_dom_annot_from_clinvar_and_omim_plp'].values]]

fig, ax = plt.subplots(figsize=(5, 4.5))

vp = ax.violinplot(
    plot_data,
    showmeans=False,
    showmedians=True,
    showextrema=True
)

color_map=['#9f4a96', '#3697d4']
for body, color in zip(vp["bodies"], color_map):
    body.set_facecolor(color)
    body.set_edgecolor("black")
    body.set_alpha(0.3)

# Median
vp["cmedians"].set_color("#757575")
vp["cmedians"].set_linewidth(2)

# Extrema (min/max + connecting bar)
for key in ["cmins", "cmaxes", "cbars"]:
    vp[key].set_color("#757575")
    vp[key].set_linewidth(1.5)

# bp = ax.boxplot(
#     plot_data
#     # showmeans=False,
#     # showmedians=True,
#     # showextrema=True
# )

ax.set_xticks(np.arange(1, len(plot_data) + 1))
ax.set_xticklabels(['D&D Group 1 Genes', 'D&D Group 2 Genes'], 
                   rotation=0)
color_map2 = ['#9f4a96', '#3697d4']
for i, col in enumerate(plot_data, start=1):
    y = plot_data[i-1]
    x = np.random.normal(i, 0.04, size=len(y))  # jitter
    ax.scatter(x, y, s=10, alpha=0.5, color=color_map2[i-1])
#ax.set_yscale("log")
ax.set_ylabel("Pathogenic mutation count per gene", fontsize=12)

# ax.text(
#     0.94, 0.9,
#     "N = 593 D&D \nGroup 1 Genes",
#     transform=ax.transAxes,
#     ha="right",
#     va="top",
#     fontsize=10
# )

# # for body in vp["bodies"]:
# #     body.set_alpha(0.7)

# save
savedir="/Users/graceramey/Library/CloudStorage/Box-Box/capra_lab/projects/dominant_negative_disease_editing/figures/jupyter_notebook_savefigs"
plt.savefig(savedir + "/Pathogenic_Var_nums_tall_g2.svg", format='svg', bbox_inches='tight',transparent=True)


plt.tight_layout()
plt.show()

# %%
print('D&D Group2 Gene Summary Statistics')
print(np.mean([x if x<200 else 200 for x in (merged[merged['s_het']<0.1])['total_dom_annot_from_clinvar_and_omim_plp'].values]))
print(np.median([x if x<200 else 200 for x in (merged[merged['s_het']<0.1])['total_dom_annot_from_clinvar_and_omim_plp'].values]))
# Out:
# D&D Group2 Gene Summary Statistics
# 26.380165289256198
# 9.0

# %%
dom_clean[dom_clean['gene']=='MFN2']
# Out:
#          gene  total_dom_annot_plp  total_dom_annot_mis_plp  \
# counter
# 318      MFN2                   32                       28
#
#          total_dom_annot_ns_plp  total_dom_annot_and_omim_plp  added_mutations
# counter
# 318                           3                            55               23

# %%
dom_clean[dom_clean['gene']=='NEFL']
# Out:
#          gene  total_dom_annot_plp  total_dom_annot_mis_plp  \
# counter
# 348      NEFL                    2                        2
#
#          total_dom_annot_ns_plp  total_dom_annot_and_omim_plp  added_mutations
# counter
# 348                           0                            44               42

# %%
dom_clean.sort_values('total_dom_annot_and_omim_plp', ascending=False)[0:20]
# Out:
#              gene  total_dom_annot_plp  total_dom_annot_mis_plp  \
# counter
# 112        COL1A2                   51                       42
# 114        COL4A4                   73                       36
# 32           ANK1                   18                        1
# 3           ABCC8                   10                        7
# 461      SERPING1                  170                       61
# 454          SDHA                   12                        4
# 75           CASR                   12                       11
# 117        COL6A2                   10                        4
# 31           ALPL                   10                        8
# 443          RYR1                   91                       69
# 345           NEB                    0                        0
# 9           ACTA1                   32                       31
# 444          RYR2                   19                       16
# 577           VWF                   44                       37
# 116        COL6A1                   13                        4
# 333          MYH7                  106                      100
# 301         LZTR1                   29                       10
# 48         ATP1A3                   29                       23
# 34           ANO5                    0                        0
# 524          TERT                    8                        5
#
#          total_dom_annot_ns_plp  total_dom_annot_and_omim_plp  added_mutations
# counter
# 112                           0                           565              514
# 114                           9                           339              266
# 32                           10                           277              259
# 3                             0                           272              262
# 461                          21                           262               92
# 454                           1                           244              232
# 75                            0                           238              226
# 117                           2                           204              194
# 31                            0                           194              184
# 443                           8                           193              102
# 345                           0                           177              177
# 9                             0                           177              145
# 444                           1                           169              150
# 577                           2                           159              115
# 116                           0                           152              139
# 333                           0                           149               43
# 301                           4                           147              118
# 48                            0                           141              112
# 34                            0                           140              140
# 524                           0                           139              131

# %%
dom_clean.sort_values('total_dom_annot_and_omim_plp', ascending=False, ignore_index=True)[95:110]
# Out:
#        gene  total_dom_annot_plp  total_dom_annot_mis_plp  \
# 95   ZNF292                   23                        1
# 96    CEBPA                    2                        0
# 97     KRAS                   18                       17
# 98     MYH9                   27                       21
# 99     RERE                    9                        2
# 100   KCNA2                   12                        9
# 101    NEFL                    2                        2
# 102   GANAB                   11                        2
# 103    TLK2                   14                        4
# 104    MYLK                    0                        0
# 105   KIF5A                   18                       11
# 106  PIK3R1                    8                        3
# 107  ZBTB20                   10                        5
# 108   KCNQ3                    6                        5
# 109     MPL                    2                        2
#
#      total_dom_annot_ns_plp  total_dom_annot_and_omim_plp  added_mutations
# 95                        9                            47               24
# 96                        0                            46               44
# 97                        0                            46               28
# 98                        1                            46               19
# 99                        0                            45               36
# 100                       1                            44               32
# 101                       0                            44               42
# 102                       2                            44               33
# 103                       5                            43               29
# 104                       0                            43               43
# 105                       1                            43               25
# 106                       2                            42               34
# 107                       1                            42               32
# 108                       0                            42               36
# 109                       0                            42               40

# %%
dom_clean[dom_clean['gene']=='MYH7']
# Out:
#          gene  total_dom_annot_plp  total_dom_annot_mis_plp  \
# counter
# 333      MYH7                  106                      100
#
#          total_dom_annot_ns_plp  total_dom_annot_and_omim_plp  added_mutations
# counter
# 333                           0                           149               43

# %%
# average and median values
print('Average number of pathogenic mutations per gene: ' + str(np.mean(dom_clean['total_dom_annot_and_omim_plp'])))
print('Median number of pathogenic mutations per gene: ' + str(np.median(dom_clean['total_dom_annot_and_omim_plp'])))
# Out:
# Average number of pathogenic mutations per gene: 26.93760539629005
# Median number of pathogenic mutations per gene: 10.0

# %%
# Percent of genes with more than 4 dominant pathogenic mutations
total_genes = len(dom_clean['gene'].unique())
four_guides = dom_clean[dom_clean['total_dom_annot_and_omim_plp']>=4]
print('Percent of all D&D genes with more than 4 dominant pathogenic mutations: ' + str((len(four_guides.gene)/total_genes)*100) + '%')
print('Number of D&D genes with more than 4 dominant pathogenic mutations: ' + str(len(four_guides.gene)))
# Out:
# Percent of all D&D genes with more than 4 dominant pathogenic mutations: 75.21079258010118%
# Number of D&D genes with more than 4 dominant pathogenic mutations: 446

# %%
g2_genes.sort_values('total_dom_annot_and_omim_plp', ascending=False)[0:20]
# Out:
#          gene  total_dom_annot_plp  total_dom_annot_mis_plp  \
# 180    COL4A4                   73                       36
# 5       ABCC8                   10                        7
# 681  SERPING1                  170                       61
# 673      SDHA                   12                        4
# 118      CASR                   12                       11
# 184    COL6A2                   10                        4
# 51       ALPL                   10                        8
# 654      RYR1                   91                       69
# 17      ACTA1                   32                       31
# 519       NEB                    0                        0
# 657      RYR2                   19                       16
# 834       VWF                   44                       37
# 182    COL6A1                   13                        4
# 497      MYH7                  106                      100
# 450     LZTR1                   29                       10
# 56       ANO5                    0                        0
# 760      TERT                    8                        5
# 679  SERPINC1                   30                       22
# 186    COL6A3                    2                        1
# 512     MYO7A                    5                        4
#
#      total_dom_annot_ns_plp  total_dom_annot_and_omim_plp  added_mutations  \
# 180                       9                           339              266
# 5                         0                           272              262
# 681                      21                           262               92
# 673                       1                           244              232
# 118                       0                           238              226
# 184                       2                           204              194
# 51                        0                           194              184
# 654                       8                           193              102
# 17                        0                           177              145
# 519                       0                           177              177
# 657                       1                           169              150
# 834                       2                           159              115
# 182                       0                           152              139
# 497                       0                           149               43
# 450                       4                           147              118
# 56                        0                           140              140
# 760                       0                           139              131
# 679                       2                           139              109
# 186                       0                           132              130
# 512                       0                           129              124
#
#         s_het
# 180  0.014433
# 5    0.008893
# 681  0.051901
# 673  0.047165
# 118  0.052534
# 184  0.011007
# 51   0.011099
# 654  0.022355
# 17   0.008776
# 519  0.018070
# 657  0.071907
# 834  0.012617
# 182  0.093841
# 497  0.018570
# 450  0.000665
# 56   0.004078
# 760  0.079548
# 679  0.065153
# 186  0.027337
# 512  0.004961

# %%
# average and median values
print('Average number of pathogenic mutations per gene: ' + str(np.mean(g2_genes['total_dom_annot_and_omim_plp'])))
print('Median number of pathogenic mutations per gene: ' + str(np.median(g2_genes['total_dom_annot_and_omim_plp'])))
# Out:
# Average number of pathogenic mutations per gene: 27.36914600550964
# Median number of pathogenic mutations per gene: 9.0

# %%
# Percent of genes with more than 4 dominant pathogenic mutations
total_genes = len(g2_genes['gene'].unique())
four_guides = g2_genes[g2_genes['total_dom_annot_and_omim_plp']>=4]
print('Percent of all D&D genes with more than 4 dominant pathogenic mutations: ' + str((len(four_guides.gene)/total_genes)*100) + '%')
print('Number of D&D genes with more than 4 dominant pathogenic mutations: ' + str(len(four_guides.gene)))
# Out:
# Percent of all D&D genes with more than 4 dominant pathogenic mutations: 72.1763085399449%
# Number of D&D genes with more than 4 dominant pathogenic mutations: 262

# %%
# plot adjusted for gene length
gl2 = exon_df[['hgnc_symbol','start_position', 'end_position']].drop_duplicates()
gl2.rename(columns={'hgnc_symbol':'gene'},inplace=True)
gl2['gene_length']=gl2['end_position']-gl2['start_position']
dc_merged = dom_clean.merge(gl2, on='gene', how='left')
dc_merged['dom_omim_plp_gl_normalized'] = dc_merged['total_dom_annot_and_omim_plp']/dc_merged['gene_length']

# %%
dc_merged
# Out:
#        gene  total_dom_annot_plp  total_dom_annot_mis_plp  \
# 0     AARS1                    4                        2
# 1     ABCB6                    2                        1
# 2     ABCC6                    1                        0
# 3     ABCC8                   10                        7
# 4     ABCC9                    6                        6
# ..      ...                  ...                      ...
# 588    ZIC1                    0                        0
# 589   ZMIZ1                    4                        1
# 590  ZMYND8                    1                        0
# 591  ZNF292                   23                        1
# 592  ZSWIM6                    2                        0
#
#      total_dom_annot_ns_plp  total_dom_annot_and_omim_plp  added_mutations  \
# 0                         0                            10                6
# 1                         0                             8                6
# 2                         1                            74               73
# 3                         0                           272              262
# 4                         0                            63               57
# ..                      ...                           ...              ...
# 588                       0                             5                5
# 589                       2                            25               21
# 590                       0                             1                0
# 591                       9                            47               24
# 592                       1                             3                1
#
#      start_position  end_position  gene_length  dom_omim_plp_gl_normalized
# 0          70251983      70289707        37724                    0.000265
# 1         219209766     219219012         9246                    0.000865
# 2          16149565      16223637        74072                    0.000999
# 3          17392498      17476894        84396                    0.003223
# 4          21797389      21942543       145154                    0.000434
# ..              ...           ...          ...                         ...
# 588       147393422     147510293       116871                    0.000043
# 589        79068929      79316550       247621                    0.000101
# 590        47209214      47357804       148590                    0.000007
# 591        87151803      87265943       114140                    0.000412
# 592        61332258      61546172       213914                    0.000014
#
# [593 rows x 10 columns]

# %%
# plot the normalized values
cols = [
    'dom_omim_plp_gl_normalized'
]

plot_data = [dc_merged[col].values for col in cols]
fig, ax = plt.subplots(figsize=(5, 4))

vp = ax.violinplot(
    plot_data,
    showmeans=False,
    showmedians=True,
    showextrema=True
)

# bp = ax.boxplot(
#     plot_data
#     # showmeans=False,
#     # showmedians=True,
#     # showextrema=True
# )

ax.set_xticks(np.arange(1, len(cols) + 1))
ax.set_xticklabels(['Dominant\nPathogenic Mutations'], 
                   rotation=0)

for i, col in enumerate(cols, start=1):
    y = dc_merged[col].values
    x = np.random.normal(i, 0.04, size=len(y))  # jitter
    ax.scatter(x, y, s=10, alpha=0.6, color="black")
ax.set_yscale("log")
ax.set_ylabel("Pathogenic mutation count per gene", fontsize=12)

ax.text(
    0.94, 0.9,
    "N = 593 D&D \nGroup 1 Genes",
    transform=ax.transAxes,
    ha="right",
    va="top",
    fontsize=10
)

# for body in vp["bodies"]:
#     body.set_alpha(0.7)
plt.tight_layout()
plt.show()

# %%
# save this revised dominant mutation information
dom_clean.rename(columns={'total_dom_annot_plp':'total_dom_annot_plp_from_clinvar', 'total_dom_annot_mis_plp':'total_dom_annot_mis_plp_from_clinvar', 'total_dom_annot_ns_plp':'total_dom_annot_ns_plp_from_clinvar', 'total_dom_annot_and_omim_plp':'total_dom_annot_from_clinvar_and_omim_plp', 'added_dom_mutations_from_omim':'added_mutations'}, inplace=True)
dom_clean.to_csv('/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/ClinVar_Omim_dom_annot.csv')

# %% [markdown]
# # Reload data to re-plot

# %%
dom_clean = pd.read_csv("/Users/graceramey/Desktop/UCSF/CapraLab/Conklin_Collabs/Data/GeneSets/dHS/2025-11-13/ClinVar_checkpoints/ClinVar_Omim_dom_annot.csv")
dom_clean
# Out:
#      counter    gene  total_dom_annot_plp_from_clinvar  \
# 0          0   AARS1                                 4
# 1          1   ABCB6                                 2
# 2          2   ABCC6                                 1
# 3          3   ABCC8                                10
# 4          4   ABCC9                                 6
# ..       ...     ...                               ...
# 588      588    ZIC1                                 0
# 589      589   ZMIZ1                                 4
# 590      590  ZMYND8                                 1
# 591      591  ZNF292                                23
# 592      592  ZSWIM6                                 2
#
#      total_dom_annot_mis_plp_from_clinvar  \
# 0                                       2
# 1                                       1
# 2                                       0
# 3                                       7
# 4                                       6
# ..                                    ...
# 588                                     0
# 589                                     1
# 590                                     0
# 591                                     1
# 592                                     0
#
#      total_dom_annot_ns_plp_from_clinvar  \
# 0                                      0
# 1                                      0
# 2                                      1
# 3                                      0
# 4                                      0
# ..                                   ...
# 588                                    0
# 589                                    2
# 590                                    0
# 591                                    9
# 592                                    1
#
#      total_dom_annot_from_clinvar_and_omim_plp  added_mutations
# 0                                           10                6
# 1                                            8                6
# 2                                           74               73
# 3                                          272              262
# 4                                           63               57
# ..                                         ...              ...
# 588                                          5                5
# 589                                         25               21
# 590                                          1                0
# 591                                         47               24
# 592                                          3                1
#
# [593 rows x 7 columns]

# %%
# pick out a few additional genes to highlight, based on broad organ system involvements
# (right now we've seen cardio, nervous system, how about some immune and others)
genes_to_highlight = ['BEST1','RHO', 'TNPO3','INS','ALPL','STAT1', 'SFTPA1','VWF','NAF1', 'CLCN7', 'FAM111B','PARN']
vis_df = dom_clean[dom_clean['gene'].isin(genes_to_highlight)][['gene', 'total_dom_annot_from_clinvar_and_omim_plp']]
vis_df.rename(columns={'total_dom_annot_from_clinvar_and_omim_plp':'dom_path_muts'},inplace=True)
vis_df[vis_df['dom_path_muts']>5]
# Out:
#       gene  dom_path_muts
# 31    ALPL            194
# 53   BEST1             56
# 105  CLCN7             12
# 372   PARN             70
# 434    RHO             86
# 507  STAT1             68
# 541  TNPO3              7
# 577    VWF            159

# %%
# let's plot the violin in grey, but make each point the color of which D&D group

# %% [markdown]
# ## Old Code

# %%
cur_uid_result
# Out:
# {'uid': '41236',
#  'obj_type': 'single nucleotide variant',
#  'accession': 'VCV000041236',
#  'accession_version': 'VCV000041236.63',
#  'title': 'NM_006158.5(NEFL):c.293A>G (p.Asn98Ser)',
#  'variation_set': [{'measure_id': '49660',
#    'variation_xrefs': [{'db_source': 'ClinGen', 'db_id': 'CA217547'},
#     {'db_source': 'UniProtKB', 'db_id': 'P07196#VAR_016023'},
#     {'db_source': 'OMIM', 'db_id': '162280.0011'},
#     {'db_source': 'dbSNP', 'db_id': '58982919'}],
#    'variation_name': 'NM_006158.5(NEFL):c.293A>G (p.Asn98Ser)',
#    'cdna_change': 'c.293A>G',
#    'aliases': ['NEFL, ASN98SER (rs58982919)'],
#    'variation_loc': [{'status': 'current',
#      'assembly_name': 'GRCh38',
#      'chr': '8',
#      'band': '8p21.2',
#      'start': '24956223',
#      'stop': '24956223',
#      'inner_start': '',
#      'inner_stop': '',
#      'outer_start': '',
#      'outer_stop': '',
#      'display_start': '24956223',
#      'display_stop': '24956223',
#      'assembly_acc_ver': 'GCF_000001405.38',
#      'annotation_release': '',
#      'alt': '',
#      'ref': ''},
#     {'status': 'previous',
#      'assembly_name': 'GRCh37',
#      'chr': '8',
#      'band': '8p21.2',
#      'start': '24813737',
#      'stop': '24813737',
#      'inner_start': '',
#      'inner_stop': '',
#      'outer_start': '',
#      'outer_stop': '',
#      'display_start': '24813737',
#      'display_stop': '24813737',
#      'assembly_acc_ver': 'GCF_000001405.25',
#      'annotation_release': '',
#      'alt': '',
#      'ref': ''}],
#    'allele_freq_set': [],
#    'variant_type': 'single nucleotide variant',
#    'canonical_spdi': 'NC_000008.11:24956222:T:C',
#    'common_name': ''}],
#  'supporting_submissions': {'scv': ['SCV000058067',
#    'SCV000088249',
#    'SCV000279221',
#    'SCV000639659',
#    'SCV000693719',
#    'SCV000999783',
#    'SCV001190244',
#    'SCV001245758',
#    'SCV001337494',
#    'SCV001368210',
#    'SCV001429941',
#    'SCV002012110',
#    'SCV002102851',
#    'SCV004101323',
#    'SCV004848847'],
#   'rcv': ['RCV000034136',
#    'RCV000057136',
#    'RCV000585792',
#    'RCV000554079',
#    'RCV000857201',
#    'RCV001027680',
#    'RCV001843465',
#    'RCV005867811']},
#  'germline_classification': {'description': 'Pathogenic/Likely pathogenic',
#   'last_evaluated': '2024/08/11 00:00',
#   'review_status': 'criteria provided, multiple submitters, no conflicts',
#   'fda_recognized_database': '',
#   'trait_set': [{'trait_xrefs': [{'db_source': 'MedGen', 'db_id': 'C0018784'},
#      {'db_source': 'MeSH', 'db_id': 'D006319'},
#      {'db_source': 'MONDO', 'db_id': 'MONDO:0020678'},
#      {'db_source': 'Human Phenotype Ontology', 'db_id': 'HP:0000407'},
#      {'db_source': 'Human Phenotype Ontology', 'db_id': 'HP:0000374'},
#      {'db_source': 'Human Phenotype Ontology', 'db_id': 'HP:0001753'},
#      {'db_source': 'Human Phenotype Ontology', 'db_id': 'HP:0001916'},
#      {'db_source': 'Human Phenotype Ontology', 'db_id': 'HP:0008538'},
#      {'db_source': 'Human Phenotype Ontology', 'db_id': 'HP:0008553'},
#      {'db_source': 'Human Phenotype Ontology', 'db_id': 'HP:0008565'},
#      {'db_source': 'Human Phenotype Ontology', 'db_id': 'HP:0008576'},
#      {'db_source': 'Human Phenotype Ontology', 'db_id': 'HP:0008611'},
#      {'db_source': 'Human Phenotype Ontology', 'db_id': 'HP:0008613'},
#      {'db_source': 'Human Phenotype Ontology', 'db_id': 'HP:0008614'}],
#     'trait_name': 'Sensorineural hearing loss disorder'},
#    {'trait_xrefs': [{'db_source': 'MedGen', 'db_id': 'C0008073'}],
#     'trait_name': 'Developmental disorder'},
#    {'trait_xrefs': [], 'trait_name': 'NEFL-related disorder'},
#    {'trait_xrefs': [{'db_source': 'Orphanet', 'db_id': '99939'},
#      {'db_source': 'MedGen', 'db_id': 'C1843225'},
#      {'db_source': 'MONDO', 'db_id': 'MONDO:0011894'},
#      {'db_source': 'OMIM', 'db_id': '607684'}],
#     'trait_name': 'Charcot-Marie-Tooth disease type 2E'},
#    {'trait_xrefs': [{'db_source': 'Orphanet', 'db_id': '101085'},
#      {'db_source': 'MedGen', 'db_id': 'C1843164'},
#      {'db_source': 'MONDO', 'db_id': 'MONDO:0011902'},
#      {'db_source': 'OMIM', 'db_id': '607734'}],
#     'trait_name': 'Charcot-Marie-Tooth disease type 1F'},
#    {'trait_xrefs': [{'db_source': 'MedGen', 'db_id': 'C4693509'},
#      {'db_source': 'MONDO', 'db_id': 'MONDO:0036484'},
#      {'db_source': 'OMIM', 'db_id': '617882'}],
#     'trait_name': 'Charcot-Marie-Tooth disease, dominant intermediate G'},
#    {'trait_xrefs': [{'db_source': 'Orphanet', 'db_id': '166'},
#      {'db_source': 'MedGen', 'db_id': 'C0007959'},
#      {'db_source': 'MONDO', 'db_id': 'MONDO:0015626'},
#      {'db_source': 'OMIM', 'db_id': 'PS118220'}],
#     'trait_name': 'Charcot-Marie-Tooth disease'},
#    {'trait_xrefs': [{'db_source': 'MedGen', 'db_id': 'C3661900'}],
#     'trait_name': 'not provided'},
#    {'trait_xrefs': [{'db_source': 'Orphanet', 'db_id': '99939'},
#      {'db_source': 'MedGen', 'db_id': 'C1843225'},
#      {'db_source': 'MONDO', 'db_id': 'MONDO:0011894'},
#      {'db_source': 'OMIM', 'db_id': '607684'}],
#     'trait_name': 'Charcot-Marie-Tooth disease type 2E'},
#    {'trait_xrefs': [{'db_source': 'Orphanet', 'db_id': '101085'},
#      {'db_source': 'MedGen', 'db_id': 'C1843164'},
#      {'db_source': 'MONDO', 'db_id': 'MONDO:0011902'},
#      {'db_source': 'OMIM', 'db_id': '607734'}],
#     'trait_name': 'Charcot-Marie-Tooth disease type 1F'}]},
#  'clinical_impact_classification': {'description': '',
#   'last_evaluated': '1/01/01 00:00',
#   'review_status': '',
#   'fda_recognized_database': '',
#   'trait_set': []},
#  'oncogenicity_classification': {'description': '',
#   'last_evaluated': '1/01/01 00:00',
#   'review_status': '',
#   'fda_recognized_database': '',
#   'trait_set': []},
#  'record_status': '',
#  'gene_sort': 'NEFL',
#  'chr_sort': '08',
#  'location_sort': '00000000000024956223',
#  'variation_set_name': '',
#  'variation_set_id': '',
#  'genes': [{'symbol': 'NEFL',
#    'geneid': '4747',
#    'strand': '-',
#    'source': 'submitted'}],
#  'molecular_consequence_list': ['missense variant'],
#  'protein_change': 'N98S',
#  'fda_recognized_database': ''}

# %%
# second query for disease matching dominance
# here we'll do a broader search and some fancy filtering for dominant using ontology mapping
term = (
        f'{gene}[gene] AND single_gene[prop] AND "moi autosomal dominant"[prop] AND '
        '(pathogenic[clinsig] OR "likely pathogenic"[clinsig] OR "pathogenic/likely pathogenic"[clinsig])'
    )
    
esearch_params = {"db": "clinvar", "term": term, "retmode": "json", "retmax": 100000}
r = request_with_429_retry("GET", base_esearch, params=esearch_params, timeout=30)
esearch_data = r.json()

dom_annot_ids = esearch_data["esearchresult"]["idlist"]


term2 = (
    f'{gene}[gene] AND single_gene[prop] AND '
    '(pathogenic[clinsig] OR "likely pathogenic"[clinsig] OR "pathogenic/likely pathogenic"[clinsig])'
)
esearch_params = {"db": "clinvar", "term": term2, "retmode": "json", "retmax": 100000}
r = request_with_429_retry("GET", base_esearch, params=esearch_params, timeout=30)
esearch_data = r.json()
cur_ids2 = esearch_data["esearchresult"]["idlist"]

if cur_ids2:
    for post_batch in batched(cur_ids2, 5000):
        webenv, query_key = epost_ids("clinvar", post_batch)

        retstart = 0
        while retstart < len(post_batch):
            esum_data = esummary_from_history(
                "clinvar",
                webenv,
                query_key,
                retstart=retstart,
                retmax=ESUMMARY_PAGE_SIZE,
            )
            # check if the uid has already been analyzed
            for uid in esum_data.get("result", {}).get("uids", []):
                if uid not in dom_annot_ids:
                    cur_uid_result = esum_data["result"].get(uid, {})

                    germ_desc = (
                        cur_uid_result
                        .get("germline_classification", {})
                        .get("description", "")
                        .strip()
                    )
                    if germ_desc not in ALLOWED_GERMLINE:
                        continue
                        
                    # get trait information for the current variant
                    trait_set = (cur_uid_result
                                .get("germline_classification", {})
                                .get("trait_set", []))
                    source_to_ids = defaultdict(list)
                    
                    # of the multiple trait entries, store ontology sources with their ids that we'll use for lookup
                    for entry in trait_set:
                        for xref in entry.get("trait_xrefs", []):
                            source_to_ids[xref["db_source"]].append(xref["db_id"])
                    source_to_ids = dict(source_to_ids)

                    # if OMIM ids are available, look those up using OMIM API
                    # otherwise, map MONDO id to OMIM
                    # notice how we're being very relaxed in stringency here-->
                    # if any one of these disease terms is associated with dominance, we'll consider the mutation dominant
                    var_assoc_with_dominance=False
                    source_keys = list(source_to_ids.keys())
                    omim_query_ids=[]
                    if 'OMIMPS' in source_keys:
                        omim_query_ids = omim_query_ids + source_to_ids['OMIMPS']
                    elif ('OMIM' in source_keys):
                        omim_query_ids = omim_query_ids + source_to_ids['OMIM']
                    elif ('MONDO' in source_keys):
                        # map to OMIM first
                        for mondo_id in source_to_ids['MONDO']:
                            cur_xrefs = mondo_xrefs(mondo_id)
                            # isolate any 'OMIM' containing elements from cur_xrefs
                            if any('OMIM' in element for element in cur_xrefs):
                                omim_query_ids = omim_query_ids + [
                                        x.split(":")[1] for x in cur_xrefs
                                        if x.startswith(("OMIM", "OMIMPS"))]
                    # run omim query on resulting ids
                    if len(omim_query_ids)>0:
                        #try:
                        json_data = query_omim_safe(omim_query_ids)
                        # except requests.HTTPError as e:
                        #     print(f"OMIM query failed for IDs {omim_query_ids}: {e}")
                        #     json_data = None
                    
                        if json_data:
                            # OMIM JSON structure: data['omim']['entryList'] is a list of entries
                            for entry_wrapper in json_data.get("omim", {}).get("entryList", []):
                                entry = entry_wrapper.get("entry", {})
                                mim_number = entry.get("mimNumber")
                                #print('mim_number')
                                clinicalSynopsis_inheritance=entry.get("clinicalSynopsis",{}).get("inheritance",{})
                                #print(clinicalSynopsis_inheritance)
                                pheno_map_inheritance_list=[]
                                for list_item in entry.get("phenotypeMapList", {}):
                                    pheno_inheritance=list_item.get("phenotypeMap",{}).get("phenotypeInheritance")
                                    if pheno_inheritance:
                                        pheno_map_inheritance_list.append(pheno_inheritance)
                                
                                # check if any of the listed phenotypes have autosomal dominant annotations in OMIM
                                if ('Autosomal dominant' in clinicalSynopsis_inheritance) or (any('Autosomal dominant' in str(x) for x in pheno_map_inheritance_list)):
                                    var_assoc_with_dominance=True
                                    break
                        else:
                            print(f"Skipping OMIM check for these IDs: {omim_query_ids} due to rate limit")
                    # check if the mutation was associatied with autosomal dominant disorders
                    if var_assoc_with_dominance:
                       p_lp_mutation_counter += 1

                    mcons = cur_uid_result.get("molecular_consequence_list", [])
                    mcons_text = " ".join(
                        (mc.get("type", "") if isinstance(mc, dict) else str(mc))
                        for mc in mcons
                    ).lower()

                    if "missense" in mcons_text:
                        mis_plp_mutation_counter += 1
                    if ("nonsense" in mcons_text) or ("stop_gained" in mcons_text):
                        ns_plp_mutation_counter += 1


            retstart += ESUMMARY_PAGE_SIZE
            time.sleep(0.35)

# %%
gene='NEFL'
term = (
    f'{gene}[gene] AND single_gene[prop] AND "moi autosomal dominant"[prop] AND '
    '(pathogenic[clinsig] OR "likely pathogenic"[clinsig] OR "pathogenic/likely pathogenic"[clinsig])'
)

esearch_params = {"db": "clinvar", "term": term, "retmode": "json", "retmax": 100000}
r = request_with_429_retry("GET", base_esearch, params=esearch_params, timeout=30)
esearch_data = r.json()

cur_ids = esearch_data["esearchresult"]["idlist"]

# STRICT aggregate germline P/LP-only counts
p_lp_mutation_counter = 0
mis_plp_mutation_counter = 0
ns_plp_mutation_counter = 0

if cur_ids:
    for post_batch in batched(cur_ids, 5000):
        webenv, query_key = epost_ids("clinvar", post_batch)

        retstart = 0
        while retstart < len(post_batch):
            esum_data = esummary_from_history(
                "clinvar",
                webenv,
                query_key,
                retstart=retstart,
                retmax=ESUMMARY_PAGE_SIZE,
            )
            #print(len(esum_data.get("result", {}).get("uids", [])))
            for uid in esum_data.get("result", {}).get("uids", []):
                cur_uid_result = esum_data["result"].get(uid, {})

                germ_desc = (
                    cur_uid_result
                    .get("germline_classification", {})
                    .get("description", "")
                    .strip()
                )
                if germ_desc not in ALLOWED_GERMLINE:
                    continue

                p_lp_mutation_counter += 1

                mcons = cur_uid_result.get("molecular_consequence_list", [])
                mcons_text = " ".join(
                    (mc.get("type", "") if isinstance(mc, dict) else str(mc))
                    for mc in mcons
                ).lower()

                if "missense" in mcons_text:
                    mis_plp_mutation_counter += 1
                if ("nonsense" in mcons_text) or ("stop_gained" in mcons_text):
                    ns_plp_mutation_counter += 1

            retstart += ESUMMARY_PAGE_SIZE
            time.sleep(0.35)

# that was the specific query for 'moi dominant'
# now, do a fuzzy string match for the dominant disease name on the vars that were left out
# to get a more accurate count of dominant p/lp mutations

# broaden the clinvar search
term2 = (
    f'{gene}[gene] AND single_gene[prop] AND '
    '(pathogenic[clinsig] OR "likely pathogenic"[clinsig] OR "pathogenic/likely pathogenic"[clinsig])'
)
esearch_params = {"db": "clinvar", "term": term2, "retmode": "json", "retmax": 100000}
r = request_with_429_retry("GET", base_esearch, params=esearch_params, timeout=30)
esearch_data = r.json()
cur_ids2 = esearch_data["esearchresult"]["idlist"]

if cur_ids2:
    for post_batch in batched(cur_ids2, 5000):
        webenv, query_key = epost_ids("clinvar", post_batch)

        retstart = 0
        while retstart < len(post_batch):
            esum_data = esummary_from_history(
                "clinvar",
                webenv,
                query_key,
                retstart=retstart,
                retmax=ESUMMARY_PAGE_SIZE,
            )
            # check if the uid has already been analyzed
            for uid in esum_data.get("result", {}).get("uids", []):
                if uid not in cur_ids:
                    cur_uid_result = esum_data["result"].get(uid, {})

                    germ_desc = (
                        cur_uid_result
                        .get("germline_classification", {})
                        .get("description", "")
                        .strip()
                    )
                    if germ_desc not in ALLOWED_GERMLINE:
                        continue

                    p_lp_mutation_counter += 1

                    mcons = cur_uid_result.get("molecular_consequence_list", [])
                    mcons_text = " ".join(
                        (mc.get("type", "") if isinstance(mc, dict) else str(mc))
                        for mc in mcons
                    ).lower()

                    if "missense" in mcons_text:
                        mis_plp_mutation_counter += 1
                    if ("nonsense" in mcons_text) or ("stop_gained" in mcons_text):
                        ns_plp_mutation_counter += 1


            retstart += ESUMMARY_PAGE_SIZE
            time.sleep(0.35)
# Out:
# 429 from esearch.fcgi ; sleeping 1.0s and retrying…

# %%
cur_uid_result
# Out:
# {'uid': '14028',
#  'obj_type': 'single nucleotide variant',
#  'accession': 'VCV000014028',
#  'accession_version': 'VCV000014028.2',
#  'title': 'NM_006158.5(NEFL):c.995A>C (p.Gln332Pro)',
#  'variation_set': [{'measure_id': '29067',
#    'variation_xrefs': [{'db_source': 'ClinGen', 'db_id': 'CA217588'},
#     {'db_source': 'UniProtKB', 'db_id': 'P07196#VAR_009703'},
#     {'db_source': 'OMIM', 'db_id': '162280.0001'},
#     {'db_source': 'dbSNP', 'db_id': '59443585'}],
#    'variation_name': 'NM_006158.5(NEFL):c.995A>C (p.Gln332Pro)',
#    'cdna_change': 'c.995A>C',
#    'aliases': ['NEFL, GLN333PRO', 'Q333P'],
#    'variation_loc': [{'status': 'current',
#      'assembly_name': 'GRCh38',
#      'chr': '8',
#      'band': '8p21.2',
#      'start': '24955521',
#      'stop': '24955521',
#      'inner_start': '',
#      'inner_stop': '',
#      'outer_start': '',
#      'outer_stop': '',
#      'display_start': '24955521',
#      'display_stop': '24955521',
#      'assembly_acc_ver': 'GCF_000001405.38',
#      'annotation_release': '',
#      'alt': '',
#      'ref': ''},
#     {'status': 'previous',
#      'assembly_name': 'GRCh37',
#      'chr': '8',
#      'band': '8p21.2',
#      'start': '24813035',
#      'stop': '24813035',
#      'inner_start': '',
#      'inner_stop': '',
#      'outer_start': '',
#      'outer_stop': '',
#      'display_start': '24813035',
#      'display_stop': '24813035',
#      'assembly_acc_ver': 'GCF_000001405.25',
#      'annotation_release': '',
#      'alt': '',
#      'ref': ''}],
#    'allele_freq_set': [],
#    'variant_type': 'single nucleotide variant',
#    'canonical_spdi': 'NC_000008.11:24955520:T:G',
#    'common_name': ''}],
#  'supporting_submissions': {'scv': ['SCV000035328',
#    'SCV000088264',
#    'SCV000553805'],
#   'rcv': ['RCV000057151', 'RCV000015072']},
#  'germline_classification': {'description': 'Pathogenic',
#   'last_evaluated': '2016/11/03 00:00',
#   'review_status': 'criteria provided, single submitter',
#   'fda_recognized_database': '',
#   'trait_set': [{'trait_xrefs': [{'db_source': 'Orphanet', 'db_id': '99939'},
#      {'db_source': 'MedGen', 'db_id': 'C1843225'},
#      {'db_source': 'MONDO', 'db_id': 'MONDO:0011894'},
#      {'db_source': 'OMIM', 'db_id': '607684'}],
#     'trait_name': 'Charcot-Marie-Tooth disease type 2E'}]},
#  'clinical_impact_classification': {'description': '',
#   'last_evaluated': '1/01/01 00:00',
#   'review_status': '',
#   'fda_recognized_database': '',
#   'trait_set': []},
#  'oncogenicity_classification': {'description': '',
#   'last_evaluated': '1/01/01 00:00',
#   'review_status': '',
#   'fda_recognized_database': '',
#   'trait_set': []},
#  'record_status': '',
#  'gene_sort': 'NEFL',
#  'chr_sort': '08',
#  'location_sort': '00000000000024955521',
#  'variation_set_name': '',
#  'variation_set_id': '',
#  'genes': [{'symbol': 'NEFL',
#    'geneid': '4747',
#    'strand': '-',
#    'source': 'submitted'}],
#  'molecular_consequence_list': ['missense variant'],
#  'protein_change': 'Q332P',
#  'fda_recognized_database': ''}

# %%
cur_uid_result
# Out:
# {'uid': '431797',
#  'obj_type': 'single nucleotide variant',
#  'accession': 'VCV000431797',
#  'accession_version': 'VCV000431797.23',
#  'title': 'NM_020928.2(ZSWIM6):c.2737C>T (p.Arg913Ter)',
#  'variation_set': [{'measure_id': '425299',
#    'variation_xrefs': [{'db_source': 'ClinGen', 'db_id': 'CA359946038'},
#     {'db_source': 'OMIM', 'db_id': '615951.0002'},
#     {'db_source': 'dbSNP', 'db_id': '1554041295'}],
#    'variation_name': 'NM_020928.2(ZSWIM6):c.2737C>T (p.Arg913Ter)',
#    'cdna_change': 'c.2737C>T',
#    'aliases': [],
#    'variation_loc': [{'status': 'current',
#      'assembly_name': 'GRCh38',
#      'chr': '5',
#      'band': '5q12.1',
#      'start': '61541917',
#      'stop': '61541917',
#      'inner_start': '',
#      'inner_stop': '',
#      'outer_start': '',
#      'outer_stop': '',
#      'display_start': '61541917',
#      'display_stop': '61541917',
#      'assembly_acc_ver': 'GCF_000001405.38',
#      'annotation_release': '',
#      'alt': '',
#      'ref': ''},
#     {'status': 'previous',
#      'assembly_name': 'GRCh37',
#      'chr': '5',
#      'band': '5q12.1',
#      'start': '60837744',
#      'stop': '60837744',
#      'inner_start': '',
#      'inner_stop': '',
#      'outer_start': '',
#      'outer_stop': '',
#      'display_start': '60837744',
#      'display_stop': '60837744',
#      'assembly_acc_ver': 'GCF_000001405.25',
#      'annotation_release': '',
#      'alt': '',
#      'ref': ''}],
#    'allele_freq_set': [],
#    'variant_type': 'single nucleotide variant',
#    'canonical_spdi': 'NC_000005.10:61541916:C:T',
#    'common_name': ''}],
#  'supporting_submissions': {'scv': ['SCV000680486',
#    'SCV000890451',
#    'SCV000958315',
#    'SCV000588874',
#    'SCV001712257',
#    'SCV001760164',
#    'SCV002822873',
#    'SCV004104534',
#    'SCV005199033',
#    'SCV005878805',
#    'SCV005905966',
#    'SCV006474698'],
#   'rcv': ['RCV000590997',
#    'RCV000578491',
#    'RCV000760560',
#    'RCV003403147',
#    'RCV005781979']},
#  'germline_classification': {'description': 'Pathogenic/Likely pathogenic',
#   'last_evaluated': '2025/08/27 00:00',
#   'review_status': 'criteria provided, multiple submitters, no conflicts',
#   'fda_recognized_database': '',
#   'trait_set': [{'trait_xrefs': [{'db_source': 'MedGen', 'db_id': 'C4693405'},
#      {'db_source': 'MONDO', 'db_id': 'MONDO:0060642'},
#      {'db_source': 'OMIM', 'db_id': '617865'}],
#     'trait_name': 'Neurodevelopmental disorder with movement abnormalities, abnormal gait, and autistic features'},
#    {'trait_xrefs': [], 'trait_name': 'ZSWIM6-related disorder'},
#    {'trait_xrefs': [{'db_source': 'MedGen', 'db_id': 'C3661900'}],
#     'trait_name': 'not provided'},
#    {'trait_xrefs': [], 'trait_name': 'ZSWIM6 related intellectual disability'},
#    {'trait_xrefs': [{'db_source': 'MedGen', 'db_id': 'C0950123'},
#      {'db_source': 'MeSH', 'db_id': 'D030342'}],
#     'trait_name': 'Inborn genetic diseases'}]},
#  'clinical_impact_classification': {'description': '',
#   'last_evaluated': '1/01/01 00:00',
#   'review_status': '',
#   'fda_recognized_database': '',
#   'trait_set': []},
#  'oncogenicity_classification': {'description': '',
#   'last_evaluated': '1/01/01 00:00',
#   'review_status': '',
#   'fda_recognized_database': '',
#   'trait_set': []},
#  'record_status': '',
#  'gene_sort': 'ZSWIM6',
#  'chr_sort': '05',
#  'location_sort': '00000000000061541917',
#  'variation_set_name': '',
#  'variation_set_id': '',
#  'genes': [{'symbol': 'ZSWIM6',
#    'geneid': '57688',
#    'strand': '+',
#    'source': 'submitted'}],
#  'molecular_consequence_list': ['nonsense'],
#  'protein_change': 'R913*',
#  'fda_recognized_database': ''}

# %%
MONDO:0011359

# %%
cur_uid_result['germline_classification']['trait_set']
# Out:
# [{'trait_xrefs': [{'db_source': 'MedGen', 'db_id': 'C4693405'},
#    {'db_source': 'MONDO', 'db_id': 'MONDO:0060642'},
#    {'db_source': 'OMIM', 'db_id': '617865'}],
#   'trait_name': 'Neurodevelopmental disorder with movement abnormalities, abnormal gait, and autistic features'},
#  {'trait_xrefs': [], 'trait_name': 'ZSWIM6-related disorder'},
#  {'trait_xrefs': [{'db_source': 'MedGen', 'db_id': 'C3661900'}],
#   'trait_name': 'not provided'},
#  {'trait_xrefs': [], 'trait_name': 'ZSWIM6 related intellectual disability'},
#  {'trait_xrefs': [{'db_source': 'MedGen', 'db_id': 'C0950123'},
#    {'db_source': 'MeSH', 'db_id': 'D030342'}],
#   'trait_name': 'Inborn genetic diseases'}]

# %%
cur_uid_result['germline_classification']['trait_set'][0]
# Out:
# {'trait_xrefs': [{'db_source': 'MedGen', 'db_id': 'C4693405'},
#   {'db_source': 'MONDO', 'db_id': 'MONDO:0060642'},
#   {'db_source': 'OMIM', 'db_id': '617865'}],
#  'trait_name': 'Neurodevelopmental disorder with movement abnormalities, abnormal gait, and autistic features'}

# %%
trait_set_list=cur_uid_result['germline_classification']['trait_set']
for trait_dict in trait_set_list:
    print(trait_dict['trait_name'])
for trait_dict in trait_set_list:
    print(trait_dict['trait_name'])
# Out:
# Neurodevelopmental disorder with movement abnormalities, abnormal gait, and autistic features
# ZSWIM6-related disorder
# not provided
# ZSWIM6 related intellectual disability
# Inborn genetic diseases

# %%
import pronto

# %%
# test out MONDO obo hierarchy mapping
mondo_obo = "/Users/graceramey/Downloads/mondo.obo"
# Load MONDO ontology
onto = pronto.Ontology(mondo_obo)

def get_mondo_ancestors(
    mondo_id,
    *,
    max_depth=None,
    relationship_types=("is_a",)
):
    """
    Return ancestor MONDO IDs and names for a given MONDO ID.

    Parameters
    ----------
    mondo_id : str
        e.g. "MONDO:0007254"
    max_depth : int or None
        Limit traversal depth (None = all ancestors)
    relationship_types : tuple
        Typically only ("is_a",)

    Returns
    -------
    List of (mondo_id, name)
    """
    term = onto.get(mondo_id)
    if term is None:
        return []

    ancestors = []

    for rel in relationship_types:
        for parent in term.superclasses(
            distance=max_depth,
            with_self=False
        ):
            if parent.id:
                ancestors.append((parent.id, parent.name))

    # Deduplicate
    return sorted(set(ancestors))
# Out:
# /var/folders/d8/m8_nz4tx72l143cvq_1skt6h0000gn/T/ipykernel_14074/3114593452.py:4: UnicodeWarning: unsound encoding, assuming utf-8 (99% confidence)
#   onto = pronto.Ontology(mondo_obo)

# %%
cur_MONDO='MONDO:0011894' # this is the mondo for the overall term in ClinVar

# %%
ancestors = get_mondo_ancestors(cur_MONDO)

for aid, name in ancestors:
    if aid not in ['BFO:0000001','BFO:0000002','BFO:0000016','BFO:0000017','BFO:0000020','MONDO:0000001']:
        print(aid, name)
# Out:
# MONDO:0003620 peripheral nervous system disorder
# MONDO:0003847 hereditary disease
# MONDO:0005071 nervous system disorder
# MONDO:0005244 peripheral neuropathy
# MONDO:0015626 Charcot-Marie-Tooth disease
# MONDO:0018993 Charcot-Marie-Tooth disease type 2
# MONDO:0019056 neuromuscular disease
# MONDO:0020127 hereditary peripheral neuropathy
# MONDO:0100545 hereditary neurological disease
# MONDO:0100546 hereditary neuromuscular disease
# MONDO:0700096 human disease

# %%
cur_MONDO = 'MONDO:0015626' # this is the more specific disease from ClinGen

# %%
ancestors = get_mondo_ancestors(cur_MONDO)

for aid, name in ancestors:
    print(aid, name)
# Out:
# BFO:0000001 entity
# BFO:0000002 continuant
# BFO:0000016 disposition
# BFO:0000017 realizable entity
# BFO:0000020 specifically dependent continuant
# MONDO:0000001 disease
# MONDO:0003620 peripheral nervous system disorder
# MONDO:0003847 hereditary disease
# MONDO:0005071 nervous system disorder
# MONDO:0005244 peripheral neuropathy
# MONDO:0019056 neuromuscular disease
# MONDO:0020127 hereditary peripheral neuropathy
# MONDO:0100545 hereditary neurological disease
# MONDO:0100546 hereditary neuromuscular disease
# MONDO:0700096 human disease

# %%
def calc_id_overlap(id_list1,id_list2):
    len_total

# %%
hpoa_file="/Users/graceramey/Downloads/phenotype.hpoa"
hpoa_cols = [
    "database_id",
    "disease_name",
    "qualifier",
    "hpo_id",
    "reference",
    "evidence",
    "onset",
    "frequency",
    "sex",
    "modifier",
    "aspect",
    "biocuration",
]

hpoa = pd.read_csv(
    hpoa_file,
    sep="\t",
    comment="#",
    dtype=str,
)
mondo_hpo = hpoa[hpoa["database_id"].str.startswith("MONDO")].copy()
mondo_hpo
# Out:
# Empty DataFrame
# Columns: [database_id, disease_name, qualifier, hpo_id, reference, evidence, onset, frequency, sex, modifier, aspect, biocuration]
# Index: []

# %%
hpoa
# Out:
#         database_id                                   disease_name qualifier  \
# 0       OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 1       OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 2       OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 3       OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 4       OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# ...             ...                                            ...       ...
# 276012   ORPHA:1777                               Temtamy syndrome       NaN
# 276013   ORPHA:1777                               Temtamy syndrome       NaN
# 276014   ORPHA:1777                               Temtamy syndrome       NaN
# 276015   ORPHA:1777                               Temtamy syndrome       NaN
# 276016   ORPHA:1777                               Temtamy syndrome       NaN
#
#             hpo_id      reference evidence onset   frequency  sex modifier  \
# 0       HP:0011097  PMID:31675180      PCS   NaN         1/2  NaN      NaN
# 1       HP:0002187  PMID:31675180      PCS   NaN         1/1  NaN      NaN
# 2       HP:0001518  PMID:31675180      PCS   NaN         1/2  NaN      NaN
# 3       HP:0032792  PMID:31675180      PCS   NaN         1/2  NaN      NaN
# 4       HP:0011451  PMID:31675180      PCS   NaN         1/2  NaN      NaN
# ...            ...            ...      ...   ...         ...  ...      ...
# 276012  HP:0000324     ORPHA:1777      TAS   NaN  HP:0040283  NaN      NaN
# 276013  HP:0000506     ORPHA:1777      TAS   NaN  HP:0040283  NaN      NaN
# 276014  HP:0000568     ORPHA:1777      TAS   NaN  HP:0040283  NaN      NaN
# 276015  HP:0004209     ORPHA:1777      TAS   NaN  HP:0040283  NaN      NaN
# 276016  HP:0001382     ORPHA:1777      TAS   NaN  HP:0040283  NaN      NaN
#
#        aspect                  biocuration
# 0           P    HPO:probinson[2021-06-21]
# 1           P    HPO:probinson[2021-06-21]
# 2           P    HPO:probinson[2021-06-21]
# 3           P    HPO:probinson[2021-06-21]
# 4           P    HPO:probinson[2021-06-21]
# ...       ...                          ...
# 276012      P  ORPHA:orphadata[2025-11-24]
# 276013      P  ORPHA:orphadata[2025-11-24]
# 276014      P  ORPHA:orphadata[2025-11-24]
# 276015      P  ORPHA:orphadata[2025-11-24]
# 276016      P  ORPHA:orphadata[2025-11-24]
#
# [276017 rows x 12 columns]

# %%
mondo = pronto.Ontology(mondo_obo)

def mondo_xrefs(mondo_id, prefixes=("OMIM", "Orpha")):
    term = mondo.get(mondo_id)
    if term is None:
        return set()

    xrefs = set()
    for x in term.xrefs:
        xref_id = x.id   # <-- THIS is the fix
        for p in prefixes:
            if xref_id.startswith(p):
                xrefs.add(xref_id)

    return xrefs

cur_id='MONDO:0015626'
mondo_xrefs(cur_id)
# Out:
# /var/folders/d8/m8_nz4tx72l143cvq_1skt6h0000gn/T/ipykernel_14074/1224853759.py:1: UnicodeWarning: unsound encoding, assuming utf-8 (99% confidence)
#   mondo = pronto.Ontology(mondo_obo)
# {'OMIMPS:118220', 'Orphanet:166'}

# %%
term = mondo.get(cur_id)

# %%
term
# Out:
# Term('MONDO:0015626', name='Charcot-Marie-Tooth disease')

# %%
for x in term.xrefs:
    print(x)
# Out:
# Xref('MESH:D002607')
# Xref('NCIT:C75467')
# Xref('OMIMPS:118220')
# Xref('GARD:6034')
# Xref('MedDRA:10034699')
# Xref('NANDO:1200016')
# Xref('NANDO:2200855')
# Xref('Orphanet:166')
# Xref('NORD:919')
# Xref('DOID:10595')
# Xref('UMLS:C0007959')
# Xref('MEDGEN:2980')
# Xref('ICD9:356.1')

# %%
xref_id=x.id

# %%
xref_id
# Out:
# 'Orphanet:166'

# %%
for idx, row in dis.iterrows():
# Out:
#     hgnc_symbol                                  DISEASE LABEL  \
# 0         AARS1     Charcot-Marie-Tooth disease axonal type 2N
# 1         AARS1              AARS1-related leukoencephalopathy
# 2         ABCB6      microphthalmia, isolated, with coloboma 7
# 3         ABCB6       dyschromatosis universalis hereditaria 3
# 4         ABCC6             inherited pseudoxanthoma elasticum
# ..          ...                                            ...
# 850        ZIC1                             craniosynostosis 6
# 851       ZMIZ1            complex neurodevelopmental disorder
# 852      ZMYND8  syndromic complex neurodevelopmental disorder
# 853      ZNF292            complex neurodevelopmental disorder
# 854      ZSWIM6               acromelic frontonasal dysostosis
#
#     DISEASE ID (MONDO)
# 0        MONDO:0013212
# 1        MONDO:1010132
# 2        MONDO:0013783
# 3        MONDO:0014169
# 4        MONDO:0100091
# ..                 ...
# 850      MONDO:0014705
# 851      MONDO:0100038
# 852      MONDO:0800439
# 853      MONDO:0100038
# 854      MONDO:0011359
#
# [737 rows x 3 columns]

# %%
# load mondo ontology
mondo_obo = "/Users/graceramey/Downloads/mondo.obo"
mondo = pronto.Ontology(mondo_obo)

# load hpoa file
hpoa_file="/Users/graceramey/Downloads/phenotype.hpoa"
hpoa_cols = [
    "database_id",
    "disease_name",
    "qualifier",
    "hpo_id",
    "reference",
    "evidence",
    "onset",
    "frequency",
    "sex",
    "modifier",
    "aspect",
    "biocuration",
]

hpoa = pd.read_csv(
    hpoa_file,
    sep="\t",
    comment="#",
    dtype=str,
)
mondo_hpo = hpoa[hpoa["database_id"].str.startswith("MONDO")].copy()

# function to map mondos to 
def mondo_xrefs(mondo_id): # prefixes=("OMIM", "Orpha")):
    term = mondo.get(mondo_id)
    xrefs=set()
    if term is None:
        return set()
    else:
        for x in term.xrefs:
            xrefs.add(getattr(x, 'id'))
    return xrefs

counter=0
for idx, row in dis.iterrows():
    cur_mondo=row['DISEASE ID (MONDO)']
    cur_xrefs = mondo_xrefs(cur_mondo)
    if any('OMIM' in element for element in cur_xrefs):
        print(cur_xrefs)
        print("---------------------")
        counter+=1
# Out:
# /var/folders/d8/m8_nz4tx72l143cvq_1skt6h0000gn/T/ipykernel_14074/3498259331.py:3: UnicodeWarning: unsound encoding, assuming utf-8 (99% confidence)
#   mondo = pronto.Ontology(mondo_obo)
# {'MESH:C567653', 'MEDGEN:413754', 'Orphanet:228174', 'GARD:12429', 'OMIM:613287', 'SCTID:719515001', 'UMLS:C2750090', 'DOID:0110177'}
# ---------------------
# {'OMIM:614497', 'GARD:15811', 'UMLS:C3281027', 'MEDGEN:482657'}
# ---------------------
# {'GARD:15959', 'MEDGEN:815724', 'OMIM:615402', 'UMLS:C3809394'}
# ---------------------
# {'UMLS:C0795905', 'MEDGEN:208647', 'GARD:8585', 'Orphanet:1517', 'MESH:C535572', 'DOID:0060569', 'SCTID:239087008', 'OMIM:239850'}
# ---------------------
# {'ICD9:746.89', 'MESH:D053840', 'icd11.foundation:1250136584', 'MedDRA:10059027', 'OMIMPS:601144', 'DOID:0050451', 'UMLS:C1142166', 'MEDGEN:222975', 'NORD:878', 'SCTID:418818005', 'GARD:1030', 'Orphanet:130', 'NCIT:C142891'}
# ---------------------
# {'GARD:18199', 'DOID:0111442', 'OMIM:616289', 'UMLS:C4225384', 'MEDGEN:898858'}
# ---------------------
# {'OMIM:618960', 'UMLS:C5394554', 'MEDGEN:1714342', 'DOID:0070516', 'Orphanet:631248'}
# ---------------------
# {'Orphanet:404463', 'UMLS:C3151201', 'GARD:12811', 'OMIM:613834', 'MEDGEN:462551'}
# ---------------------
# {'SCTID:702410002', 'GARD:5279', 'MEDGEN:340016', 'UMLS:C1853623', 'ICD9:759.89', 'OMIMPS:243310', 'Orphanet:2995', 'DOID:0060229'}
# ---------------------
# {'Orphanet:674653', 'MEDGEN:1851006', 'UMLS:C5882677', 'OMIM:620475'}
# ---------------------
# {'DOID:0081113', 'UMLS:C3281235', 'MEDGEN:482865', 'OMIM:614583', 'GARD:15817'}
# ---------------------
# {'MEDGEN:767577', 'UMLS:C3554663', 'DOID:0111053', 'NANDO:2200665', 'OMIM:615193', 'GARD:18272'}
# ---------------------
# {'NANDO:1200871', 'DOID:13374', 'GARD:6445', 'Orphanet:337', 'NANDO:2201020', 'MEDGEN:4698', 'UMLS:C0016037', 'icd11.foundation:2102976705', 'ICD9:728.11', 'ICD10CM:M61.1', 'NCIT:C3040', 'OMIM:135100', 'NORD:1143', 'MESH:D009221', 'SCTID:82725007', 'MedDRA:10068715'}
# ---------------------
# {'UMLS:C5908309', 'MEDGEN:1859334', 'OMIMPS:606703'}
# ---------------------
# {'GARD:16399', 'DOID:0080840', 'OMIM:618977', 'UMLS:C5436534', 'MEDGEN:1720703'}
# ---------------------
# {'OMIM:619149', 'GARD:18538', 'MEDGEN:1762595', 'UMLS:C5436892'}
# ---------------------
# {'SCTID:403836001', 'GARD:10578', 'OMIM:605258', 'NCIT:C129074', 'DOID:0060758', 'MEDGEN:354548', 'UMLS:C1720956', 'Orphanet:101089'}
# ---------------------
# {'MESH:D050010', 'NCIT:C131813', 'SCTID:237547004', 'Orphanet:276271', 'MEDGEN:90974', 'OMIM:615999', 'UMLS:C0342185'}
# ---------------------
# {'UMLS:C2751681', 'MEDGEN:414083', 'OMIM:613014'}
# ---------------------
# {'MEDGEN:349976', 'NANDO:2200663', 'OMIM:188000', 'GARD:5191', 'UMLS:C1861185', 'NCIT:C129035', 'MESH:C536519'}
# ---------------------
# {'SCTID:715568002', 'MESH:C536039', 'OMIM:166260', 'Orphanet:53697', 'DOID:0111533', 'MEDGEN:331575', 'icd11.foundation:1984860886', 'UMLS:C1833736', 'GARD:8698'}
# ---------------------
# {'GARD:16262', 'DOID:0080225', 'MEDGEN:1645924', 'OMIM:617839', 'UMLS:C4693381'}
# ---------------------
# {'NCIT:C157147', 'UMLS:C2751536', 'MEDGEN:414044', 'DOID:0070028', 'OMIM:605714'}
# ---------------------
# {'UMLS:C1868720', 'Orphanet:98892', 'NANDO:1201079', 'GARD:12724', 'MESH:D054091', 'MedDRA:10066854', 'DOID:0050454', 'icd11.foundation:20200096', 'OMIMPS:300049', 'MEDGEN:358387'}
# ---------------------
# {'SCTID:449790007', 'DOID:0050567', 'OMIMPS:119530', 'UMLS:C3266076', 'MEDGEN:472000'}
# ---------------------
# {'GARD:15695', 'DOID:0070156', 'OMIM:613708', 'UMLS:C3150972', 'MEDGEN:462322'}
# ---------------------
# {'UMLS:C3810194', 'GARD:15995', 'MEDGEN:816524', 'OMIM:615632', 'DOID:0070154'}
# ---------------------
# {'OMIMPS:124900', 'MEDGEN:1843285', 'UMLS:C5779548', 'Orphanet:90635', 'GARD:16791', 'DOID:0050564'}
# ---------------------
# {'DOID:0111558', 'MEDGEN:1648475', 'UMLS:C4747974', 'GARD:17959', 'OMIM:618036', 'Orphanet:521414'}
# ---------------------
# {'OMIMPS:124900', 'MEDGEN:1843285', 'UMLS:C5779548', 'Orphanet:90635', 'GARD:16791', 'DOID:0050564'}
# ---------------------
# {'NCIT:C148315', 'NANDO:1200046', 'DOID:0060204', 'OMIM:183090', 'Orphanet:98756', 'DOID:0050955', 'UMLS:C0752121', 'MEDGEN:155704', 'icd11.foundation:1232187870', 'SCTID:715751004', 'GARD:4072'}
# ---------------------
# {'OMIM:618394', 'MEDGEN:1681890', 'DOID:0111954', 'UMLS:C5193072'}
# ---------------------
# {'OMIM:618092', 'UMLS:C4748152', 'Orphanet:662829', 'MEDGEN:1648327'}
# ---------------------
# {'Orphanet:1465', 'NORD:984', 'MEDGEN:75565', 'icd11.foundation:734451870', 'DOID:1925', 'NCIT:C35321', 'ICD9:759.89', 'NANDO:1200670', 'GARD:6124', 'SCTID:10007009', 'UMLS:C0265338', 'NANDO:2200977', 'OMIMPS:135900', 'MESH:C536436'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'NORD:1360', 'MedDRA:10062901', 'MEDGEN:104494', 'Orphanet:500', 'UMLS:C0175704', 'ICD9:709.09', 'MESH:D044542', 'DOID:14291', 'icd11.foundation:939197023', 'OMIMPS:151100', 'NCIT:C84820', 'SCTID:111306001', 'GARD:1100'}
# ---------------------
# {'DOID:0060233', 'NCIT:C84617', 'GARD:9146', 'Orphanet:1340', 'OMIMPS:115150', 'SCTID:403770008', 'MESH:C535579', 'MEDGEN:266149', 'NANDO:2200967', 'NORD:891', 'NANDO:1200462', 'UMLS:C1275081'}
# ---------------------
# {'MESH:D056685', 'ICD9:799.89', 'GARD:1550', 'NCIT:C84652', 'UMLS:C0587248', 'SCTID:309776008', 'DOID:0050469', 'MedDRA:10067380', 'Orphanet:3071', 'NORD:1011', 'NANDO:1200463', 'icd11.foundation:1946512039', 'MEDGEN:108454', 'OMIM:218040', 'NANDO:2200971'}
# ---------------------
# {'Orphanet:289560', 'GARD:12569', 'UMLS:C3280371', 'NCIT:C175707', 'MEDGEN:482001', 'OMIM:614298', 'SCTID:709415008', 'ICD9:333.0', 'DOID:0110738', 'NANDO:1200540'}
# ---------------------
# {'UMLS:C4055342', 'NCIT:C123043', 'GARD:16487', 'MEDGEN:884569', 'Orphanet:329931', 'OMIM:614809'}
# ---------------------
# {'MEDGEN:442875', 'OMIM:612925', 'UMLS:C2752037', 'GARD:18555', 'Orphanet:93575'}
# ---------------------
# {'DOID:0060213', 'GARD:18396', 'MEDGEN:1830423', 'NCIT:C168756', 'UMLS:C5779877', 'OMIM:105550'}
# ---------------------
# {'icd11.foundation:553392015', 'Orphanet:51083', 'OMIMPS:609620', 'ICD9:426.89', 'NORD:2019', 'UMLS:C2348199', 'SCTID:698272007', 'GARD:16650', 'DOID:0050793', 'MESH:C580439', 'NCIT:C71060', 'MEDGEN:378835'}
# ---------------------
# {'Orphanet:65283', 'UMLS:C1832916', 'OMIM:601005', 'GARD:9294', 'MEDGEN:331395', 'DOID:0060173', 'NCIT:C142894', 'NORD:1772', 'MESH:C536962'}
# ---------------------
# {'ICD9:746.89', 'MESH:D053840', 'icd11.foundation:1250136584', 'MedDRA:10059027', 'OMIMPS:601144', 'DOID:0050451', 'UMLS:C1142166', 'MEDGEN:222975', 'NORD:878', 'SCTID:418818005', 'GARD:1030', 'Orphanet:130', 'NCIT:C142891'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'MESH:C535698', 'MEDGEN:356151', 'OMIM:601887', 'UMLS:C1866077'}
# ---------------------
# {'SCTID:419671004', 'OMIMPS:604772', 'MESH:C536334', 'NANDO:2200216', 'GARD:4421', 'ICD10CM:I47.2', 'Orphanet:3286', 'icd11.foundation:976309888', 'DOID:0060674', 'NANDO:2200221', 'UMLS:C5574922', 'MEDGEN:1803763'}
# ---------------------
# {'SCTID:419671004', 'OMIMPS:604772', 'MESH:C536334', 'NANDO:2200216', 'GARD:4421', 'ICD10CM:I47.2', 'Orphanet:3286', 'icd11.foundation:976309888', 'DOID:0060674', 'NANDO:2200221', 'UMLS:C5574922', 'MEDGEN:1803763'}
# ---------------------
# {'SCTID:419671004', 'OMIMPS:604772', 'MESH:C536334', 'NANDO:2200216', 'GARD:4421', 'ICD10CM:I47.2', 'Orphanet:3286', 'icd11.foundation:976309888', 'DOID:0060674', 'NANDO:2200221', 'UMLS:C5574922', 'MEDGEN:1803763'}
# ---------------------
# {'icd11.foundation:537908479', 'UMLS:C5675009', 'DOID:0110273', 'Orphanet:102014', 'GARD:19824', 'OMIMPS:603511', 'MEDGEN:1826162'}
# ---------------------
# {'MedDRA:10057896', 'MESH:D018630', 'SCTID:770791000', 'ICD9:362.29', 'DOID:9719', 'MEDGEN:1648542', 'Orphanet:329211', 'GARD:17497', 'UMLS:C4721549', 'OMIM:193235', 'SCTID:232016005'}
# ---------------------
# {'Orphanet:464336', 'MEDGEN:1641265', 'OMIM:616452', 'UMLS:C4551967', 'GARD:13339'}
# ---------------------
# {'NCIT:C176630', 'DOID:0111958', 'MEDGEN:1627819', 'UMLS:C4539957', 'OMIM:617638'}
# ---------------------
# {'SCTID:419671004', 'OMIMPS:604772', 'MESH:C536334', 'NANDO:2200216', 'GARD:4421', 'ICD10CM:I47.2', 'Orphanet:3286', 'icd11.foundation:976309888', 'DOID:0060674', 'NANDO:2200221', 'UMLS:C5574922', 'MEDGEN:1803763'}
# ---------------------
# {'MESH:C537145', 'MedDRA:10068704', 'GARD:2796', 'MEDGEN:137973', 'OMIM:145980', 'UMLS:C0342637', 'DOID:0060700', 'SCTID:704166007', 'Orphanet:93372'}
# ---------------------
# {'UMLS:C0342345', 'DOID:0090107', 'MEDGEN:87438', 'OMIM:601198'}
# ---------------------
# {'GARD:17577', 'OMIM:613563', 'Orphanet:363972', 'UMLS:C3150803', 'MEDGEN:462153'}
# ---------------------
# {'OMIM:603284', 'DOID:0060670', 'MESH:C566394', 'UMLS:C1864041', 'GARD:18313', 'MEDGEN:400438'}
# ---------------------
# {'OMIM:615938', 'UMLS:C4014742', 'MEDGEN:863179', 'GARD:18079'}
# ---------------------
# {'OMIMPS:124900', 'MEDGEN:1843285', 'UMLS:C5779548', 'Orphanet:90635', 'GARD:16791', 'DOID:0050564'}
# ---------------------
# {'OMIMPS:603278', 'NANDO:2200113', 'NANDO:1200722'}
# ---------------------
# {'MEDGEN:906646', 'Orphanet:487796', 'GARD:17884', 'UMLS:C4225222', 'OMIM:616737', 'NANDO:2200985'}
# ---------------------
# {'DOID:0081074', 'UMLS:C5676911', 'OMIM:619736', 'MEDGEN:1809276'}
# ---------------------
# {'OMIM:609048', 'UMLS:C1836892', 'MEDGEN:373202'}
# ---------------------
# {'OMIM:601626', 'ICD9:205.0', 'ICD10CM:C92.0', 'UMLS:C0023467', 'ICD9:205.00', 'MedDRA:10000880', 'NORD:1905', 'EFO:0000222', 'NCIT:C3171', 'SCTID:91861009', 'ONCOTREE:AML', 'Orphanet:519', 'MESH:D015470', 'ICDO:9861/3', 'DOID:9119', 'MEDGEN:9730', 'GARD:12757'}
# ---------------------
# {'MESH:C565225', 'SCTID:609575003', 'DOID:0111105', 'OMIM:609812', 'UMLS:C1853297', 'GARD:10662', 'MEDGEN:342845'}
# ---------------------
# {'DOID:0112229', 'UMLS:C5394354', 'OMIM:618873', 'MEDGEN:1719546'}
# ---------------------
# {'UMLS:C4055342', 'NCIT:C123043', 'GARD:16487', 'MEDGEN:884569', 'Orphanet:329931', 'OMIM:614809'}
# ---------------------
# {'Orphanet:93578', 'GARD:18554', 'MEDGEN:416691', 'OMIM:612924', 'UMLS:C2752038'}
# ---------------------
# {'UMLS:C4055342', 'NCIT:C123043', 'GARD:16487', 'MEDGEN:884569', 'Orphanet:329931', 'OMIM:614809'}
# ---------------------
# {'MEDGEN:863085', 'OMIM:615911', 'UMLS:C4014648', 'GARD:18397', 'DOID:0060214'}
# ---------------------
# {'GARD:13806', 'OMIM:618205', 'UMLS:C4748701', 'Orphanet:599082', 'MEDGEN:1648495'}
# ---------------------
# {'MESH:C563708', 'OMIM:614696', 'ICD9:331.19', 'MESH:C579991', 'DOID:0060208', 'MEDGEN:318833', 'SCTID:702393003', 'DOID:0111227', 'OMIM:600795', 'UMLS:C1833296', 'GARD:15322'}
# ---------------------
# {'DOID:0061028', 'SCTID:128083007', 'OMIM:604356', 'UMLS:C0751083', 'MEDGEN:196721', 'GARD:9966'}
# ---------------------
# {'UMLS:C5577629', 'OMIMPS:600513', 'MEDGEN:1865268'}
# ---------------------
# {'GARD:9895', 'UMLS:C4225374', 'MEDGEN:908185', 'OMIM:616313', 'DOID:0110681'}
# ---------------------
# {'UMLS:C5577629', 'OMIMPS:600513', 'MEDGEN:1865268'}
# ---------------------
# {'UMLS:C5543020', 'MEDGEN:1781967', 'DOID:0061189', 'Orphanet:610573', 'GARD:18023', 'OMIM:619173'}
# ---------------------
# {'UMLS:C5203300', 'MEDGEN:1684826', 'OMIM:618541'}
# ---------------------
# {'SCTID:725050005', 'UMLS:C3179239', 'MEDGEN:465707', 'OMIM:166600', 'DOID:0110938', 'GARD:383', 'Orphanet:53'}
# ---------------------
# {'MEDGEN:906582', 'OMIM:616418', 'UMLS:C4225333'}
# ---------------------
# {'DOID:0080021', 'GARD:7029', 'SCTID:29248006', 'MESH:C537352', 'Orphanet:174', 'OMIM:156500', 'NORD:1444', 'MEDGEN:78550', 'UMLS:C0265289'}
# ---------------------
# {'OMIMPS:124900', 'MEDGEN:1843285', 'UMLS:C5779548', 'Orphanet:90635', 'GARD:16791', 'DOID:0050564'}
# ---------------------
# {'MEDGEN:1617409', 'DOID:0080026', 'GARD:4130', 'OMIMPS:184840', 'ICD9:759.89', 'icd11.foundation:1885284987', 'SCTID:254060000', 'UMLS:C4520892', 'Orphanet:1427'}
# ---------------------
# {'ICD10CM:Q87.81', 'Orphanet:63', 'MEDGEN:339209', 'GARD:5785', 'UMLS:C1567741', 'NANDO:2200126', 'NANDO:1200712', 'NCIT:C34842', 'icd11.foundation:1170919425', 'DOID:10983', 'OMIMPS:301050', 'NORD:756', 'MESH:D009394', 'MedDRA:10001843'}
# ---------------------
# {'ICD10CM:Q87.81', 'Orphanet:63', 'MEDGEN:339209', 'GARD:5785', 'UMLS:C1567741', 'NANDO:2200126', 'NANDO:1200712', 'NCIT:C34842', 'icd11.foundation:1170919425', 'DOID:10983', 'OMIMPS:301050', 'NORD:756', 'MESH:D009394', 'MedDRA:10001843'}
# ---------------------
# {'NCIT:C162399', 'DOID:0111005', 'MEDGEN:483485', 'UMLS:C3489532', 'SCTID:80328002', 'GARD:6145', 'ICD9:362.75', 'OMIM:120970'}
# ---------------------
# {'Orphanet:689397', 'MEDGEN:1684718', 'UMLS:C5231482', 'OMIM:618732'}
# ---------------------
# {'UMLS:C4015214', 'Orphanet:436159', 'GARD:12316', 'NCIT:C126341', 'MEDGEN:863651', 'OMIM:616100'}
# ---------------------
# {'MEDGEN:1623594', 'GARD:16244', 'UMLS:C4540127', 'OMIM:617681', 'DOID:0080346'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'OMIMPS:193670', 'UMLS:C0472817', 'MEDGEN:96875'}
# ---------------------
# {'OMIM:618175', 'MEDGEN:1677486', 'UMLS:C5193019'}
# ---------------------
# {'GARD:13608', 'MEDGEN:1622162', 'UMLS:C4540496', 'OMIM:617804', 'Orphanet:647788'}
# ---------------------
# {'icd11.foundation:537908479', 'UMLS:C5675009', 'DOID:0110273', 'Orphanet:102014', 'GARD:19824', 'OMIMPS:603511', 'MEDGEN:1826162'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'OMIMPS:614388', 'UMLS:C5681458', 'Orphanet:527276', 'MEDGEN:1814479', 'GARD:22192'}
# ---------------------
# {'Orphanet:506', 'UMLS:C2931891', 'DOID:3652', 'ICD9:330.8', 'NORD:1355', 'icd11.foundation:672871576', 'MEDGEN:419518', 'GARD:6877', 'SCTID:29570005', 'MESH:D007888', 'MedDRA:10062950', 'NANDO:2200527', 'OMIM:256000', 'NCIT:C84814', 'NANDO:1200175', 'ICD10CM:G31.82'}
# ---------------------
# {'OMIMPS:118220', 'MESH:D002607', 'NCIT:C75467', 'GARD:6034', 'MedDRA:10034699', 'NANDO:1200016', 'NANDO:2200855', 'Orphanet:166', 'NORD:919', 'DOID:10595', 'UMLS:C0007959', 'MEDGEN:2980', 'ICD9:356.1'}
# ---------------------
# {'UMLS:C4551952', 'Orphanet:169189', 'DOID:0111217', 'OMIM:614408', 'MEDGEN:1645741', 'GARD:12719', 'SCTID:716696006', 'NCIT:C126689', 'OMIM:160150', 'DOID:0111223'}
# ---------------------
# {'Orphanet:1465', 'NORD:984', 'MEDGEN:75565', 'icd11.foundation:734451870', 'DOID:1925', 'NCIT:C35321', 'ICD9:759.89', 'NANDO:1200670', 'GARD:6124', 'SCTID:10007009', 'UMLS:C0265338', 'NANDO:2200977', 'OMIMPS:135900', 'MESH:C536436'}
# ---------------------
# {'GARD:17129', 'Orphanet:217656', 'OMIMPS:107970', 'SCTID:715865008', 'icd11.foundation:460188584', 'MEDGEN:901869', 'UMLS:C4274968'}
# ---------------------
# {'Orphanet:659396', 'MEDGEN:1386939', 'UMLS:C4479654', 'OMIM:617561', 'GARD:16235'}
# ---------------------
# {'Orphanet:75376', 'DOID:0060745', 'SCTID:193411004', 'GARD:1912', 'ICD10CM:H35.5', 'MEDGEN:321900', 'OMIM:126600', 'UMLS:C1832174'}
# ---------------------
# {'OMIMPS:118220', 'MESH:D002607', 'NCIT:C75467', 'GARD:6034', 'MedDRA:10034699', 'NANDO:1200016', 'NANDO:2200855', 'Orphanet:166', 'NORD:919', 'DOID:10595', 'UMLS:C0007959', 'MEDGEN:2980', 'ICD9:356.1'}
# ---------------------
# {'OMIM:300987', 'SCTID:722037004', 'DOID:0060801', 'MESH:C537451', 'MEDGEN:375855', 'icd11.foundation:500681653', 'GARD:9178', 'Orphanet:85282', 'UMLS:C1846278', 'OMIM:300148'}
# ---------------------
# {'MEDGEN:87542', 'OMIM:114480', 'GARD:17142', 'ICD10CM:C50.2', 'ICD10CM:C50.3', 'MESH:C562840', 'SCTID:254843006', 'NCIT:C4503', 'Orphanet:227535', 'UMLS:C0346153', 'ICD10CM:C50.6'}
# ---------------------
# {'NCIT:C125599', 'OMIM:277590', 'NANDO:1200659', 'MEDGEN:120511', 'DOID:14731', 'Orphanet:3447', 'NANDO:2200957', 'icd11.foundation:2042913723', 'GARD:7878', 'ICD9:759.89', 'UMLS:C0265210', 'GTR:AN0102079', 'SCTID:63119004', 'MESH:C536687', 'NORD:1839', 'GTR:AN0102080'}
# ---------------------
# {'NCIT:C84705', 'OMIM:612416', 'icd11.foundation:413739466', 'DOID:2229', 'UMLS:C0015523', 'SCTID:49762007', 'ICD9:286.2', 'MEDGEN:8770', 'Orphanet:329', 'ICD10CM:D68.1', 'GARD:9670'}
# ---------------------
# {'OMIM:610618', 'MEDGEN:346653', 'Orphanet:100054', 'DOID:0080940', 'SCTID:427167008', 'ICD9:277.6', 'UMLS:C1857728', 'GARD:16935', 'MESH:D056828'}
# ---------------------
# {'SCTID:111293003', 'ICD9:453.9', 'DOID:0111907', 'DOID:0080701', 'MEDGEN:463623', 'GARD:10815', 'OMIM:188050', 'UMLS:C3160733'}
# ---------------------
# {'MESH:D020016', 'ICD9:289.81', 'OMIM:188055', 'UMLS:C1861171', 'DOID:0111902', 'SCTID:421527008', 'MEDGEN:396074'}
# ---------------------
# {'MEDGEN:816655', 'OMIM:615704', 'icd11.foundation:1585528459', 'UMLS:C3810325', 'Orphanet:221043', 'GARD:13218'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'UMLS:C0175700', 'Orphanet:3237', 'DOID:0050794', 'MEDGEN:511579', 'GARD:3836', 'icd11.foundation:248917534', 'OMIMPS:186500'}
# ---------------------
# {'NANDO:1200667', 'NORD:793', 'icd11.foundation:1962779847', 'GARD:5833', 'OMIM:101200', 'NANDO:2200844', 'MedDRA:10002943', 'NCIT:C99099', 'MEDGEN:7858', 'MESH:D000168', 'Orphanet:87', 'UMLS:C0001193', 'SCTID:205258009'}
# ---------------------
# {'MEDGEN:377668', 'icd11.foundation:947865461', 'ICD9:759.89', 'DOID:0050660', 'Orphanet:1555', 'UMLS:C1852406', 'OMIM:123790', 'SCTID:703528008', 'GARD:332', 'MESH:C565129', 'NCIT:C123813'}
# ---------------------
# {'OMIM:123500', 'UMLS:C0010273', 'NANDO:1200666', 'NORD:1018', 'Orphanet:207', 'MESH:D003394', 'SCTID:28861008', 'DOID:2339', 'GARD:6206', 'NCIT:C84653', 'NANDO:2200845', 'MEDGEN:1162', 'icd11.foundation:1535725821'}
# ---------------------
# {'NANDO:2200976', 'NORD:1572', 'UMLS:C0220658', 'MEDGEN:67390', 'NANDO:1200668', 'Orphanet:710', 'icd11.foundation:1075159878', 'GARD:7380', 'MESH:D000168', 'OMIM:101600', 'DOID:14705', 'NCIT:C99100', 'SCTID:70410008'}
# ---------------------
# {'GARD:10965', 'MEDGEN:482877', 'Orphanet:313855', 'UMLS:C3281247', 'OMIM:614592', 'DOID:0060992'}
# ---------------------
# {'NORD:1345', 'Orphanet:2363', 'DOID:0081370', 'GARD:6848', 'MESH:C538132', 'SCTID:23817003', 'ICD9:759.89', 'DOID:0050331', 'OMIMPS:149730', 'MEDGEN:78545', 'UMLS:C0265269'}
# ---------------------
# {'MESH:C567382', 'OMIM:612247', 'MEDGEN:394201', 'NCIT:C38145', 'SCTID:702361006', 'GARD:16810', 'Orphanet:93262', 'DOID:0111161', 'UMLS:C2677099'}
# ---------------------
# {'icd11.foundation:1860572017', 'NCIT:C84904', 'Orphanet:53271', 'DOID:0060703', 'MESH:C537369', 'GARD:7097', 'MEDGEN:355217', 'OMIM:602849', 'SCTID:440350001', 'UMLS:C1864436'}
# ---------------------
# {'NCIT:C34345', 'SCTID:86268005', 'icd11.foundation:24224082', 'MedDRA:10000452', 'UMLS:C0001080', 'MESH:D000130', 'NORD:711', 'NANDO:1200877', 'MEDGEN:1289', 'DOID:4480', 'GARD:8173', 'NANDO:2201009', 'ICD10CM:Q77.4', 'OMIM:100800', 'Orphanet:15'}
# ---------------------
# {'ICD10CM:Q77.4', 'MEDGEN:98376', 'MESH:C562937', 'OMIM:146000', 'icd11.foundation:1930265486', 'ICD9:756.9', 'NANDO:2201010', 'MedDRA:10020967', 'SCTID:205468002', 'GARD:6724', 'NORD:1271', 'UMLS:C0410529', 'NCIT:C118697', 'DOID:0080041', 'Orphanet:429'}
# ---------------------
# {'MEDGEN:355844', 'DOID:0111160', 'UMLS:C1864852', 'OMIM:610474', 'Orphanet:85164', 'GARD:10012', 'MESH:C537975'}
# ---------------------
# {'PMID:10053006', 'ICD9:757.39', 'SCTID:699870002', 'Orphanet:85165', 'ICD9:783.40', 'OMIM:616482', 'GARD:9443', 'DOID:0111158', 'ICD10CM:Q77.4', 'MEDGEN:393098', 'UMLS:C2674173'}
# ---------------------
# {'MEDGEN:1386863', 'GARD:16230', 'UMLS:C4479515', 'OMIM:617443'}
# ---------------------
# {'MEDGEN:309963', 'DOID:0070210', 'OMIM:153100', 'UMLS:C1704423', 'GARD:3328', 'Orphanet:79452', 'SCTID:399889006', 'DOID:0070212'}
# ---------------------
# {'OMIM:618780', 'MEDGEN:1714491', 'UMLS:C5394062'}
# ---------------------
# {'GARD:4991', 'DOID:0112297', 'UMLS:C0432221', 'OMIM:184255', 'MEDGEN:98146', 'SCTID:254078005', 'icd11.foundation:1295452752', 'MESH:C535793', 'Orphanet:93315'}
# ---------------------
# {'OMIM:601894', 'SCTID:722759007', 'UMLS:C1866075', 'MEDGEN:356149', 'GARD:9914'}
# ---------------------
# {'SCTID:718182008', 'UMLS:C4273747', 'MEDGEN:906592', 'ICD10CM:E23.0', 'Orphanet:95494', 'GARD:10602', 'OMIMPS:613038'}
# ---------------------
# {'GARD:2249', 'UMLS:C4707243', 'MEDGEN:1644766', 'ICD9:447.9', 'SCTID:45894003', 'Orphanet:91387', 'OMIMPS:607086', 'SCTID:764965000'}
# ---------------------
# {'DOID:0111856', 'MEDGEN:1684675', 'UMLS:C5231466', 'OMIM:618699'}
# ---------------------
# {'UMLS:C1866426', 'MEDGEN:355713', 'DOID:0060769', 'OMIM:601705', 'Orphanet:169095', 'SCTID:720345008', 'MESH:C536781', 'GARD:4358'}
# ---------------------
# {'GARD:13472', 'Orphanet:247790', 'Orphanet:447792', 'OMIM:615517', 'DOID:0111031', 'UMLS:C1851316', 'MESH:C565020', 'MEDGEN:341982'}
# ---------------------
# {'MEDGEN:1845761', 'OMIM:620669', 'UMLS:C5882740'}
# ---------------------
# {'OMIM:608030', 'UMLS:C2931786', 'MEDGEN:419901', 'DOID:0060198', 'MESH:C567699', 'GARD:9874'}
# ---------------------
# {'GARD:3350', 'SCTID:725393000', 'DOID:0060885', 'OMIM:154020', 'MEDGEN:320542', 'MESH:C537152', 'UMLS:C1835171', 'Orphanet:34528'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'OMIM:600666', 'DOID:0110860', 'MEDGEN:854672', 'UMLS:C3887964', 'GARD:18598'}
# ---------------------
# {'Orphanet:99938', 'UMLS:C1832274', 'SCTID:717011006', 'GARD:1251', 'MESH:C537993', 'DOID:0110164', 'icd11.foundation:1617529678', 'MEDGEN:316946', 'OMIM:601472', 'NCIT:C122659'}
# ---------------------
# {'MEDGEN:10590', 'NANDO:1200010', 'OMIMPS:168600', 'ICD9:332.0', 'Orphanet:319705', 'UMLS:C0030567', 'ICD9:332', 'birnlex:2098', 'SCTID:49049000', 'NCIT:C26845', 'ICD10CM:G20', 'MESH:D010300', 'DOID:14330', 'icd11.foundation:296066191', 'ICD10WHO:G20'}
# ---------------------
# {'OMIMPS:118220', 'MESH:D002607', 'NCIT:C75467', 'GARD:6034', 'MedDRA:10034699', 'NANDO:1200016', 'NANDO:2200855', 'Orphanet:166', 'NORD:919', 'DOID:10595', 'UMLS:C0007959', 'MEDGEN:2980', 'ICD9:356.1'}
# ---------------------
# {'OMIM:615506', 'MEDGEN:816040', 'UMLS:C3809710', 'GARD:15978'}
# ---------------------
# {'icd11.foundation:2023359698', 'MESH:D038261', 'NCIT:C84545', 'NANDO:2200835', 'UMLS:C0270726', 'NORD:749', 'NANDO:1200554', 'OMIM:203450', 'Orphanet:58', 'DOID:4252', 'SCTID:81854007', 'GARD:5774', 'MEDGEN:78724'}
# ---------------------
# {'DOID:0111049', 'MEDGEN:396078', 'GARD:15117', 'NCIT:C142084', 'MESH:C566060', 'OMIM:187900', 'UMLS:C1861194'}
# ---------------------
# {'MEDGEN:75587', 'Orphanet:316', 'Orphanet:317', 'Orphanet:308166', 'NORD:1285', 'DOID:0050467', 'MESH:D056266', 'OMIMPS:133200', 'GARD:16528', 'SCTID:70041004', 'MESH:C536154', 'NCIT:C84696', 'MedDRA:10049048', 'UMLS:C0265961', 'icd11.foundation:551200965'}
# ---------------------
# {'MEDGEN:56416', 'DOID:14693', 'GARD:2056', 'UMLS:C0162361', 'SCTID:54209007', 'Orphanet:189', 'OMIM:129500'}
# ---------------------
# {'GARD:9931', 'UMLS:C1847555', 'NCIT:C131832', 'Orphanet:35878', 'DOID:0070217', 'MESH:C538375', 'MEDGEN:376153', 'OMIM:606762'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'UMLS:C4225188', 'MEDGEN:905079', 'OMIM:616835', 'DOID:0080517', 'GARD:16163'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'OMIM:616973', 'Orphanet:488613', 'GARD:18501', 'UMLS:C4310774', 'MEDGEN:934741', 'DOID:0070072'}
# ---------------------
# {'OMIMPS:118220', 'MESH:D002607', 'NCIT:C75467', 'GARD:6034', 'MedDRA:10034699', 'NANDO:1200016', 'NANDO:2200855', 'Orphanet:166', 'NORD:919', 'DOID:10595', 'UMLS:C0007959', 'MEDGEN:2980', 'ICD9:356.1'}
# ---------------------
# {'MEDGEN:226914', 'Orphanet:52530', 'MESH:C536458', 'UMLS:C1280798', 'DOID:0111056', 'GARD:8312', 'OMIM:177820', 'NANDO:2200668', 'NCIT:C131681'}
# ---------------------
# {'MEDGEN:1672870', 'icd11.foundation:219068911', 'OMIMPS:601228', 'MESH:C563365', 'DOID:0111684', 'GARD:16981', 'Orphanet:157794', 'UMLS:C5192681'}
# ---------------------
# {'OMIM:618917', 'UMLS:C5394502', 'MEDGEN:1708389'}
# ---------------------
# {'OMIM:617864', 'MEDGEN:1645968', 'UMLS:C4693391'}
# ---------------------
# {'OMIMPS:105500'}
# ---------------------
# {'MEDGEN:356104', 'DOID:0080314', 'OMIM:602093', 'GARD:15342', 'UMLS:C1865869'}
# ---------------------
# {'DOID:0051011', 'UMLS:C5676905', 'OMIM:619720', 'MEDGEN:1801103'}
# ---------------------
# {'OMIM:619950', 'MEDGEN:1824083', 'UMLS:C5774310'}
# ---------------------
# {'MEDGEN:1635511', 'GARD:16277', 'UMLS:C4693798', 'OMIM:617973'}
# ---------------------
# {'MEDGEN:1642594', 'UMLS:C4693823', 'OMIM:617981', 'DOID:0111631'}
# ---------------------
# {'SCTID:74912001', 'Orphanet:330041', 'MESH:C581942', 'GARD:13007', 'UMLS:C3665425', 'MEDGEN:777099', 'OMIM:617971'}
# ---------------------
# {'DOID:0080770', 'OMIM:603902', 'Orphanet:231226', 'UMLS:C1858990', 'GARD:17164', 'SCTID:716682000', 'MESH:C565834', 'MEDGEN:347036'}
# ---------------------
# {'DOID:0111632', 'UMLS:C4693822', 'MEDGEN:1634191', 'OMIM:617980'}
# ---------------------
# {'OMIMPS:604233', 'MESH:C565808', 'MEDGEN:503203', 'DOID:0060170', 'UMLS:C3502809', 'NCIT:C122811', 'Orphanet:36387', 'GARD:18641', 'SCTID:699688008'}
# ---------------------
# {'OMIM:601144', 'MEDGEN:1646402', 'DOID:0110218', 'UMLS:C4551804'}
# ---------------------
# {'GARD:18284', 'OMIM:163800', 'UMLS:C1834144', 'MEDGEN:320273', 'MESH:C563513'}
# ---------------------
# {'OMIM:613926', 'DOID:0080317', 'MEDGEN:462706', 'GARD:15729', 'UMLS:C3151356'}
# ---------------------
# {'UMLS:C5394456', 'OMIM:618908', 'GARD:18465', 'MEDGEN:1713787'}
# ---------------------
# {'GARD:15962', 'UMLS:C3809468', 'DOID:0111384', 'MEDGEN:815798', 'OMIM:615422'}
# ---------------------
# {'icd11.foundation:537908479', 'UMLS:C5675009', 'DOID:0110273', 'Orphanet:102014', 'GARD:19824', 'OMIMPS:603511', 'MEDGEN:1826162'}
# ---------------------
# {'MESH:D056685', 'ICD9:799.89', 'GARD:1550', 'NCIT:C84652', 'UMLS:C0587248', 'SCTID:309776008', 'DOID:0050469', 'MedDRA:10067380', 'Orphanet:3071', 'NORD:1011', 'NANDO:1200463', 'icd11.foundation:1946512039', 'MEDGEN:108454', 'OMIM:218040', 'NANDO:2200971'}
# ---------------------
# {'GARD:10719', 'OMIMPS:607721', 'DOID:0080691', 'NCIT:C178129', 'Orphanet:2701', 'UMLS:C1843181', 'SCTID:723444009', 'MESH:C564342', 'MEDGEN:334697'}
# ---------------------
# {'icd11.foundation:1764310021', 'GARD:17125', 'Orphanet:217467', 'MESH:C567737', 'MEDGEN:416465', 'DOID:0111903', 'OMIM:613116', 'UMLS:C2751090'}
# ---------------------
# {'UMLS:C1847823', 'Orphanet:99940', 'DOID:0110163', 'MEDGEN:335784', 'OMIM:606595', 'MESH:C535413', 'SCTID:719510006', 'GARD:9194'}
# ---------------------
# {'Orphanet:140465', 'UMLS:C5548212', 'OMIMPS:182960', 'MEDGEN:1787720', 'GARD:19926', 'DOID:0111198'}
# ---------------------
# {'NCIT:C82342', 'NORD:1256', 'DOID:12858', 'GARD:6677', 'MedDRA:10070668', 'MEDGEN:5654', 'Orphanet:399', 'UMLS:C0020179', 'ICD9:333.4', 'icd11.foundation:2132180242', 'ICD10WHO:G10', 'NANDO:1200012', 'ICD10CM:G10', 'MESH:D006816', 'OMIM:143100', 'SCTID:58756001'}
# ---------------------
# {'GARD:18463', 'MEDGEN:894912', 'OMIM:616489', 'UMLS:C4225307'}
# ---------------------
# {'UMLS:C4748694', 'DOID:0111960', 'OMIM:618204', 'MEDGEN:1648385', 'GARD:18469'}
# ---------------------
# {'OMIM:619437', 'MEDGEN:1794150', 'DOID:0061054', 'UMLS:C5561940'}
# ---------------------
# {'Orphanet:93114', 'SCTID:722294004', 'GARD:12011', 'DOID:0110205', 'OMIM:614455', 'MEDGEN:928336', 'UMLS:C4302667'}
# ---------------------
# {'UMLS:C5442010', 'DOID:0060691', 'OMIM:187800', 'MEDGEN:1781222', 'MESH:C566061'}
# ---------------------
# {'UMLS:C5442010', 'DOID:0060691', 'OMIM:187800', 'MEDGEN:1781222', 'MESH:C566061'}
# ---------------------
# {'MESH:C536370', 'ICD9:759.89', 'GARD:13', 'SCTID:253176002', 'DOID:0111578', 'NORD:786', 'OMIM:206700', 'Orphanet:1065', 'UMLS:C0431401', 'MEDGEN:96563'}
# ---------------------
# {'GARD:10480', 'OMIM:117360', 'SCTID:715825009', 'DOID:0050978', 'icd11.foundation:359640365', 'Orphanet:208513', 'UMLS:C1861732', 'MEDGEN:350085', 'MESH:C537206'}
# ---------------------
# {'OMIM:618999', 'MEDGEN:1750270', 'UMLS:C5436572'}
# ---------------------
# {'MESH:C538398', 'DOID:0110935', 'GARD:15452', 'MEDGEN:373095', 'OMIM:609273', 'UMLS:C1836472'}
# ---------------------
# {'Orphanet:37612', 'DOID:0050989', 'OMIM:160120', 'MEDGEN:318554', 'GARD:16641', 'SCTID:421182009', 'UMLS:C1719788'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'MEDGEN:199732', 'MESH:D020191', 'SCTID:267581004', 'NANDO:1200953', 'GARD:7140', 'icd11.foundation:173613583', 'Orphanet:98261', 'NORD:1617', 'OMIMPS:254800', 'UMLS:C0751778', 'NANDO:2100237', 'NCIT:C7636', 'DOID:891'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'icd11.foundation:1191033828', 'UMLS:C1854488', 'MEDGEN:344297', 'MESH:C537195', 'SCTID:719209002', 'OMIM:605259', 'Orphanet:98768', 'DOID:0050963', 'GARD:9611'}
# ---------------------
# {'icd11.foundation:553392015', 'Orphanet:51083', 'OMIMPS:609620', 'ICD9:426.89', 'NORD:2019', 'UMLS:C2348199', 'SCTID:698272007', 'GARD:16650', 'DOID:0050793', 'MESH:C580439', 'NCIT:C71060', 'MEDGEN:378835'}
# ---------------------
# {'SCTID:419671004', 'OMIMPS:604772', 'MESH:C536334', 'NANDO:2200216', 'GARD:4421', 'ICD10CM:I47.2', 'Orphanet:3286', 'icd11.foundation:976309888', 'DOID:0060674', 'NANDO:2200221', 'UMLS:C5574922', 'MEDGEN:1803763'}
# ---------------------
# {'MEDGEN:824604', 'GARD:12362', 'OMIM:613677', 'UMLS:C3838758', 'SCTID:703234002', 'Orphanet:251274'}
# ---------------------
# {'MEDGEN:1679105', 'Orphanet:598603', 'OMIM:618381', 'UMLS:C5193066', 'GARD:18019'}
# ---------------------
# {'MESH:C563719', 'UMLS:C5574945', 'Orphanet:79137', 'GARD:16704', 'OMIM:609446', 'MEDGEN:1801137', 'DOID:0070442'}
# ---------------------
# {'GARD:18593', 'MEDGEN:934583', 'OMIM:617337', 'DOID:0111652', 'UMLS:C4310616'}
# ---------------------
# {'UMLS:C5543371', 'GARD:18547', 'OMIM:619320', 'MEDGEN:1787923', 'DOID:0061038'}
# ---------------------
# {'OMIM:617296', 'GARD:17957', 'Orphanet:521390', 'UMLS:C4284592', 'MEDGEN:924883'}
# ---------------------
# {'Orphanet:45358', 'icd11.foundation:887449084', 'DOID:0080143', 'GARD:12590', 'MEDGEN:724506', 'UMLS:C1302995', 'OMIMPS:135700', 'SCTID:400946004', 'ICD9:728.2', 'NORD:997', 'MESH:C580012'}
# ---------------------
# {'DOID:0081379', 'UMLS:C4693609', 'OMIM:617921', 'MEDGEN:1633917'}
# ---------------------
# {'DOID:0060233', 'NCIT:C84617', 'GARD:9146', 'Orphanet:1340', 'OMIMPS:115150', 'SCTID:403770008', 'MESH:C535579', 'MEDGEN:266149', 'NANDO:2200967', 'NORD:891', 'NANDO:1200462', 'UMLS:C1275081'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'MESH:D056685', 'ICD9:799.89', 'GARD:1550', 'NCIT:C84652', 'UMLS:C0587248', 'SCTID:309776008', 'DOID:0050469', 'MedDRA:10067380', 'Orphanet:3071', 'NORD:1011', 'NANDO:1200463', 'icd11.foundation:1946512039', 'MEDGEN:108454', 'OMIM:218040', 'NANDO:2200971'}
# ---------------------
# {'OMIMPS:118220', 'MESH:D002607', 'NCIT:C75467', 'GARD:6034', 'MedDRA:10034699', 'NANDO:1200016', 'NANDO:2200855', 'Orphanet:166', 'NORD:919', 'DOID:10595', 'UMLS:C0007959', 'MEDGEN:2980', 'ICD9:356.1'}
# ---------------------
# {'OMIMPS:124900', 'MEDGEN:1843285', 'UMLS:C5779548', 'Orphanet:90635', 'GARD:16791', 'DOID:0050564'}
# ---------------------
# {'GARD:2249', 'UMLS:C4707243', 'MEDGEN:1644766', 'ICD9:447.9', 'SCTID:45894003', 'Orphanet:91387', 'OMIMPS:607086', 'SCTID:764965000'}
# ---------------------
# {'DOID:0081297', 'MEDGEN:1684682', 'NANDO:1200219', 'OMIM:164310', 'UMLS:C5231388', 'GARD:15097'}
# ---------------------
# {'MEDGEN:10590', 'NANDO:1200010', 'OMIMPS:168600', 'ICD9:332.0', 'Orphanet:319705', 'UMLS:C0030567', 'ICD9:332', 'birnlex:2098', 'SCTID:49049000', 'NCIT:C26845', 'ICD10CM:G20', 'MESH:D010300', 'DOID:14330', 'icd11.foundation:296066191', 'ICD10WHO:G20'}
# ---------------------
# {'SCTID:719511005', 'MEDGEN:482427', 'UMLS:C3280797', 'OMIM:608591', 'OMIM:614436', 'DOID:0110169', 'Orphanet:300319', 'Orphanet:99941', 'GARD:12435'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'Orphanet:424099', 'MEDGEN:862977', 'DOID:0111802', 'UMLS:C4014540', 'OMIM:615877', 'GARD:17707'}
# ---------------------
# {'MESH:C535385', 'OMIM:208080', 'Orphanet:398069', 'UMLS:C5575066', 'DOID:0111715', 'MEDGEN:1807366', 'OMIM:615547', 'GARD:13316'}
# ---------------------
# {'UMLS:C1868720', 'Orphanet:98892', 'NANDO:1201079', 'GARD:12724', 'MESH:D054091', 'MedDRA:10066854', 'DOID:0050454', 'icd11.foundation:20200096', 'OMIMPS:300049', 'MEDGEN:358387'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'MESH:D056685', 'ICD9:799.89', 'GARD:1550', 'NCIT:C84652', 'UMLS:C0587248', 'SCTID:309776008', 'DOID:0050469', 'MedDRA:10067380', 'Orphanet:3071', 'NORD:1011', 'NANDO:1200463', 'icd11.foundation:1946512039', 'MEDGEN:108454', 'OMIM:218040', 'NANDO:2200971'}
# ---------------------
# {'NORD:1360', 'MedDRA:10062901', 'MEDGEN:104494', 'Orphanet:500', 'UMLS:C0175704', 'ICD9:709.09', 'MESH:D044542', 'DOID:14291', 'icd11.foundation:939197023', 'OMIMPS:151100', 'NCIT:C84820', 'SCTID:111306001', 'GARD:1100'}
# ---------------------
# {'DOID:0060233', 'NCIT:C84617', 'GARD:9146', 'Orphanet:1340', 'OMIMPS:115150', 'SCTID:403770008', 'MESH:C535579', 'MEDGEN:266149', 'NANDO:2200967', 'NORD:891', 'NANDO:1200462', 'UMLS:C1275081'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'DOID:0060233', 'NCIT:C84617', 'GARD:9146', 'Orphanet:1340', 'OMIMPS:115150', 'SCTID:403770008', 'MESH:C535579', 'MEDGEN:266149', 'NANDO:2200967', 'NORD:891', 'NANDO:1200462', 'UMLS:C1275081'}
# ---------------------
# {'OMIM:618443', 'MEDGEN:1675664', 'UMLS:C5193102'}
# ---------------------
# {'MEDGEN:1717739', 'UMLS:C5394274', 'OMIM:618849'}
# ---------------------
# {'MEDGEN:1715748', 'UMLS:C5394350', 'OMIM:618872'}
# ---------------------
# {'GARD:2249', 'UMLS:C4707243', 'MEDGEN:1644766', 'ICD9:447.9', 'SCTID:45894003', 'Orphanet:91387', 'OMIMPS:607086', 'SCTID:764965000'}
# ---------------------
# {'Orphanet:506', 'UMLS:C2931891', 'DOID:3652', 'ICD9:330.8', 'NORD:1355', 'icd11.foundation:672871576', 'MEDGEN:419518', 'GARD:6877', 'SCTID:29570005', 'MESH:D007888', 'MedDRA:10062950', 'NANDO:2200527', 'OMIM:256000', 'NCIT:C84814', 'NANDO:1200175', 'ICD10CM:G31.82'}
# ---------------------
# {'UMLS:C5569025', 'OMIM:616688', 'Orphanet:466768', 'MEDGEN:1800448', 'DOID:0110181', 'GARD:17829'}
# ---------------------
# {'UMLS:C3275998', 'MEDGEN:477629', 'OMIM:601977'}
# ---------------------
# {'OMIMPS:118220', 'MESH:D002607', 'NCIT:C75467', 'GARD:6034', 'MedDRA:10034699', 'NANDO:1200016', 'NANDO:2200855', 'Orphanet:166', 'NORD:919', 'DOID:10595', 'UMLS:C0007959', 'MEDGEN:2980', 'ICD9:356.1'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'GARD:16662', 'HP:0002697', 'SCTID:718099006', 'OMIMPS:168500', 'DOID:0060285', 'Orphanet:60015', 'MESH:C566826', 'icd11.foundation:905361904'}
# ---------------------
# {'OMIM:604757', 'GARD:5538', 'MEDGEN:346753', 'DOID:0061009', 'UMLS:C1858160', 'SCTID:720817008', 'Orphanet:1541'}
# ---------------------
# {'NCIT:C122660', 'DOID:0080664', 'UMLS:C1862177', 'GARD:10072', 'MEDGEN:350613', 'Orphanet:85182', 'OMIM:112250'}
# ---------------------
# {'GARD:7002', 'MEDGEN:358137', 'NCIT:C123171', 'OMIM:174000', 'DOID:0061118', 'Orphanet:88949', 'UMLS:C1868139'}
# ---------------------
# {'GARD:2249', 'UMLS:C4707243', 'MEDGEN:1644766', 'ICD9:447.9', 'SCTID:45894003', 'Orphanet:91387', 'OMIMPS:607086', 'SCTID:764965000'}
# ---------------------
# {'DOID:0080719', 'OMIM:605637', 'MESH:C565311', 'UMLS:C1854106', 'MEDGEN:381340'}
# ---------------------
# {'MEDGEN:1647391', 'UMLS:C4552004', 'SCTID:764859001', 'Orphanet:59135', 'GARD:10769', 'DOID:0070197', 'OMIM:160500'}
# ---------------------
# {'Orphanet:807', 'UMLS:C5200934', 'SCTID:234485006', 'ICD9:287.33', 'NCIT:C158788', 'SCTID:234484005', 'OMIM:605249', 'EFO:0009646', 'NCIT:C131646', 'SCTID:236422008', 'MESH:C537831', 'Orphanet:182050', 'OMIM:600208', 'OMIM:155100', 'ICD9:759.89', 'GARD:180', 'OMIM:153640', 'SCTID:712922002', 'ICD9:582.89', 'Orphanet:1019', 'DOID:0060651', 'Orphanet:1984', 'MEDGEN:1704278', 'Orphanet:850'}
# ---------------------
# {'GARD:2249', 'UMLS:C4707243', 'MEDGEN:1644766', 'ICD9:447.9', 'SCTID:45894003', 'Orphanet:91387', 'OMIMPS:607086', 'SCTID:764965000'}
# ---------------------
# {'OMIM:620365', 'MEDGEN:1841121', 'UMLS:C5830485'}
# ---------------------
# {'GARD:18535', 'OMIM:619092', 'MEDGEN:1764121', 'UMLS:C5436788'}
# ---------------------
# {'MEDGEN:934636', 'UMLS:C4310669', 'GARD:16210', 'OMIM:617201'}
# ---------------------
# {'MEDGEN:934757', 'OMIM:616924', 'DOID:0110180', 'UMLS:C4310790'}
# ---------------------
# {'OMIMPS:118220', 'MESH:D002607', 'NCIT:C75467', 'GARD:6034', 'MedDRA:10034699', 'NANDO:1200016', 'NANDO:2200855', 'Orphanet:166', 'NORD:919', 'DOID:10595', 'UMLS:C0007959', 'MEDGEN:2980', 'ICD9:356.1'}
# ---------------------
# {'OMIM:617892', 'MEDGEN:1632999', 'DOID:0081378', 'UMLS:C4693523'}
# ---------------------
# {'GARD:16141', 'UMLS:C4225277', 'OMIM:616576', 'DOID:0081154', 'MEDGEN:906018'}
# ---------------------
# {'DOID:0081152', 'GARD:15990', 'OMIM:615577', 'UMLS:C3809991', 'MEDGEN:816321'}
# ---------------------
# {'MEDGEN:394295', 'OMIM:612132', 'DOID:0081079', 'NCIT:C176826', 'UMLS:C2677481', 'MESH:C567411', 'GARD:15542'}
# ---------------------
# {'DOID:0050678', 'OMIM:609464', 'UMLS:C5201146', 'MESH:C538157', 'Orphanet:90341', 'NCIT:C116794', 'GARD:304', 'icd11.foundation:382488319', 'OMIM:186580', 'NANDO:1200476', 'MedDRA:10071755', 'Orphanet:90340', 'ICD9:714.89', 'ICD9:692.9', 'SCTID:699861000', 'NANDO:2200434', 'MEDGEN:1684759'}
# ---------------------
# {'OMIMPS:118450', 'MESH:D016738', 'icd11.foundation:1249656206', 'NORD:748', 'DOID:9245', 'NCIT:C35139', 'MEDGEN:39014', 'NANDO:1200919', 'UMLS:C0085280', 'ICD9:759.89', 'NANDO:1200918', 'NANDO:2200931', 'GARD:804', 'MedDRA:10053870', 'Orphanet:52', 'SCTID:31742004'}
# ---------------------
# {'MEDGEN:182961', 'UMLS:C0917715', 'MESH:C535663', 'NCIT:C84745', 'NORD:1214', 'DOID:2736', 'SCTID:63122002', 'Orphanet:955', 'MESH:C531695', 'GARD:508', 'OMIM:102500', 'MESH:C537586', 'ICD9:756.59'}
# ---------------------
# {'MESH:D056685', 'ICD9:799.89', 'GARD:1550', 'NCIT:C84652', 'UMLS:C0587248', 'SCTID:309776008', 'DOID:0050469', 'MedDRA:10067380', 'Orphanet:3071', 'NORD:1011', 'NANDO:1200463', 'icd11.foundation:1946512039', 'MEDGEN:108454', 'OMIM:218040', 'NANDO:2200971'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'DOID:0060233', 'NCIT:C84617', 'GARD:9146', 'Orphanet:1340', 'OMIMPS:115150', 'SCTID:403770008', 'MESH:C535579', 'MEDGEN:266149', 'NANDO:2200967', 'NORD:891', 'NANDO:1200462', 'UMLS:C1275081'}
# ---------------------
# {'NORD:1360', 'MedDRA:10062901', 'MEDGEN:104494', 'Orphanet:500', 'UMLS:C0175704', 'ICD9:709.09', 'MESH:D044542', 'DOID:14291', 'icd11.foundation:939197023', 'OMIMPS:151100', 'NCIT:C84820', 'SCTID:111306001', 'GARD:1100'}
# ---------------------
# {'OMIM:613750', 'ICD10CM:H35.5', 'MESH:C563526', 'DOID:0110397', 'MEDGEN:320323', 'UMLS:C1834329', 'GARD:15700'}
# ---------------------
# {'SCTID:719517009', 'UMLS:C1833809', 'DOID:0111433', 'GARD:10203', 'MEDGEN:371657', 'MESH:C537128', 'Orphanet:67036', 'OMIM:165300'}
# ---------------------
# {'GARD:15663', 'UMLS:C3150692', 'MEDGEN:462042', 'OMIM:613435', 'DOID:0060203'}
# ---------------------
# {'OMIM:606657', 'UMLS:C1847730', 'MEDGEN:335756'}
# ---------------------
# {'OMIMPS:160565', 'MEDGEN:98050', 'GARD:3884', 'Orphanet:2593', 'DOID:0080089', 'UMLS:C0410207'}
# ---------------------
# {'MESH:C565220', 'GARD:12478', 'MEDGEN:344008', 'Orphanet:36355', 'OMIM:609821', 'DOID:0060692', 'SCTID:725291001', 'NANDO:2200669', 'UMLS:C1853278'}
# ---------------------
# {'UMLS:C3554343', 'GARD:13043', 'OMIM:615009', 'Orphanet:329224', 'NCIT:C150555', 'MEDGEN:767257', 'DOID:0070047'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'GARD:16097', 'MEDGEN:903928', 'UMLS:C4225347', 'OMIM:616371'}
# ---------------------
# {'UMLS:C5193060', 'OMIM:618371', 'MEDGEN:1683283', 'Orphanet:688642'}
# ---------------------
# {'UMLS:C1863551', 'OMIM:603776', 'MESH:C566337', 'MEDGEN:355007'}
# ---------------------
# {'NORD:1174', 'ICD10CM:C49.A', 'MedDRA:10051066', 'ICDO:8936/1', 'Orphanet:44890', 'SCTID:420120006', 'GARD:8598', 'DOID:9253', 'UMLS:C0238198', 'MESH:D046152', 'OMIM:606764', 'NCIT:C3868', 'ONCOTREE:GIST', 'MEDGEN:116049'}
# ---------------------
# {'DOID:0060209', 'OMIM:614808', 'GARD:15841', 'UMLS:C3553719', 'MEDGEN:766633'}
# ---------------------
# {'OMIM:194380', 'GARD:15126', 'MEDGEN:1638271', 'UMLS:C4551512', 'DOID:0111576'}
# ---------------------
# {'MEDGEN:87542', 'OMIM:114480', 'GARD:17142', 'ICD10CM:C50.2', 'ICD10CM:C50.3', 'MESH:C562840', 'SCTID:254843006', 'NCIT:C4503', 'Orphanet:227535', 'UMLS:C0346153', 'ICD10CM:C50.6'}
# ---------------------
# {'OMIM:615513', 'DOID:0111936', 'GARD:15979', 'MEDGEN:811535', 'UMLS:C3714976', 'NORD:111933'}
# ---------------------
# {'DOID:0111050', 'icd11.foundation:1618741944', 'UMLS:C1866423', 'MESH:C536260', 'MEDGEN:356528', 'Orphanet:220436', 'GARD:8345', 'OMIM:601709'}
# ---------------------
# {'OMIM:614669', 'GARD:15831', 'MEDGEN:766318', 'UMLS:C3553404'}
# ---------------------
# {'GARD:12601', 'Orphanet:280356', 'OMIM:613877', 'UMLS:C5191005', 'MEDGEN:1675945', 'DOID:0070205'}
# ---------------------
# {'OMIMPS:118220', 'MESH:D002607', 'NCIT:C75467', 'GARD:6034', 'MedDRA:10034699', 'NANDO:1200016', 'NANDO:2200855', 'Orphanet:166', 'NORD:919', 'DOID:10595', 'UMLS:C0007959', 'MEDGEN:2980', 'ICD9:356.1'}
# ---------------------
# {'GARD:15944', 'UMLS:C3809147', 'OMIM:615327', 'MEDGEN:815477'}
# ---------------------
# {'Orphanet:363649', 'UMLS:C3715192', 'MEDGEN:811623', 'GARD:10989', 'OMIM:615381'}
# ---------------------
# {'DOID:0080792', 'OMIM:618939', 'UMLS:C5394546', 'MEDGEN:1712280', 'GARD:16396'}
# ---------------------
# {'NCIT:C85219', 'GARD:7848', 'NANDO:2201265', 'UMLS:C0162532', 'SCTID:58275005', 'OMIM:176200', 'DOID:4346', 'icd11.foundation:1227474618', 'MEDGEN:58118', 'Orphanet:79473', 'NORD:1821', 'MESH:D046350', 'NANDO:1200814'}
# ---------------------
# {'GARD:10719', 'OMIMPS:607721', 'DOID:0080691', 'NCIT:C178129', 'Orphanet:2701', 'UMLS:C1843181', 'SCTID:723444009', 'MESH:C564342', 'MEDGEN:334697'}
# ---------------------
# {'UMLS:C5394158', 'MEDGEN:1720440', 'OMIM:618820'}
# ---------------------
# {'GARD:2249', 'UMLS:C4707243', 'MEDGEN:1644766', 'ICD9:447.9', 'SCTID:45894003', 'Orphanet:91387', 'OMIMPS:607086', 'SCTID:764965000'}
# ---------------------
# {'DOID:0090077', 'OMIM:610628', 'GARD:10772', 'ICD10CM:E23.0', 'MEDGEN:765257', 'UMLS:C3552343', 'MESH:C565696'}
# ---------------------
# {'UMLS:C3550478', 'ICD10CM:E23.0', 'DOID:0090092', 'OMIM:244200', 'MEDGEN:763392', 'GARD:3073'}
# ---------------------
# {'MESH:C563320', 'ICD10CM:H35.5', 'DOID:0110356', 'OMIM:601414', 'MEDGEN:371314', 'UMLS:C1832378', 'GARD:10392'}
# ---------------------
# {'UMLS:C0238339', 'NANDO:2200942', 'SCTID:68072000', 'MEDGEN:116056', 'NANDO:1200921', 'Orphanet:676', 'icd11.foundation:1287702961', 'NCIT:C95436', 'ICD9:577.8', 'OMIM:167800', 'MESH:C537262', 'GARD:6632'}
# ---------------------
# {'MEDGEN:1375936', 'UMLS:C4479599', 'OMIM:617516'}
# ---------------------
# {'UMLS:C5436549', 'DOID:0112061', 'OMIM:618986', 'MEDGEN:1740566'}
# ---------------------
# {'SCTID:723443003', 'UMLS:C1842398', 'OMIM:608203', 'GARD:17087', 'icd11.foundation:1459690929', 'DOID:0112064', 'MEDGEN:374920', 'MESH:C564275', 'Orphanet:183707'}
# ---------------------
# {'MESH:D056685', 'ICD9:799.89', 'GARD:1550', 'NCIT:C84652', 'UMLS:C0587248', 'SCTID:309776008', 'DOID:0050469', 'MedDRA:10067380', 'Orphanet:3071', 'NORD:1011', 'NANDO:1200463', 'icd11.foundation:1946512039', 'MEDGEN:108454', 'OMIM:218040', 'NANDO:2200971'}
# ---------------------
# {'DOID:0060233', 'NCIT:C84617', 'GARD:9146', 'Orphanet:1340', 'OMIMPS:115150', 'SCTID:403770008', 'MESH:C535579', 'MEDGEN:266149', 'NANDO:2200967', 'NORD:891', 'NANDO:1200462', 'UMLS:C1275081'}
# ---------------------
# {'NORD:1360', 'MedDRA:10062901', 'MEDGEN:104494', 'Orphanet:500', 'UMLS:C0175704', 'ICD9:709.09', 'MESH:D044542', 'DOID:14291', 'icd11.foundation:939197023', 'OMIMPS:151100', 'NCIT:C84820', 'SCTID:111306001', 'GARD:1100'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'Orphanet:506', 'UMLS:C2931891', 'DOID:3652', 'ICD9:330.8', 'NORD:1355', 'icd11.foundation:672871576', 'MEDGEN:419518', 'GARD:6877', 'SCTID:29570005', 'MESH:D007888', 'MedDRA:10062950', 'NANDO:2200527', 'OMIM:256000', 'NCIT:C84814', 'NANDO:1200175', 'ICD10CM:G31.82'}
# ---------------------
# {'GARD:13232', 'MEDGEN:382634', 'UMLS:C2675556', 'Orphanet:88619', 'SCTID:723359002', 'OMIM:608033'}
# ---------------------
# {'DOID:0111800', 'OMIM:615524', 'MEDGEN:816133', 'Orphanet:689829', 'GARD:13235', 'UMLS:C3809803'}
# ---------------------
# {'Orphanet:217330', 'SCTID:721840000', 'MEDGEN:414347', 'OMIM:613092', 'GARD:13461', 'DOID:0061119', 'MESH:C567760', 'UMLS:C2751310'}
# ---------------------
# {'SCTID:111030006', 'DOID:0111506', 'GARD:3102', 'MEDGEN:324338', 'MESH:C536164', 'Orphanet:2198', 'UMLS:C1835664', 'OMIM:148500'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'MEDGEN:934681', 'OMIM:617108', 'UMLS:C4310714'}
# ---------------------
# {'DOID:0111879', 'UMLS:C2931850', 'MESH:C538442', 'NCIT:C176915', 'GARD:15568', 'MEDGEN:419918', 'OMIM:612561'}
# ---------------------
# {'NANDO:1200890', 'MEDGEN:266045', 'UMLS:C1260899', 'NCIT:C61236', 'MedDRA:10062989', 'NORD:773', 'DOID:1339', 'Orphanet:124', 'MESH:D029503', 'OMIMPS:105650', 'NANDO:2200614', 'SCTID:88854002', 'GARD:6274'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'UMLS:C2930980', 'DOID:0080990', 'MESH:C535694', 'OMIM:145600', 'MEDGEN:443948'}
# ---------------------
# {'SCTID:419671004', 'OMIMPS:604772', 'MESH:C536334', 'NANDO:2200216', 'GARD:4421', 'ICD10CM:I47.2', 'Orphanet:3286', 'icd11.foundation:976309888', 'DOID:0060674', 'NANDO:2200221', 'UMLS:C5574922', 'MEDGEN:1803763'}
# ---------------------
# {'OMIMPS:604233', 'MESH:C565808', 'MEDGEN:503203', 'DOID:0060170', 'UMLS:C3502809', 'NCIT:C122811', 'Orphanet:36387', 'GARD:18641', 'SCTID:699688008'}
# ---------------------
# {'OMIM:601144', 'MEDGEN:1646402', 'DOID:0110218', 'UMLS:C4551804'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'NANDO:2100131', 'GARD:7381', 'MedDRA:10037113', 'NCIT:C84827', 'MESH:D056929', 'SCTID:707747007', 'DOID:0050477', 'UMLS:C0221043', 'OMIMPS:177200', 'MedDRA:10052313', 'MEDGEN:67439', 'NANDO:2200363', 'NORD:2034', 'Orphanet:526'}
# ---------------------
# {'MEDGEN:313270', 'Orphanet:29072', 'GARD:11984', 'OMIMPS:168000', 'UMLS:C1708353'}
# ---------------------
# {'UMLS:C4310769', 'DOID:0060975', 'GARD:16174', 'MEDGEN:934736', 'OMIM:617004'}
# ---------------------
# {'MEDGEN:199732', 'MESH:D020191', 'SCTID:267581004', 'NANDO:1200953', 'GARD:7140', 'icd11.foundation:173613583', 'Orphanet:98261', 'NORD:1617', 'OMIMPS:254800', 'UMLS:C0751778', 'NANDO:2100237', 'NCIT:C7636', 'DOID:891'}
# ---------------------
# {'DOID:3755', 'MESH:D020152', 'NORD:791', 'SCTID:36351005', 'GARD:6148', 'MEDGEN:75781', 'OMIM:613118', 'UMLS:C0272375', 'ICD9:286.9', 'Orphanet:82'}
# ---------------------
# {'ICD9:286.3', 'OMIM:612356', 'MEDGEN:96017', 'MESH:C562865', 'SCTID:234468009', 'DOID:0111901', 'UMLS:C0398626'}
# ---------------------
# {'DOID:0080939', 'MEDGEN:1812520', 'Orphanet:528623', 'OMIM:106100', 'GARD:22194', 'UMLS:C4552294'}
# ---------------------
# {'MEDGEN:199732', 'MESH:D020191', 'SCTID:267581004', 'NANDO:1200953', 'GARD:7140', 'icd11.foundation:173613583', 'Orphanet:98261', 'NORD:1617', 'OMIMPS:254800', 'UMLS:C0751778', 'NANDO:2100237', 'NCIT:C7636', 'DOID:891'}
# ---------------------
# {'OMIM:619611', 'DOID:0060941', 'MEDGEN:1794231', 'UMLS:C5562021'}
# ---------------------
# {'OMIM:178500', 'DOID:0060971', 'UMLS:C5561926', 'MEDGEN:1794136'}
# ---------------------
# {'GARD:10719', 'OMIMPS:607721', 'DOID:0080691', 'NCIT:C178129', 'Orphanet:2701', 'UMLS:C1843181', 'SCTID:723444009', 'MESH:C564342', 'MEDGEN:334697'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'MESH:D056685', 'ICD9:799.89', 'GARD:1550', 'NCIT:C84652', 'UMLS:C0587248', 'SCTID:309776008', 'DOID:0050469', 'MedDRA:10067380', 'Orphanet:3071', 'NORD:1011', 'NANDO:1200463', 'icd11.foundation:1946512039', 'MEDGEN:108454', 'OMIM:218040', 'NANDO:2200971'}
# ---------------------
# {'DOID:0060233', 'NCIT:C84617', 'GARD:9146', 'Orphanet:1340', 'OMIMPS:115150', 'SCTID:403770008', 'MESH:C535579', 'MEDGEN:266149', 'NANDO:2200967', 'NORD:891', 'NANDO:1200462', 'UMLS:C1275081'}
# ---------------------
# {'MedDRA:10071135', 'GARD:10147', 'SCTID:290006', 'MEDGEN:82693', 'DOID:14702', 'NCIT:C98983', 'icd11.foundation:504227287', 'NANDO:1200675', 'Orphanet:107', 'ICD9:759.89', 'MESH:D019280', 'OMIMPS:113650', 'UMLS:C0265234', 'Wikipedia:Branchio-oto-renal_syndrome'}
# ---------------------
# {'SCTID:719069008', 'OMIM:182212', 'Orphanet:2462', 'NORD:1908', 'UMLS:C1321551', 'NCIT:C124840', 'GARD:4861', 'MEDGEN:231160'}
# ---------------------
# {'OMIM:617105', 'GARD:16190', 'UMLS:C4310717', 'DOID:0080442', 'MEDGEN:934684'}
# ---------------------
# {'GARD:17107', 'DOID:0050994', 'MEDGEN:390739', 'UMLS:C2675211', 'MESH:C567207', 'OMIM:612656', 'icd11.foundation:1493336901', 'Orphanet:209967', 'SCTID:718753002'}
# ---------------------
# {'MEDGEN:330858', 'MESH:C564286', 'OMIM:608118', 'UMLS:C1842486'}
# ---------------------
# {'icd11.foundation:553392015', 'Orphanet:51083', 'OMIMPS:609620', 'ICD9:426.89', 'NORD:2019', 'UMLS:C2348199', 'SCTID:698272007', 'GARD:16650', 'DOID:0050793', 'MESH:C580439', 'NCIT:C71060', 'MEDGEN:378835'}
# ---------------------
# {'DOID:0111201', 'MESH:C563562', 'UMLS:C1834703', 'GARD:18269', 'MEDGEN:322474', 'OMIM:158580'}
# ---------------------
# {'MEDGEN:934764', 'GARD:18491', 'Orphanet:466806', 'UMLS:C4310797', 'DOID:0111055', 'OMIM:616913'}
# ---------------------
# {'DOID:0060964', 'MEDGEN:1794251', 'OMIM:619656', 'UMLS:C5562041'}
# ---------------------
# {'SCTID:401046009', 'GARD:270', 'MEDGEN:220983', 'UMLS:C1303073', 'DOID:0081441', 'OMIM:601358', 'Orphanet:3051', 'MESH:C536116'}
# ---------------------
# {'Orphanet:1465', 'NORD:984', 'MEDGEN:75565', 'icd11.foundation:734451870', 'DOID:1925', 'NCIT:C35321', 'ICD9:759.89', 'NANDO:1200670', 'GARD:6124', 'SCTID:10007009', 'UMLS:C0265338', 'NANDO:2200977', 'OMIMPS:135900', 'MESH:C536436'}
# ---------------------
# {'NCIT:C75016', 'GARD:10109', 'icd11.foundation:1801560012', 'MedDRA:10056354', 'NANDO:2200958', 'NORD:1009', 'NANDO:1200960', 'DOID:11725', 'OMIMPS:122470', 'Orphanet:199', 'UMLS:C0270972', 'MEDGEN:78752'}
# ---------------------
# {'Orphanet:1135', 'SCTID:720511000', 'Orphanet:2250', 'MEDGEN:355084', 'MESH:C537429', 'UMLS:C1863878', 'OMIM:603457'}
# ---------------------
# {'ICD9:345.10', 'DOID:0112202', 'OMIMPS:308350', 'NANDO:1200593', 'NCIT:C122814', 'GARD:9255'}
# ---------------------
# {'MEDGEN:10590', 'NANDO:1200010', 'OMIMPS:168600', 'ICD9:332.0', 'Orphanet:319705', 'UMLS:C0030567', 'ICD9:332', 'birnlex:2098', 'SCTID:49049000', 'NCIT:C26845', 'ICD10CM:G20', 'MESH:D010300', 'DOID:14330', 'icd11.foundation:296066191', 'ICD10WHO:G20'}
# ---------------------
# {'MEDGEN:1784363', 'UMLS:C5543547', 'OMIM:619375'}
# ---------------------
# {'MESH:C531617', 'DOID:0060193', 'MEDGEN:400169', 'OMIM:105400', 'UMLS:C1862939'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'MESH:D056685', 'ICD9:799.89', 'GARD:1550', 'NCIT:C84652', 'UMLS:C0587248', 'SCTID:309776008', 'DOID:0050469', 'MedDRA:10067380', 'Orphanet:3071', 'NORD:1011', 'NANDO:1200463', 'icd11.foundation:1946512039', 'MEDGEN:108454', 'OMIM:218040', 'NANDO:2200971'}
# ---------------------
# {'DOID:0060233', 'NCIT:C84617', 'GARD:9146', 'Orphanet:1340', 'OMIMPS:115150', 'SCTID:403770008', 'MESH:C535579', 'MEDGEN:266149', 'NANDO:2200967', 'NORD:891', 'NANDO:1200462', 'UMLS:C1275081'}
# ---------------------
# {'MedDRA:10029748', 'SCTID:205824006', 'MEDGEN:18073', 'NCIT:C34854', 'OMIMPS:163950', 'UMLS:C0028326', 'DOID:3490', 'icd11.foundation:1044395354', 'NANDO:1200680', 'Orphanet:648', 'MESH:D009634', 'ICD9:759.89', 'NORD:1513', 'GARD:10955', 'NANDO:2200413'}
# ---------------------
# {'MEDGEN:1778557', 'Orphanet:662234', 'OMIM:619312', 'UMLS:C5543339'}
# ---------------------
# {'MEDGEN:1806624', 'DOID:0081142', 'UMLS:C5676900', 'OMIM:619707'}
# ---------------------
# {'UMLS:C5561957', 'OMIM:619475', 'MEDGEN:1794167'}
# ---------------------
# {'Orphanet:98766', 'MEDGEN:155705', 'DOID:0050882', 'icd11.foundation:78905851', 'OMIM:600224', 'SCTID:719302009', 'GARD:4953', 'UMLS:C0752123'}
# ---------------------
# {'UMLS:C3150896', 'DOID:0070157', 'OMIM:613640', 'MEDGEN:462246', 'GARD:15683'}
# ---------------------
# {'OMIM:616437', 'GARD:16113', 'DOID:0110068', 'UMLS:C4225326', 'MEDGEN:897127'}
# ---------------------
# {'UMLS:C4310789', 'Orphanet:480851', 'OMIM:616937', 'GARD:17870', 'MEDGEN:934756'}
# ---------------------
# {'MEDGEN:152667', 'NCIT:C175241', 'OMIM:136140', 'Orphanet:2044', 'icd11.foundation:2101730645', 'DOID:0111358', 'ICD9:759.89', 'MESH:C537062', 'NORD:1151', 'UMLS:C0729582', 'SCTID:312214005', 'GARD:6455'}
# ---------------------
# {'MEDGEN:1768962', 'OMIM:165510', 'MESH:C563494', 'UMLS:C5435585'}
# ---------------------
# {'Orphanet:506', 'UMLS:C2931891', 'DOID:3652', 'ICD9:330.8', 'NORD:1355', 'icd11.foundation:672871576', 'MEDGEN:419518', 'GARD:6877', 'SCTID:29570005', 'MESH:D007888', 'MedDRA:10062950', 'NANDO:2200527', 'OMIM:256000', 'NCIT:C84814', 'NANDO:1200175', 'ICD10CM:G31.82'}
# ---------------------
# {'Orphanet:319595', 'MEDGEN:862387', 'UMLS:C4013950', 'DOID:0111945', 'OMIM:614892'}
# ---------------------
# {'OMIM:614162', 'UMLS:C3279990', 'Orphanet:391487', 'DOID:0111946', 'MEDGEN:481620', 'GARD:12314'}
# ---------------------
# {'UMLS:C4014795', 'Orphanet:438159', 'NCIT:C157123', 'DOID:0061160', 'MEDGEN:863232', 'GARD:17737', 'OMIM:615952'}
# ---------------------
# {'SCTID:50926003', 'OMIM:147060', 'NCIT:C126342', 'DOID:3261', 'OMIM:146840', 'Orphanet:2314', 'MEDGEN:445391', 'UMLS:C2936739', 'GARD:6800', 'MESH:C567925', 'MESH:C564135'}
# ---------------------
# {'UMLS:C5848786', 'MEDGEN:1851769', 'OMIM:620532'}
# ---------------------
# {'OMIMPS:160565', 'MEDGEN:98050', 'GARD:3884', 'Orphanet:2593', 'DOID:0080089', 'UMLS:C0410207'}
# ---------------------
# {'MEDGEN:1794278', 'OMIM:619714', 'UMLS:C5562068'}
# ---------------------
# {'OMIMPS:604233', 'MESH:C565808', 'MEDGEN:503203', 'DOID:0060170', 'UMLS:C3502809', 'NCIT:C122811', 'Orphanet:36387', 'GARD:18641', 'SCTID:699688008'}
# ---------------------
# {'MedDRA:10027107', 'EFO:0002939', 'DOID:0050902', 'GARD:7005', 'OMIM:155255', 'Orphanet:616', 'ONCOTREE:MBL', 'NORD:1422', 'MESH:D008527', 'ICDO:9470/3', 'icd11.foundation:290815825', 'MEDGEN:7517', 'DOID:0060104', 'NANDO:2200090', 'UMLS:C0025149', 'NCIT:C3222', 'SCTID:443333004'}
# ---------------------
# {'UMLS:C4015038', 'MEDGEN:863475', 'DOID:0110659', 'GARD:16053', 'OMIM:616040'}
# ---------------------
# {'OMIM:618906', 'GARD:18522', 'UMLS:C5394447', 'DOID:0081430', 'MEDGEN:1715081'}
# ---------------------
# {'MESH:C567429', 'OMIM:612069', 'UMLS:C2677565', 'DOID:0060201', 'GARD:15540', 'MEDGEN:383137'}
# ---------------------
# {'GARD:18398', 'DOID:0110069', 'UMLS:C4225325', 'MEDGEN:902979', 'OMIM:616439'}
# ---------------------
# {'SCTID:707273001', 'UMLS:C4551974', 'GARD:6299', 'MEDGEN:1645250', 'NCIT:C176921', 'DOID:0070014', 'MESH:C565079', 'OMIM:127550'}
# ---------------------
# {'NCIT:C176922', 'DOID:0070016', 'OMIM:613989', 'UMLS:C3151443', 'MEDGEN:462793', 'GARD:15741'}
# ---------------------
# {'Orphanet:684216', 'OMIM:618798', 'UMLS:C5394097', 'MEDGEN:1711894'}
# ---------------------
# {'GARD:2249', 'UMLS:C4707243', 'MEDGEN:1644766', 'ICD9:447.9', 'SCTID:45894003', 'Orphanet:91387', 'OMIMPS:607086', 'SCTID:764965000'}
# ---------------------
# {'GARD:10586', 'DOID:0070234', 'MESH:C537783', 'UMLS:C2674574', 'OMIM:610168', 'NCIT:C114768', 'Orphanet:284973', 'MEDGEN:382398'}
# ---------------------
# {'GARD:2249', 'UMLS:C4707243', 'MEDGEN:1644766', 'ICD9:447.9', 'SCTID:45894003', 'Orphanet:91387', 'OMIMPS:607086', 'SCTID:764965000'}
# ---------------------
# {'Orphanet:436169', 'OMIM:614486', 'DOID:0111908', 'MESH:C566057', 'MEDGEN:482606', 'GARD:17726', 'UMLS:C3280976'}
# ---------------------
# {'UMLS:C1327915', 'icd11.foundation:801723173', 'MEDGEN:272171', 'OMIMPS:604498'}
# ---------------------
# {'MEDGEN:479301', 'UMLS:C3277671', 'OMIM:187950'}
# ---------------------
# {'MEDGEN:338164', 'Orphanet:59181', 'OMIM:136900', 'UMLS:C1850938', 'SCTID:193410003', 'MESH:C564992', 'icd11.foundation:796458172', 'DOID:0090114', 'GARD:16480'}
# ---------------------
# {'DOID:0070018', 'GARD:15742', 'OMIM:613990', 'NCIT:C176923', 'MEDGEN:462795', 'UMLS:C3151445'}
# ---------------------
# {'MESH:C565776', 'MEDGEN:346805', 'UMLS:C1858379', 'DOID:0110074', 'OMIM:604400'}
# ---------------------
# {'icd11.foundation:1869883509', 'DOID:0090018', 'NANDO:2200433', 'NANDO:1200472', 'UMLS:C1275126', 'SCTID:403833009', 'MESH:C536657', 'MEDGEN:226899', 'NCIT:C119051', 'Orphanet:32960', 'OMIM:142680', 'NORD:1804', 'GARD:8457'}
# ---------------------
# {'icd11.foundation:537908479', 'UMLS:C5675009', 'DOID:0110273', 'Orphanet:102014', 'GARD:19824', 'OMIMPS:603511', 'MEDGEN:1826162'}
# ---------------------
# {'MESH:C563745', 'Orphanet:567502', 'OMIM:609296', 'UMLS:C1836437', 'MEDGEN:332208'}
# ---------------------
# {'DOID:0060783', 'MEDGEN:347666', 'OMIM:604292', 'MESH:C565799', 'UMLS:C1858562'}
# ---------------------
# {'UMLS:C5561938', 'MEDGEN:1794148', 'OMIM:619428'}
# ---------------------
# {'MEDGEN:1840935', 'UMLS:C5830299', 'OMIM:620253'}
# ---------------------
# {'OMIMPS:613112'}
# ---------------------
# {'MEDGEN:863949', 'DOID:0060355', 'UMLS:C4015512', 'OMIM:616208', 'GARD:16068'}
# ---------------------
# {'DOID:0090102', 'MEDGEN:1811721', 'MESH:C567747', 'OMIM:613112', 'GARD:18271', 'UMLS:C5676892'}
# ---------------------
# {'DOID:0090131', 'OMIMPS:614039'}
# ---------------------
# {'GARD:12291', 'NANDO:2200817', 'MEDGEN:78604', 'SCTID:204036008', 'NORD:1374', 'MESH:D054082', 'UMLS:C0266463', 'Orphanet:48471', 'NANDO:1200574', 'OMIMPS:607432', 'MedDRA:10048911', 'NCIT:C103921', 'HP:0001339', 'DOID:0050453'}
# ---------------------
# {'OMIM:619959', 'MEDGEN:1804308', 'UMLS:C5677019'}
# ---------------------
# {'MEDGEN:1626007', 'DOID:0070474', 'Orphanet:500180', 'UMLS:C4540086', 'GARD:13658', 'OMIM:617672'}
# ---------------------
# {'icd11.foundation:810807375', 'ICD10CM:G11.4', 'MEDGEN:20844', 'NCIT:C140267', 'MedDRA:10019903', 'NORD:1238', 'Orphanet:685', 'NANDO:1200052', 'OMIMPS:303350', 'SCTID:39912006', 'DOID:2476', 'MESH:D015419', 'ICD9:334.1', 'GARD:6637', 'UMLS:C0037773'}
# ---------------------
# {'UMLS:C0024141', 'DOID:9074', 'ICD10CM:M32', 'Orphanet:536', 'MESH:D008180', 'NCIT:C3201', 'icd11.foundation:749596428', 'GARD:18695', 'NANDO:1200272', 'OMIM:152700', 'HP:0002725', 'ICD10WHO:M32', 'MEDGEN:6146', 'ICD9:710.0', 'SCTID:55464009', 'NORD:1380', 'NANDO:2200416'}
# ---------------------
# {'OMIM:608627', 'DOID:0050752', 'GARD:10499', 'UMLS:C1837728', 'MESH:C563895', 'MEDGEN:325237'}
# ---------------------
# {'GARD:7871', 'OMIM:143200', 'MEDGEN:326741', 'MESH:C536075', 'ICD10CM:H35.5', 'SCTID:232064001', 'icd11.foundation:780893571', 'MedDRA:10063383', 'Orphanet:898', 'UMLS:C1840452'}
# ---------------------
# {'MEDGEN:322251', 'UMLS:C1833662', 'OMIMPS:167320', 'DOID:0050881', 'GARD:10899', 'SCTID:703544004', 'Orphanet:52430', 'icd11.foundation:1947548457'}
# ---------------------
# {'MEDGEN:10590', 'NANDO:1200010', 'OMIMPS:168600', 'ICD9:332.0', 'Orphanet:319705', 'UMLS:C0030567', 'ICD9:332', 'birnlex:2098', 'SCTID:49049000', 'NCIT:C26845', 'ICD10CM:G20', 'MESH:D010300', 'DOID:14330', 'icd11.foundation:296066191', 'ICD10WHO:G20'}
# ---------------------
# {'DOID:0110823', 'UMLS:C1863704', 'MEDGEN:400359', 'GARD:9591', 'MESH:C580458', 'Orphanet:100989', 'OMIM:603563'}
# ---------------------
# {'DOID:0111675', 'OMIM:618652', 'MEDGEN:1684841', 'Orphanet:684305', 'UMLS:C5231443'}
# ---------------------
# {'UMLS:C3280358', 'MESH:C565631', 'GARD:17683', 'Orphanet:411590', 'DOID:0080584', 'SCTID:734022008', 'OMIM:614296', 'MEDGEN:481988'}
# ---------------------
# {'OMIMPS:118220', 'MESH:D002607', 'NCIT:C75467', 'GARD:6034', 'MedDRA:10034699', 'NANDO:1200016', 'NANDO:2200855', 'Orphanet:166', 'NORD:919', 'DOID:10595', 'UMLS:C0007959', 'MEDGEN:2980', 'ICD9:356.1'}
# ---------------------
# {'UMLS:C0796121', 'MEDGEN:162911', 'GARD:4488', 'OMIM:259050', 'Orphanet:3042', 'MESH:C536420', 'SCTID:726709001'}
# ---------------------
# {'MEDGEN:1684878', 'OMIM:618674', 'UMLS:C5231457'}
# ---------------------
# {'MEDGEN:904675', 'UMLS:C4225269', 'OMIM:616602', 'Orphanet:672985', 'DOID:0061008', 'GARD:18048'}
# ---------------------
# {'MESH:C566345', 'MEDGEN:350933', 'SCTID:715427008', 'Orphanet:1827', 'UMLS:C1863616', 'GARD:5539', 'DOID:0060342', 'OMIM:603671'}
# ---------------------

# %%
counter
# Out:
# 411

# %%
counter=0
for idx, row in dis.iterrows():
    cur_mondo=row['DISEASE ID (MONDO)']
    cur_xrefs = mondo_xrefs(cur_mondo)
    if any('OMIMPS' in element for element in cur_xrefs):
        counter+=1

# %%
counter
# Out:
# 127

# %%
def mondo_xrefs(mondo_id): # prefixes=("OMIM", "Orpha")):
    term = mondo.get(mondo_id)
    xrefs=set()
    if term is None:
        return set()
    else:
        for x in term.xrefs:
            xrefs.add(getattr(x, 'id'))
    return xrefs

mondo_xrefs('MONDO:0015626')
# Out:
# {'DOID:10595',
#  'GARD:6034',
#  'ICD9:356.1',
#  'MEDGEN:2980',
#  'MESH:D002607',
#  'MedDRA:10034699',
#  'NANDO:1200016',
#  'NANDO:2200855',
#  'NCIT:C75467',
#  'NORD:919',
#  'OMIMPS:118220',
#  'Orphanet:166',
#  'UMLS:C0007959'}

# %%
term.xref
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 term.xref
#
# AttributeError: 'Term' object has no attribute 'xref'

# %%
term
# Out:
# Term('MONDO:0015626', name='Charcot-Marie-Tooth disease')

# %%
for x in term.xrefs:
    print(x)
    print(getattr(x, 'id'))
# Out:
# Xref('MESH:D002607')
# MESH:D002607
# Xref('NCIT:C75467')
# NCIT:C75467
# Xref('OMIMPS:118220')
# OMIMPS:118220
# Xref('GARD:6034')
# GARD:6034
# Xref('MedDRA:10034699')
# MedDRA:10034699
# Xref('NANDO:1200016')
# NANDO:1200016
# Xref('NANDO:2200855')
# NANDO:2200855
# Xref('Orphanet:166')
# Orphanet:166
# Xref('NORD:919')
# NORD:919
# Xref('DOID:10595')
# DOID:10595
# Xref('UMLS:C0007959')
# UMLS:C0007959
# Xref('MEDGEN:2980')
# MEDGEN:2980
# Xref('ICD9:356.1')
# ICD9:356.1
